# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Yousef Medhat
# - Alumno 2: Carlos Manzano Izquierdo
# - Alumno 3: Guillermo Bermejo Babiano
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# The -q flag means "quiet" so it doesn't print 10,000 lines and crash your browser
# !unzip -q "/content/drive/MyDrive/DL/xview_recognition.zip" -d "/content/dataset"

print("✅ Unzipping complete!")
# Out:
# ✅ Unzipping complete!

# %%
data_dir = '/content/dataset/xview_recognition' # Or whatever the extracted folder is named

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open('../content/dataset/xview_recognition/'+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json

# Load database
json_file = '../content/dataset/xview_recognition/xview_ann_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 16871
# Number of validation images: 1875

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L2

# Definimos la regularización una vez para reusarla
reg = L2(0.001)

model = Sequential([
    # 1. Input & Flatten
    Flatten(input_shape=(64, 64, 3)),
    BatchNormalization(),

    # 2. Block 1: 512 Neurons
    Dense(512, kernel_initializer='he_normal', kernel_regularizer=reg),
    BatchNormalization(),
    Activation('swish'),
    Dropout(0.3),

    # 3. Block 2: 256 Neurons
    Dense(256, kernel_initializer='he_normal', kernel_regularizer=reg),
    BatchNormalization(),
    Activation('swish'),
    Dropout(0.3),

    # 4. Block 3: 128 Neurons (Ayuda a comprimir la información antes de clasificar)
    Dense(128, kernel_initializer='he_normal', kernel_regularizer=reg),
    BatchNormalization(),
    Activation('swish'),
    Dropout(0.2),

    # 5. Output Layer
    Dense(len(categories), activation='softmax')
])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 12288)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 12288)          │        49,152 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     6,291,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,510,605 (24.84 MB)
#  Trainable params: 6,484,237 (24.74 MB)
#  Non-trainable params: 26,368 (103.00 KB)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalFocalCrossentropy

focal_loss = CategoricalFocalCrossentropy(
    gamma=2.0,        # Fuerza el enfoque en lo difícil
    alpha=0.25,       # Balancea la importancia general
    label_smoothing=0.1,  # Label smoothing para overfitting
    from_logits=False # False porque usamos Softmax al final
)

opt = Adam(learning_rate=0.001)

model.compile(optimizer=opt, loss=focal_loss, metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_delta=0.001,
    verbose=1
)
early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
def generator_from_ram(X_data, y_data, batch_size, do_shuffle=False, do_augment=False):
    # Índices para saber qué foto toca
    indices = np.arange(len(X_data))

    while True:
        if do_shuffle:
            np.random.shuffle(indices)

        # Troceamos los índices en batches
        for i in range(0, len(indices), batch_size):
            batch_indices = indices[i:i+batch_size]

            # Cogemos las imágenes crudas de la RAM
            batch_images_raw = X_data[batch_indices]
            batch_cats = y_data[batch_indices]

            images, labels = [], []

            for j in range(len(batch_images_raw)):
                # Copiamos la imagen para no modificar la original en RAM
                img = batch_images_raw[j].copy()
                cat = batch_cats[j]

                # ==========================================
                # AUGMENTATION "SAFE MODE" (Solo Brillo y Giros)
                # ==========================================
                if do_augment:
                    # 1. ROTACIÓN (90, 180, 270)
                    k = np.random.randint(0, 4)
                    if k > 0: img = np.rot90(img, k)

                    # 2. FLIP (Espejo)
                    if np.random.rand() > 0.5:
                        code = np.random.choice([0, 1])
                        img = cv2.flip(img, code)

                    # 3. BRILLO/CONTRASTE (Sin Traslación)
                    # Lo aplicamos el 80% de las veces para dar variedad de color
                    if np.random.rand() > 0.2:
                        alpha = np.random.uniform(0.8, 1.2) # Contraste
                        beta = np.random.uniform(-25, 25)   # Brillo
                        img = cv2.convertScaleAbs(img, alpha=alpha, beta=beta)
                # ==========================================

                # Normalización (Aquí pasamos a float)
                img_float = img.astype(np.float32) / 255.0

                # One-Hot Encoding
                prob = np.zeros(len(categories))
                prob[list(categories.values()).index(cat)] = 1

                images.append(img_float)
                labels.append(prob)

            yield np.array(images), np.array(labels)

# %%
import numpy as np
import cv2
from tqdm import tqdm  # Barra de progreso

def load_dataset_to_ram(objs_list, target_size=(64, 64)):
    print(f"Cargando {len(objs_list)} imágenes en RAM... ")

    X_data = []
    y_labels = []

    for filename, obj in tqdm(objs_list):
        # 1. Cargar
        img = load_geoimage(filename)

        # 2. Redimensionar a target size
        # (Es vital para poder apilarlas en un array de Numpy)
        if img.shape[:2] != target_size:
            img = cv2.resize(img, target_size, interpolation=cv2.INTER_AREA)

        # 3. Guardar tal cual (uint8, 0-255).
        # NO dividas por 255 aquí o ocuparás 4 veces más RAM.
        X_data.append(img)
        y_labels.append(obj.category)

    # Convertir a Bloque Numpy
    X_data = np.array(X_data, dtype='uint8')
    y_labels = np.array(y_labels)

    print(f"¡Carga lista! Ocupa en RAM: {X_data.nbytes / 1024 / 1024:.2f} MB")
    return X_data, y_labels

# %%
def balance_dataset_list(objs):
    # 1. Contamos cuántos hay de cada clase originalmente
    counts = {}
    for _, obj in objs:
        c = obj.category
        counts[c] = counts.get(c, 0) + 1

    print("--- CONTEO ORIGINAL ---")
    print(counts)

    balanced_objs = []

    # CONFIGURACIÓN DE OBJETIVOS
    TARGET_STANDARD = 2000  # Objetivo para la mayoría (Pylons, Barcos, Camiones...)
    TARGET_TINY = 1000      # Objetivo conservador para las muy pequeñas (Helipuertos)
    TINY_THRESHOLD = 200    # Si tiene menos de 200, usamos el objetivo 'Tiny'

    for filename, obj in objs:
        # Siempre añadimos la imagen original
        balanced_objs.append((filename, obj))

        current_count = counts[obj.category]

        # Determinamos el objetivo según el tamaño de la clase
        if current_count < TINY_THRESHOLD:
            target = TARGET_TINY  # Caso Helipuertos (111 -> ~1000)
        else:
            target = TARGET_STANDARD # Caso Pylons/Trucks (300 -> ~2000)

        # Si estamos por debajo del objetivo, calculamos copias
        if current_count < target:
            # Ejemplo Pylon (312): 2000 / 312 = 6.4 -> Multiplicador 6 (Total 7 copias)
            # Ejemplo Helipuerto (111): 1000 / 111 = 9.0 -> Multiplicador 9 (Total 10 copias)
            # Restamos 1 porque ya añadimos la original arriba
            multiplier = int(target / current_count) - 1

            # Solo añadimos si el multiplicador es positivo
            if multiplier > 0:
                for _ in range(multiplier):
                    balanced_objs.append((filename, obj))

    print(f"\n--- DATASET BALANCEADO ---")
    print(f"De {len(objs)} imágenes pasamos a {len(balanced_objs)} imágenes virtuales.")

    return balanced_objs

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]

# PASO 1: Balanceo de clases
print("--- FASE 1: Balanceo ---")
objs_train_balanced = balance_dataset_list(objs_train)


# PASO 2: Cargar todo en RAM
# -------------------------------------------------------
print("\n--- FASE 2: Carga en RAM ---")
# Train con lista inflada
X_train_ram, y_train_ram = load_dataset_to_ram(objs_train_balanced)
# Valid con lista normal
X_valid_ram, y_valid_ram = load_dataset_to_ram(objs_valid)

# PASO 3: Crear Generadores Rápidos
# -------------------------------------------------------
batch_size = 32

train_gen = generator_from_ram(
    X_train_ram, y_train_ram,
    batch_size=batch_size,
    do_shuffle=True,
    do_augment=True
)

valid_gen = generator_from_ram(
    X_valid_ram, y_valid_ram,
    batch_size=batch_size,
    do_shuffle=False,
    do_augment=False
)
# Out:
# --- FASE 1: Balanceo ---
# --- CONTEO ORIGINAL ---
# {'Bus': 1594, 'Cargo plane': 576, 'Truck': 1969, 'Building': 3231, 'Fishing vessel': 633, 'Small car': 2995, 'Pylon': 280, 'Shipping container': 1388, 'Dump truck': 1118, 'Motorboat': 960, 'Storage tank': 1317, 'Excavator': 708, 'Helipad': 102}
#
# --- DATASET BALANCEADO ---
# De 16871 imágenes pasamos a 23453 imágenes virtuales.
#
# --- FASE 2: Carga en RAM ---
# Cargando 23453 imágenes en RAM...
# 100%|██████████| 23453/23453 [01:07<00:00, 344.95it/s]
# ¡Carga lista! Ocupa en RAM: 274.84 MB
# Cargando 1875 imágenes en RAM...
# 100%|██████████| 1875/1875 [00:04<00:00, 388.83it/s]
# ¡Carga lista! Ocupa en RAM: 21.97 MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_class_balance(original_objs, balanced_objs):
    # 1. Contar Originales
    counts_orig = {}
    for _, obj in original_objs:
        counts_orig[obj.category] = counts_orig.get(obj.category, 0) + 1

    # 2. Contar Balanceados
    counts_bal = {}
    for _, obj in balanced_objs:
        counts_bal[obj.category] = counts_bal.get(obj.category, 0) + 1

    # Preparar datos para plot
    classes = list(counts_orig.keys())
    # Ordenamos por cantidad original para que quede bonito
    classes.sort(key=lambda x: counts_orig[x], reverse=True)

    vals_orig = [counts_orig[c] for c in classes]
    vals_bal = [counts_bal[c] for c in classes]

    x = range(len(classes))
    width = 0.35

    plt.figure(figsize=(15, 6))
    plt.bar([i - width/2 for i in x], vals_orig, width, label='Original', color='red', alpha=0.6)
    plt.bar([i + width/2 for i in x], vals_bal, width, label='Balanceado (Virtual)', color='green', alpha=0.6)

    plt.xticks(x, classes, rotation=45, ha='right')
    plt.ylabel('Número de Imágenes')
    plt.title('Impacto del Oversampling en el Dataset')
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# USARLO:
plot_class_balance(objs_train, objs_train_balanced)

# %%
import matplotlib.pyplot as plt
import numpy as np

def visualize_ram_augmentation(X_data, y_data, generator_func):
    # 1. Buscar índices de Helipuertos (o la clase que quieras ver)
    # Asumimos que y_data tiene los nombres de las clases (strings)
    indices = np.where(y_data == 'Helipad')[0]

    if len(indices) == 0:
        print("No se encontraron Helipuertos en los datos proporcionados.")
        return

    idx = indices[0] # Cogemos el primer helipuerto que encontremos

    # 2. Extraer la imagen y la etiqueta originales de la RAM
    sample_img = X_data[idx]
    sample_cat = y_data[idx]

    # 3. Crear un "Mini Batch Falso" de 5 copias idénticas
    # Repetimos la imagen 5 veces: (5, 64, 64, 3)
    fake_X = np.array([sample_img] * 5)
    fake_y = np.array([sample_cat] * 5)

    # 4. Instanciar el generador con estos datos falsos
    # Le decimos batch_size=5 para que nos devuelva las 5 de golpe
    gen = generator_func(fake_X, fake_y, batch_size=5, do_shuffle=False, do_augment=True)

    images_aug, _ = next(gen) # Sacamos el batch procesado

    # 5. Pintar
    plt.figure(figsize=(15, 4))
    for i in range(5):
        plt.subplot(1, 5, i+1)

        # Las imágenes vienen normalizadas (0-1) y en float32
        img_show = images_aug[i]

        # Si usaste cv2 para cargar, están en BGR. Matplotlib quiere RGB.
        # Hacemos el flip de canales con ::-1
        plt.imshow(img_show[:, :, ::-1])

        if i == 0:
            plt.title("Probablemente Original\n(o rotada)")
        else:
            plt.title(f"Variación {i}")
        plt.axis('off')

    plt.suptitle(f"Efecto del Data Augmentation en RAM ({sample_cat})")
    plt.show()

# --- CÓMO USARLO AHORA ---
# Importante: Pasa las variables _ram, NO la lista de objetos
visualize_ram_augmentation(X_train_ram, y_train_ram, generator_from_ram)

# %%
import math
import numpy as np

print('Training model')
epochs = 100
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_gen, steps_per_epoch=train_steps, validation_data=valid_gen, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2127 - loss: 1.5418
# Epoch 1: val_accuracy improved from -inf to 0.28053, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.2131 - loss: 1.5378 - val_accuracy: 0.2805 - val_loss: 0.7210 - learning_rate: 0.0010
# Epoch 2/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2820 - loss: 0.6786
# Epoch 2: val_accuracy improved from 0.28053 to 0.29600, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.2820 - loss: 0.6783 - val_accuracy: 0.2960 - val_loss: 0.5688 - learning_rate: 0.0010
# Epoch 3/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2950 - loss: 0.5675
# Epoch 3: val_accuracy did not improve from 0.29600
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2950 - loss: 0.5674 - val_accuracy: 0.2672 - val_loss: 0.5412 - learning_rate: 0.0010
# Epoch 4/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3059 - loss: 0.5411
# Epoch 4: val_accuracy did not improve from 0.29600
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.3059 - loss: 0.5411 - val_accuracy: 0.2741 - val_loss: 0.5210 - learning_rate: 0.0010
# Epoch 5/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3150 - loss: 0.5270
# Epoch 5: val_accuracy did not improve from 0.29600
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3150 - loss: 0.5270 - val_accuracy: 0.2779 - val_loss: 0.5169 - learning_rate: 0.0010
# Epoch 6/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3082 - loss: 0.5274
# Epoch 6: val_accuracy did not improve from 0.29600
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3082 - loss: 0.5274 - val_accuracy: 0.2800 - val_loss: 0.5226 - learning_rate: 0.0010
# Epoch 7/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3074 - loss: 0.5229
# Epoch 7: val_accuracy did not improve from 0.29600
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.3074 - loss: 0.5229 - val_accuracy: 0.2587 - val_loss: 0.5347 - learning_rate: 0.0010
# Epoch 8/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3120 - loss: 0.5180
# Epoch 8: val_accuracy did not improve from 0.29600
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3120 - loss: 0.5180 - val_accuracy: 0.2949 - val_loss: 0.5055 - learning_rate: 0.0010
# Epoch 9/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3214 - loss: 0.5133
# Epoch 9: val_accuracy did not improve from 0.29600
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3214 - loss: 0.5132 - val_accuracy: 0.2928 - val_loss: 0.5123 - learning_rate: 0.0010
# Epoch 10/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3166 - loss: 0.5095
# Epoch 10: val_accuracy did not improve from 0.29600
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.3166 - loss: 0.5095 - val_accuracy: 0.2416 - val_loss: 0.5367 - learning_rate: 0.0010
# Epoch 11/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3121 - loss: 0.5086
# Epoch 11: val_accuracy did not improve from 0.29600
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3122 - loss: 0.5085 - val_accuracy: 0.2715 - val_loss: 0.5088 - learning_rate: 0.0010
# Epoch 12/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3215 - loss: 0.5026
# Epoch 12: val_accuracy did not improve from 0.29600
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3216 - loss: 0.5025 - val_accuracy: 0.2736 - val_loss: 0.5175 - learning_rate: 0.0010
# Epoch 13/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3237 - loss: 0.5003
# Epoch 13: val_accuracy did not improve from 0.29600
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3237 - loss: 0.5003 - val_accuracy: 0.2811 - val_loss: 0.4971 - learning_rate: 0.0010
# Epoch 14/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3303 - loss: 0.4939
# Epoch 14: val_accuracy did not improve from 0.29600
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3303 - loss: 0.4939 - val_accuracy: 0.2763 - val_loss: 0.5007 - learning_rate: 0.0010
# Epoch 15/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3272 - loss: 0.4886
# Epoch 15: val_accuracy improved from 0.29600 to 0.32640, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3272 - loss: 0.4886 - val_accuracy: 0.3264 - val_loss: 0.4689 - learning_rate: 0.0010
# Epoch 16/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3246 - loss: 0.4864
# Epoch 16: val_accuracy did not improve from 0.32640
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.3246 - loss: 0.4864 - val_accuracy: 0.2933 - val_loss: 0.4868 - learning_rate: 0.0010
# Epoch 17/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3326 - loss: 0.4831
# Epoch 17: val_accuracy did not improve from 0.32640
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3326 - loss: 0.4831 - val_accuracy: 0.3115 - val_loss: 0.4730 - learning_rate: 0.0010
# Epoch 18/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3313 - loss: 0.4807
# Epoch 18: val_accuracy did not improve from 0.32640
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3313 - loss: 0.4807 - val_accuracy: 0.3104 - val_loss: 0.4731 - learning_rate: 0.0010
# Epoch 19/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3373 - loss: 0.4724
# Epoch 19: val_accuracy did not improve from 0.32640
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3373 - loss: 0.4725 - val_accuracy: 0.3104 - val_loss: 0.4715 - learning_rate: 0.0010
# Epoch 20/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3320 - loss: 0.4770
# Epoch 20: val_accuracy did not improve from 0.32640
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3320 - loss: 0.4769 - val_accuracy: 0.3072 - val_loss: 0.4750 - learning_rate: 0.0010
# Epoch 21/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3605 - loss: 0.4437
# Epoch 21: val_accuracy improved from 0.32640 to 0.36053, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.3606 - loss: 0.4437 - val_accuracy: 0.3605 - val_loss: 0.4195 - learning_rate: 2.0000e-04
# Epoch 22/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3794 - loss: 0.4192
# Epoch 22: val_accuracy did not improve from 0.36053
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3794 - loss: 0.4192 - val_accuracy: 0.3397 - val_loss: 0.4161 - learning_rate: 2.0000e-04
# Epoch 23/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3823 - loss: 0.4161
# Epoch 23: val_accuracy did not improve from 0.36053
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3824 - loss: 0.4160 - val_accuracy: 0.3595 - val_loss: 0.4018 - learning_rate: 2.0000e-04
# Epoch 24/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3879 - loss: 0.4108
# Epoch 24: val_accuracy improved from 0.36053 to 0.38880, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.3879 - loss: 0.4108 - val_accuracy: 0.3888 - val_loss: 0.3941 - learning_rate: 2.0000e-04
# Epoch 25/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3982 - loss: 0.4036
# Epoch 25: val_accuracy did not improve from 0.38880
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3981 - loss: 0.4036 - val_accuracy: 0.3829 - val_loss: 0.3985 - learning_rate: 2.0000e-04
# Epoch 26/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3968 - loss: 0.4060
# Epoch 26: val_accuracy did not improve from 0.38880
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3968 - loss: 0.4059 - val_accuracy: 0.3835 - val_loss: 0.3975 - learning_rate: 2.0000e-04
# Epoch 27/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4007 - loss: 0.4026
# Epoch 27: val_accuracy improved from 0.38880 to 0.39840, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4007 - loss: 0.4025 - val_accuracy: 0.3984 - val_loss: 0.3924 - learning_rate: 2.0000e-04
# Epoch 28/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4082 - loss: 0.4006
# Epoch 28: val_accuracy improved from 0.39840 to 0.39947, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.4082 - loss: 0.4006 - val_accuracy: 0.3995 - val_loss: 0.3896 - learning_rate: 2.0000e-04
# Epoch 29/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4025 - loss: 0.3980
# Epoch 29: val_accuracy improved from 0.39947 to 0.40000, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4025 - loss: 0.3980 - val_accuracy: 0.4000 - val_loss: 0.3883 - learning_rate: 2.0000e-04
# Epoch 30/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4158 - loss: 0.3943
# Epoch 30: val_accuracy improved from 0.40000 to 0.42080, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4157 - loss: 0.3943 - val_accuracy: 0.4208 - val_loss: 0.3859 - learning_rate: 2.0000e-04
# Epoch 31/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4141 - loss: 0.3954
# Epoch 31: val_accuracy did not improve from 0.42080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4141 - loss: 0.3954 - val_accuracy: 0.3888 - val_loss: 0.3887 - learning_rate: 2.0000e-04
# Epoch 32/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4198 - loss: 0.3934
# Epoch 32: val_accuracy did not improve from 0.42080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.4197 - loss: 0.3934 - val_accuracy: 0.4075 - val_loss: 0.3853 - learning_rate: 2.0000e-04
# Epoch 33/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4122 - loss: 0.3935
# Epoch 33: val_accuracy did not improve from 0.42080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4123 - loss: 0.3935 - val_accuracy: 0.3909 - val_loss: 0.3970 - learning_rate: 2.0000e-04
# Epoch 34/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4287 - loss: 0.3871
# Epoch 34: val_accuracy did not improve from 0.42080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.4287 - loss: 0.3871 - val_accuracy: 0.3851 - val_loss: 0.3909 - learning_rate: 2.0000e-04
# Epoch 35/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4249 - loss: 0.3882
# Epoch 35: val_accuracy did not improve from 0.42080
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4249 - loss: 0.3882 - val_accuracy: 0.4069 - val_loss: 0.3876 - learning_rate: 2.0000e-04
# Epoch 36/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4305 - loss: 0.3827
# Epoch 36: val_accuracy improved from 0.42080 to 0.43573, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4306 - loss: 0.3827 - val_accuracy: 0.4357 - val_loss: 0.3697 - learning_rate: 4.0000e-05
# Epoch 37/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4638 - loss: 0.3672
# Epoch 37: val_accuracy improved from 0.43573 to 0.43947, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4638 - loss: 0.3672 - val_accuracy: 0.4395 - val_loss: 0.3631 - learning_rate: 4.0000e-05
# Epoch 38/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4539 - loss: 0.3680
# Epoch 38: val_accuracy improved from 0.43947 to 0.45280, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4539 - loss: 0.3680 - val_accuracy: 0.4528 - val_loss: 0.3575 - learning_rate: 4.0000e-05
# Epoch 39/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4556 - loss: 0.3656
# Epoch 39: val_accuracy did not improve from 0.45280
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.4556 - loss: 0.3656 - val_accuracy: 0.4491 - val_loss: 0.3567 - learning_rate: 4.0000e-05
# Epoch 40/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4519 - loss: 0.3659
# Epoch 40: val_accuracy improved from 0.45280 to 0.46027, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4519 - loss: 0.3659 - val_accuracy: 0.4603 - val_loss: 0.3518 - learning_rate: 4.0000e-05
# Epoch 41/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4599 - loss: 0.3594
# Epoch 41: val_accuracy did not improve from 0.46027
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4599 - loss: 0.3594 - val_accuracy: 0.4571 - val_loss: 0.3544 - learning_rate: 4.0000e-05
# Epoch 42/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4600 - loss: 0.3601
# Epoch 42: val_accuracy improved from 0.46027 to 0.46347, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4600 - loss: 0.3601 - val_accuracy: 0.4635 - val_loss: 0.3516 - learning_rate: 4.0000e-05
# Epoch 43/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4573 - loss: 0.3574
# Epoch 43: val_accuracy did not improve from 0.46347
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4573 - loss: 0.3574 - val_accuracy: 0.4560 - val_loss: 0.3521 - learning_rate: 4.0000e-05
# Epoch 44/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4637 - loss: 0.3571
# Epoch 44: val_accuracy did not improve from 0.46347
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4637 - loss: 0.3571 - val_accuracy: 0.4501 - val_loss: 0.3507 - learning_rate: 4.0000e-05
# Epoch 45/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4599 - loss: 0.3573
# Epoch 45: val_accuracy did not improve from 0.46347
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.4599 - loss: 0.3573 - val_accuracy: 0.4560 - val_loss: 0.3526 - learning_rate: 4.0000e-05
# Epoch 46/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4721 - loss: 0.3535
# Epoch 46: val_accuracy did not improve from 0.46347
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4721 - loss: 0.3535 - val_accuracy: 0.4555 - val_loss: 0.3484 - learning_rate: 4.0000e-05
# Epoch 47/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4652 - loss: 0.3519
# Epoch 47: val_accuracy did not improve from 0.46347
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.4652 - loss: 0.3519 - val_accuracy: 0.4635 - val_loss: 0.3473 - learning_rate: 4.0000e-05
# Epoch 48/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4792 - loss: 0.3502
# Epoch 48: val_accuracy did not improve from 0.46347
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4792 - loss: 0.3502 - val_accuracy: 0.4597 - val_loss: 0.3459 - learning_rate: 4.0000e-05
# Epoch 49/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4701 - loss: 0.3542
# Epoch 49: val_accuracy did not improve from 0.46347
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4700 - loss: 0.3542 - val_accuracy: 0.4421 - val_loss: 0.3509 - learning_rate: 4.0000e-05
# Epoch 50/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4678 - loss: 0.3546
# Epoch 50: val_accuracy did not improve from 0.46347
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4678 - loss: 0.3546 - val_accuracy: 0.4581 - val_loss: 0.3438 - learning_rate: 4.0000e-05
# Epoch 51/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4783 - loss: 0.3473
# Epoch 51: val_accuracy improved from 0.46347 to 0.47360, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4783 - loss: 0.3473 - val_accuracy: 0.4736 - val_loss: 0.3426 - learning_rate: 4.0000e-05
# Epoch 52/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4630 - loss: 0.3531
# Epoch 52: val_accuracy did not improve from 0.47360
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4631 - loss: 0.3531 - val_accuracy: 0.4619 - val_loss: 0.3406 - learning_rate: 4.0000e-05
# Epoch 53/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4788 - loss: 0.3478
# Epoch 53: val_accuracy did not improve from 0.47360
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4788 - loss: 0.3478 - val_accuracy: 0.4677 - val_loss: 0.3412 - learning_rate: 4.0000e-05
# Epoch 54/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4762 - loss: 0.3487
# Epoch 54: val_accuracy improved from 0.47360 to 0.48160, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4762 - loss: 0.3487 - val_accuracy: 0.4816 - val_loss: 0.3378 - learning_rate: 4.0000e-05
# Epoch 55/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4807 - loss: 0.3462
# Epoch 55: val_accuracy did not improve from 0.48160
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4807 - loss: 0.3462 - val_accuracy: 0.4731 - val_loss: 0.3360 - learning_rate: 4.0000e-05
# Epoch 56/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4797 - loss: 0.3469
# Epoch 56: val_accuracy did not improve from 0.48160
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4797 - loss: 0.3469 - val_accuracy: 0.4741 - val_loss: 0.3385 - learning_rate: 4.0000e-05
# Epoch 57/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4816 - loss: 0.3457
# Epoch 57: val_accuracy improved from 0.48160 to 0.50027, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4816 - loss: 0.3457 - val_accuracy: 0.5003 - val_loss: 0.3311 - learning_rate: 4.0000e-05
# Epoch 58/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4841 - loss: 0.3461
# Epoch 58: val_accuracy did not improve from 0.50027
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4840 - loss: 0.3461 - val_accuracy: 0.4848 - val_loss: 0.3323 - learning_rate: 4.0000e-05
# Epoch 59/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4876 - loss: 0.3427
# Epoch 59: val_accuracy did not improve from 0.50027
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4876 - loss: 0.3427 - val_accuracy: 0.4933 - val_loss: 0.3275 - learning_rate: 4.0000e-05
# Epoch 60/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4826 - loss: 0.3438
# Epoch 60: val_accuracy did not improve from 0.50027
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4827 - loss: 0.3438 - val_accuracy: 0.4619 - val_loss: 0.3373 - learning_rate: 4.0000e-05
# Epoch 61/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4890 - loss: 0.3411
# Epoch 61: val_accuracy did not improve from 0.50027
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4889 - loss: 0.3412 - val_accuracy: 0.4656 - val_loss: 0.3413 - learning_rate: 4.0000e-05
# Epoch 62/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4769 - loss: 0.3457
# Epoch 62: val_accuracy did not improve from 0.50027
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4769 - loss: 0.3457 - val_accuracy: 0.4987 - val_loss: 0.3298 - learning_rate: 4.0000e-05
# Epoch 63/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4808 - loss: 0.3398
# Epoch 63: val_accuracy did not improve from 0.50027
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4809 - loss: 0.3398 - val_accuracy: 0.4875 - val_loss: 0.3289 - learning_rate: 4.0000e-05
# Epoch 64/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4797 - loss: 0.3434
# Epoch 64: val_accuracy did not improve from 0.50027
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4798 - loss: 0.3434 - val_accuracy: 0.4901 - val_loss: 0.3282 - learning_rate: 4.0000e-05
# Epoch 65/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4955 - loss: 0.3359
# Epoch 65: val_accuracy did not improve from 0.50027
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4956 - loss: 0.3359 - val_accuracy: 0.4896 - val_loss: 0.3277 - learning_rate: 8.0000e-06
# Epoch 66/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5029 - loss: 0.3345
# Epoch 66: val_accuracy did not improve from 0.50027
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5029 - loss: 0.3345 - val_accuracy: 0.4928 - val_loss: 0.3244 - learning_rate: 8.0000e-06
# Epoch 67/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4989 - loss: 0.3350
# Epoch 67: val_accuracy improved from 0.50027 to 0.50933, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.4989 - loss: 0.3350 - val_accuracy: 0.5093 - val_loss: 0.3218 - learning_rate: 8.0000e-06
# Epoch 68/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5074 - loss: 0.3300
# Epoch 68: val_accuracy did not improve from 0.50933
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5074 - loss: 0.3300 - val_accuracy: 0.4971 - val_loss: 0.3246 - learning_rate: 8.0000e-06
# Epoch 69/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5026 - loss: 0.3338
# Epoch 69: val_accuracy did not improve from 0.50933
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5027 - loss: 0.3338 - val_accuracy: 0.4923 - val_loss: 0.3252 - learning_rate: 8.0000e-06
# Epoch 70/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5046 - loss: 0.3312
# Epoch 70: val_accuracy did not improve from 0.50933
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5046 - loss: 0.3312 - val_accuracy: 0.5024 - val_loss: 0.3211 - learning_rate: 8.0000e-06
# Epoch 71/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5109 - loss: 0.3285
# Epoch 71: val_accuracy did not improve from 0.50933
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5109 - loss: 0.3285 - val_accuracy: 0.5045 - val_loss: 0.3191 - learning_rate: 8.0000e-06
# Epoch 72/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5080 - loss: 0.3278
# Epoch 72: val_accuracy did not improve from 0.50933
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5080 - loss: 0.3278 - val_accuracy: 0.5045 - val_loss: 0.3200 - learning_rate: 8.0000e-06
# Epoch 73/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5177 - loss: 0.3264
# Epoch 73: val_accuracy did not improve from 0.50933
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5177 - loss: 0.3264 - val_accuracy: 0.5072 - val_loss: 0.3193 - learning_rate: 8.0000e-06
# Epoch 74/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5068 - loss: 0.3305
# Epoch 74: val_accuracy did not improve from 0.50933
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5067 - loss: 0.3305 - val_accuracy: 0.4955 - val_loss: 0.3208 - learning_rate: 8.0000e-06
# Epoch 75/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5141 - loss: 0.3277
# Epoch 75: val_accuracy did not improve from 0.50933
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5141 - loss: 0.3277 - val_accuracy: 0.5013 - val_loss: 0.3198 - learning_rate: 8.0000e-06
# Epoch 76/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5016 - loss: 0.3290
# Epoch 76: val_accuracy did not improve from 0.50933
#
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5016 - loss: 0.3290 - val_accuracy: 0.5035 - val_loss: 0.3217 - learning_rate: 8.0000e-06
# Epoch 77/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5181 - loss: 0.3249
# Epoch 77: val_accuracy did not improve from 0.50933
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5181 - loss: 0.3249 - val_accuracy: 0.5067 - val_loss: 0.3172 - learning_rate: 1.6000e-06
# Epoch 78/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5093 - loss: 0.3269
# Epoch 78: val_accuracy improved from 0.50933 to 0.50987, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5093 - loss: 0.3269 - val_accuracy: 0.5099 - val_loss: 0.3164 - learning_rate: 1.6000e-06
# Epoch 79/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5096 - loss: 0.3257
# Epoch 79: val_accuracy improved from 0.50987 to 0.51040, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5097 - loss: 0.3257 - val_accuracy: 0.5104 - val_loss: 0.3169 - learning_rate: 1.6000e-06
# Epoch 80/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5103 - loss: 0.3272
# Epoch 80: val_accuracy did not improve from 0.51040
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5103 - loss: 0.3272 - val_accuracy: 0.5056 - val_loss: 0.3187 - learning_rate: 1.6000e-06
# Epoch 81/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5109 - loss: 0.3270
# Epoch 81: val_accuracy did not improve from 0.51040
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5109 - loss: 0.3270 - val_accuracy: 0.5088 - val_loss: 0.3186 - learning_rate: 1.6000e-06
# Epoch 82/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5208 - loss: 0.3239
# Epoch 82: val_accuracy did not improve from 0.51040
#
# Epoch 82: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5208 - loss: 0.3239 - val_accuracy: 0.5061 - val_loss: 0.3181 - learning_rate: 1.6000e-06
# Epoch 83/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5193 - loss: 0.3241
# Epoch 83: val_accuracy did not improve from 0.51040
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5192 - loss: 0.3241 - val_accuracy: 0.5088 - val_loss: 0.3192 - learning_rate: 3.2000e-07
# Epoch 84/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5150 - loss: 0.3247
# Epoch 84: val_accuracy did not improve from 0.51040
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.5150 - loss: 0.3247 - val_accuracy: 0.5067 - val_loss: 0.3183 - learning_rate: 3.2000e-07
# Epoch 85/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5146 - loss: 0.3266
# Epoch 85: val_accuracy did not improve from 0.51040
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5145 - loss: 0.3266 - val_accuracy: 0.5093 - val_loss: 0.3186 - learning_rate: 3.2000e-07
# Epoch 86/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5142 - loss: 0.3272
# Epoch 86: val_accuracy did not improve from 0.51040
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5142 - loss: 0.3272 - val_accuracy: 0.5104 - val_loss: 0.3181 - learning_rate: 3.2000e-07
# Epoch 87/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5110 - loss: 0.3264
# Epoch 87: val_accuracy did not improve from 0.51040
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5110 - loss: 0.3264 - val_accuracy: 0.5056 - val_loss: 0.3183 - learning_rate: 3.2000e-07
# Epoch 88/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5182 - loss: 0.3236
# Epoch 88: val_accuracy did not improve from 0.51040
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5182 - loss: 0.3236 - val_accuracy: 0.5024 - val_loss: 0.3199 - learning_rate: 6.4000e-08
# Epoch 89/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5175 - loss: 0.3249
# Epoch 89: val_accuracy did not improve from 0.51040
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.5175 - loss: 0.3249 - val_accuracy: 0.5093 - val_loss: 0.3178 - learning_rate: 6.4000e-08
# Epoch 90/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5141 - loss: 0.3258
# Epoch 90: val_accuracy did not improve from 0.51040
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5141 - loss: 0.3258 - val_accuracy: 0.5056 - val_loss: 0.3186 - learning_rate: 6.4000e-08
# Epoch 91/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5191 - loss: 0.3233
# Epoch 91: val_accuracy did not improve from 0.51040
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5191 - loss: 0.3233 - val_accuracy: 0.5040 - val_loss: 0.3186 - learning_rate: 6.4000e-08
# Epoch 92/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5112 - loss: 0.3263
# Epoch 92: val_accuracy did not improve from 0.51040
#
# Epoch 92: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5112 - loss: 0.3263 - val_accuracy: 0.5024 - val_loss: 0.3187 - learning_rate: 6.4000e-08
# Epoch 93/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5126 - loss: 0.3247
# Epoch 93: val_accuracy did not improve from 0.51040
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5126 - loss: 0.3247 - val_accuracy: 0.5077 - val_loss: 0.3183 - learning_rate: 1.2800e-08
# Epoch 94/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5220 - loss: 0.3228
# Epoch 94: val_accuracy did not improve from 0.51040
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5220 - loss: 0.3228 - val_accuracy: 0.5083 - val_loss: 0.3178 - learning_rate: 1.2800e-08
# Epoch 94: early stopping
# Restoring model weights from the end of the best epoch: 79.
# Best validation model: epoch 79  - val_accuracy 0.5103999972343445

# %%
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(16, 5))

    # Gráfica de Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training acc')
    plt.plot(epochs, val_acc, 'ro-', label='Validation acc')
    plt.title('Accuracy: Train vs Validation')
    plt.legend()
    plt.grid(True)

    # Gráfica de Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
    plt.title('Loss: Train vs Validation')
    plt.legend()
    plt.grid(True)

    plt.show()

# USARLO:
plot_history(h)

# %%
from sklearn.metrics import classification_report
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

def plot_classification_report(model, valid_gen, steps):
    print("Generando predicciones... esto puede tardar unos segundos.")

    # 1. Predecir
    y_pred = model.predict(valid_gen, steps=steps, verbose=1)
    y_pred_classes = np.argmax(y_pred, axis=1) # Convierte [0.1, 0.9, 0] -> 1

    # 2. Etiquetas reales (CORREGIDO)
    # Como y_valid_ram tiene textos ('Helipad'), hay que pasarlos a números (0, 1, 2...)
    # Usamos el orden de 'categories' para saber qué número es cada texto.
    class_names = list(categories.values()) # ['Cargo plane', 'Small car', ...]

    # Mapeamos cada texto de la RAM a su número
    y_true = np.array([class_names.index(cat) for cat in y_valid_ram])

    # AJUSTE VITAL:
    # Al usar steps = len // batch_size, es posible que 'y_pred' sea un poco más corto
    # que 'y_true' (porque se descarta el último batch incompleto).
    # Cortamos y_true para que tenga la misma longitud exacta que y_pred.
    y_true = y_true[:len(y_pred_classes)]

    # 3. Reporte
    report = classification_report(
        y_true,
        y_pred_classes,
        target_names=class_names,
        output_dict=True,
        zero_division=0 # Evita errores si alguna clase no se predice nunca
    )

    # Convertimos a DataFrame y limpiamos
    df = pd.DataFrame(report).transpose()
    df = df.drop(['accuracy', 'macro avg', 'weighted avg'])

    # 4. Heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(df.iloc[:, :3], annot=True, cmap='RdYlGn', fmt='.2f', vmin=0, vmax=1)
    plt.title('Boletín de Notas: Precision vs Recall')
    plt.show()

# USARLO:
# Asegúrate de pasar el BATCH_SIZE correcto (el mismo que usaste en valid_gen)
plot_classification_report(model, valid_gen, len(X_valid_ram)//batch_size)
# Out:
# Generando predicciones... esto puede tardar unos segundos.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt

def visualize_errors(model, X_data, y_data):
    print("Analizando errores... (Prediciendo todo el set)")

    # 1. Predecir todo
    # Normalizamos al vuelo (/255.0) porque en RAM están como uint8
    preds = model.predict(X_data.astype('float32') / 255.0, verbose=0)

    # Obtenemos la clase predicha (Número)
    pred_classes = np.argmax(preds, axis=1)

    # 2. Obtener la clase real (CORRECCIÓN AQUÍ)
    # Como y_data son textos ('Helipad'), los convertimos a números
    class_names = list(categories.values()) # ['Cargo plane', 'Small car', ...]

    # Mapeamos: 'Helipad' -> 9 (o el número que sea)
    true_classes = np.array([class_names.index(cat) for cat in y_data])

    # 3. Buscar discrepancias
    errors = np.where(pred_classes != true_classes)[0]
    print(f"Total de errores: {len(errors)} de {len(X_data)} ({(len(errors)/len(X_data))*100:.2f}%)")

    # Si no hay errores, salimos
    if len(errors) == 0:
        print("¡Increíble! 0 errores encontrados.")
        return

    # 4. Mostrar 10 errores aleatorios
    # Si hay menos de 10 errores, los mostramos todos
    n_show = min(10, len(errors))
    indices_to_show = np.random.choice(errors, size=n_show, replace=False)

    plt.figure(figsize=(20, 8))
    for i, idx in enumerate(indices_to_show):
        plt.subplot(2, 5, i+1)

        # Imagen (Original de RAM)
        img = X_data[idx]

        # Si usas OpenCV, recuerda que carga en BGR, matplotlib quiere RGB
        # Si ves los colores raros (azul en vez de rojo), descomenta la linea de abajo:
        # img = img[:, :, ::-1]
        plt.imshow(img)

        # Etiquetas
        true_label = class_names[true_classes[idx]]
        pred_label = class_names[pred_classes[idx]]

        # Confianza: ¿Cómo de seguro estaba el modelo de su error?
        conf = np.max(preds[idx]) * 100

        # T = Truth (Verdad), P = Prediction (Predicción)
        plt.title(f"Real: {true_label}\nPred: {pred_label}\nConf: {conf:.1f}%", color='red', fontsize=10)
        plt.axis('off')

    plt.suptitle("Galería de los Horrores: Errores del Modelo", fontsize=16)
    plt.tight_layout()
    plt.show()

# USARLO:
visualize_errors(model, X_valid_ram, y_valid_ram)
# Out:
# Analizando errores... (Prediciendo todo el set)
# Total de errores: 919 de 1875 (49.01%)

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
# 1. Usamos los datos que YA cargamos en RAM (Velocidad: 100x más rápido)
# model.predict procesa todo el bloque de golpe (Batch processing)
print("Prediciendo todo el validación de golpe...")
predictions = model.predict(X_valid_ram.astype('float32') / 255.0, batch_size=32, verbose=1)

# 2. Sacamos la clase ganadora de cada foto
y_pred_indices = np.argmax(predictions, axis=1) # [0, 5, 2...]

# 3. Convertimos números a nombres (si lo necesitas en texto)
class_names = list(categories.values())
y_pred = [class_names[i] for i in y_pred_indices]

# 4. Sacamos el y_true (La realidad)
# Si y_valid_ram era texto:
y_true = y_valid_ram
# Si y_valid_ram era One-Hot o índices, adáptalo.
# Asumiendo que es la lista de textos que devolvía load_dataset_to_ram:
# (Si usaste mi última función, y_valid_ram es una lista de strings ['Helipad', 'Car'...])
# Out:
# Prediciendo todo el validación de golpe...
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 50.987%
# Mean Recall: 52.627%
# Mean Precision: 49.231%
# > Cargo plane: Recall: 79.661% Precision: 74.603% Specificity: 99.119% Dice: 77.049%
# > Small car: Recall: 77.508% Precision: 65.722% Specificity: 91.397% Dice: 71.130%
# > Bus: Recall: 47.126% Precision: 51.572% Specificity: 95.473% Dice: 49.249%
# > Truck: Recall: 9.544% Precision: 37.097% Specificity: 97.613% Dice: 15.182%
# > Motorboat: Recall: 50.459% Precision: 36.184% Specificity: 94.507% Dice: 42.146%
# > Fishing vessel: Recall: 64.384% Precision: 29.936% Specificity: 93.896% Dice: 40.870%
# > Dump truck: Recall: 36.441% Precision: 51.807% Specificity: 97.723% Dice: 42.786%
# > Excavator: Recall: 74.074% Precision: 41.096% Specificity: 95.206% Dice: 52.863%
# > Building: Recall: 64.463% Precision: 59.542% Specificity: 89.484% Dice: 61.905%
# > Helipad: Recall: 44.444% Precision: 44.444% Specificity: 99.732% Dice: 44.444%
# > Storage tank: Recall: 16.447% Precision: 80.645% Specificity: 99.652% Dice: 27.322%
# > Shipping container: Recall: 41.481% Precision: 38.621% Specificity: 94.885% Dice: 40.000%
# > Pylon: Recall: 78.125% Precision: 28.736% Specificity: 96.636% Dice: 42.017%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('../content/dataset/xview_recognition/xview_test'):
    for filename in filenames:
        image = GenericImage(dirpath[29:] + '/' + filename)
        image.tile = np.array([0, 0, 64, 64])
        obj = GenericObject()
        obj.bb = (0, 0, 64, 64)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np
import tensorflow as tf

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}

for idx, ann in enumerate(anns):
    image_data = {
        "image_id": ann.filename.split('/')[-1],
        "filename": ann.filename,
        "width": int(ann.tile[2]),
        "height": int(ann.tile[3])
    }
    predictions_data["images"][idx] = image_data

    # 1. Cargar imagen original
    # Fix: Remove 'gnition/' from the filename path which was incorrectly added
    try:
        image = load_geoimage(ann.filename[8:]) / 255.0
    except Exception as e:
        print(f"Error al cargar la ruta {ann.filename[8:]}. Saltando...")
        continue

    # --- FIX CRÍTICO: Comprobar que la imagen existe y redimensionar a 64x64 ---
    if image is None or image.size == 0:
        print(f"Advertencia: La imagen {ann.filename[8:]} se cargó vacía.")
        continue

    # Redimensionamos explícitamente al input_shape que espera nuestro modelo
    image_resized = tf.image.resize(image, (64, 64)).numpy()

    for obj_pred in ann.objects:
        # Generate prediction usando la imagen redimensionada
        warped_image = np.expand_dims(image_resized, 0)
        predictions = model.predict(warped_image, verbose=0)

        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = float(np.max(predictions)) # Casteado a float estándar de Python para evitar fallos en JSON

        annotation_data = {
            "image_id": ann.filename.split('/')[-1],
            "category_id": pred_category,
            "bbox": [int(x) for x in obj_pred.bb]
        }
        predictions_data["annotations"][idx] = annotation_data

print("Predicciones finalizadas correctamente.")
# Out:
# Predicciones finalizadas correctamente.

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)
