# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Yousef Medhat
# - Alumno 2: Carlos Manzano Izquierdo
# - Alumno 3: Guillermo Bermejo Babiano
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-25949/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      94     reply = _read_next_input_message()
#      95     if reply == _NOT_READY or not isinstance(reply, dict):
# ---> 96       time.sleep(0.025)
#      97       continue
#      98     if (
#
# KeyboardInterrupt:

# %%
# The -q flag means "quiet" so it doesn't print 10,000 lines and crash your browser
# !unzip -q "/content/drive/MyDrive/DL/xview_recognition.zip" -d "/content/dataset"

print("✅ Unzipping complete!")
# Out:
# ✅ Unzipping complete!

# %%
data_dir = '/content/dataset/xview_recognition' # Or whatever the extracted folder is named

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open('../content/dataset/xview_recognition/'+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json

# Load database
json_file = '../content/dataset/xview_recognition/xview_ann_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 16871
# Number of validation images: 1875

# %%
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L2
from tensorflow.keras.activations import swish

print('Load model')
model = Sequential()
model.add(Flatten(input_shape=(224, 224, 3)))

model.add(Dense(1024, kernel_initializer='he_normal'))
model.add(Activation('swish'))

model.add(Dense(len(categories)))
model.add(Activation('softmax'))
model.summary()
# Out:
# Load model
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 150528)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │   154,141,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 13)             │        13,325 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 13)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 154,155,021 (588.05 MB)
#  Trainable params: 154,155,021 (588.05 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import CategoricalFocalCrossentropy

focal_loss = CategoricalFocalCrossentropy(
    gamma=2.0,        # Fuerza el enfoque en lo difícil
    alpha=0.25,       # Balancea la importancia general
    label_smoothing=0.1,  # Label smoothing para overfitting
    from_logits=False # False porque usamos Softmax al final
)

# Learning rate is changed to 0.005
opt = SGD(
    learning_rate=0.005,
    momentum=0.9,
    nesterov=True,
    clipnorm=1.0
)
model.compile(optimizer=opt, loss=focal_loss, metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_delta=0.001,
    cooldown=1,
    min_lr=1e-6,
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
def generator_from_ram(X_data, y_data, batch_size, do_shuffle=False, do_augment=False):
    # Índices para saber qué foto toca
    indices = np.arange(len(X_data))

    while True:
        if do_shuffle:
            np.random.shuffle(indices)

        # Troceamos los índices en batches
        for i in range(0, len(indices), batch_size):
            batch_indices = indices[i:i+batch_size]

            # Cogemos las imágenes crudas de la RAM
            batch_images_raw = X_data[batch_indices]
            batch_cats = y_data[batch_indices]

            images, labels = [], []

            for j in range(len(batch_images_raw)):
                # Copiamos la imagen para no modificar la original en RAM
                img = batch_images_raw[j].copy()
                cat = batch_cats[j]

                # ==========================================
                # AUGMENTATION "SAFE MODE" (Solo Brillo y Giros)
                # ==========================================
                if do_augment:
                    # 1. ROTACIÓN (90, 180, 270)
                    k = np.random.randint(0, 4)
                    if k > 0: img = np.rot90(img, k)

                    # 2. FLIP (Espejo)
                    if np.random.rand() > 0.5:
                        code = np.random.choice([0, 1])
                        img = cv2.flip(img, code)

                    # 3. BRILLO/CONTRASTE (Sin Traslación)
                    # Lo aplicamos el 80% de las veces para dar variedad de color
                    if np.random.rand() > 0.2:
                        alpha = np.random.uniform(0.8, 1.2) # Contraste
                        beta = np.random.uniform(-25, 25)   # Brillo
                        img = cv2.convertScaleAbs(img, alpha=alpha, beta=beta)
                # ==========================================

                # Normalización (Aquí pasamos a float)
                img_float = img.astype(np.float32) / 255.0

                # One-Hot Encoding
                prob = np.zeros(len(categories))
                prob[list(categories.values()).index(cat)] = 1

                images.append(img_float)
                labels.append(prob)

            yield np.array(images), np.array(labels)

# %%
import numpy as np
import cv2
from tqdm import tqdm  # Barra de progreso

def load_dataset_to_ram(objs_list, target_size=(224, 224)):
    print(f"Cargando {len(objs_list)} imágenes en RAM... ")

    X_data = []
    y_labels = []

    for filename, obj in tqdm(objs_list):
        # 1. Cargar
        img = load_geoimage(filename)

        # 2. Redimensionar siempre a 224x224
        # (Es vital para poder apilarlas en un array de Numpy)
        if img.shape[:2] != target_size:
            img = cv2.resize(img, target_size, interpolation=cv2.INTER_AREA)

        # 3. Guardar tal cual (uint8, 0-255).
        # NO dividas por 255 aquí o ocuparás 4 veces más RAM.
        X_data.append(img)
        y_labels.append(obj.category)

    # Convertir a Bloque Numpy
    X_data = np.array(X_data, dtype='uint8')
    y_labels = np.array(y_labels)

    print(f"¡Carga lista! Ocupa en RAM: {X_data.nbytes / 1024 / 1024:.2f} MB")
    return X_data, y_labels

# %%
def balance_dataset_list(objs):
    # 1. Contamos cuántos hay de cada clase originalmente
    counts = {}
    for _, obj in objs:
        c = obj.category
        counts[c] = counts.get(c, 0) + 1

    print("--- CONTEO ORIGINAL ---")
    print(counts)

    balanced_objs = []

    # CONFIGURACIÓN DE OBJETIVOS
    TARGET_STANDARD = 2000  # Objetivo para la mayoría (Pylons, Barcos, Camiones...)
    TARGET_TINY = 1000      # Objetivo conservador para las muy pequeñas (Helipuertos)
    TINY_THRESHOLD = 200    # Si tiene menos de 200, usamos el objetivo 'Tiny'

    for filename, obj in objs:
        # Siempre añadimos la imagen original
        balanced_objs.append((filename, obj))

        current_count = counts[obj.category]

        # Determinamos el objetivo según el tamaño de la clase
        if current_count < TINY_THRESHOLD:
            target = TARGET_TINY  # Caso Helipuertos (111 -> ~1000)
        else:
            target = TARGET_STANDARD # Caso Pylons/Trucks (300 -> ~2000)

        # Si estamos por debajo del objetivo, calculamos copias
        if current_count < target:
            # Ejemplo Pylon (312): 2000 / 312 = 6.4 -> Multiplicador 6 (Total 7 copias)
            # Ejemplo Helipuerto (111): 1000 / 111 = 9.0 -> Multiplicador 9 (Total 10 copias)
            # Restamos 1 porque ya añadimos la original arriba
            multiplier = int(target / current_count) - 1

            # Solo añadimos si el multiplicador es positivo
            if multiplier > 0:
                for _ in range(multiplier):
                    balanced_objs.append((filename, obj))

    print(f"\n--- DATASET BALANCEADO ---")
    print(f"De {len(objs)} imágenes pasamos a {len(balanced_objs)} imágenes virtuales.")

    return balanced_objs

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]

# PASO 1: Balanceo de clases
print("--- FASE 1: Balanceo ---")
objs_train_balanced = balance_dataset_list(objs_train)


# PASO 2: Cargar todo en RAM
# -------------------------------------------------------
print("\n--- FASE 2: Carga en RAM ---")
# Train con lista inflada
X_train_ram, y_train_ram = load_dataset_to_ram(objs_train_balanced)
# Valid con lista normal
X_valid_ram, y_valid_ram = load_dataset_to_ram(objs_valid)

# PASO 3: Crear Generadores Rápidos
# -------------------------------------------------------
batch_size = 32

train_gen = generator_from_ram(
    X_train_ram, y_train_ram,
    batch_size=batch_size,
    do_shuffle=True,
    do_augment=True
)

valid_gen = generator_from_ram(
    X_valid_ram, y_valid_ram,
    batch_size=batch_size,
    do_shuffle=False,
    do_augment=False
)
# Out:
# --- FASE 1: Balanceo ---
# --- CONTEO ORIGINAL ---
# {'Bus': 1594, 'Cargo plane': 576, 'Truck': 1969, 'Building': 3231, 'Fishing vessel': 633, 'Small car': 2995, 'Pylon': 280, 'Shipping container': 1388, 'Dump truck': 1118, 'Motorboat': 960, 'Storage tank': 1317, 'Excavator': 708, 'Helipad': 102}
#
# --- DATASET BALANCEADO ---
# De 16871 imágenes pasamos a 23453 imágenes virtuales.
#
# --- FASE 2: Carga en RAM ---
# Cargando 23453 imágenes en RAM...
# 100%|██████████| 23453/23453 [01:14<00:00, 313.54it/s]
# ¡Carga lista! Ocupa en RAM: 3366.79 MB
# Cargando 1875 imágenes en RAM...
# 100%|██████████| 1875/1875 [00:05<00:00, 345.36it/s]
# ¡Carga lista! Ocupa en RAM: 269.17 MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_class_balance(original_objs, balanced_objs):
    # 1. Contar Originales
    counts_orig = {}
    for _, obj in original_objs:
        counts_orig[obj.category] = counts_orig.get(obj.category, 0) + 1

    # 2. Contar Balanceados
    counts_bal = {}
    for _, obj in balanced_objs:
        counts_bal[obj.category] = counts_bal.get(obj.category, 0) + 1

    # Preparar datos para plot
    classes = list(counts_orig.keys())
    # Ordenamos por cantidad original para que quede bonito
    classes.sort(key=lambda x: counts_orig[x], reverse=True)

    vals_orig = [counts_orig[c] for c in classes]
    vals_bal = [counts_bal[c] for c in classes]

    x = range(len(classes))
    width = 0.35

    plt.figure(figsize=(15, 6))
    plt.bar([i - width/2 for i in x], vals_orig, width, label='Original', color='red', alpha=0.6)
    plt.bar([i + width/2 for i in x], vals_bal, width, label='Balanceado (Virtual)', color='green', alpha=0.6)

    plt.xticks(x, classes, rotation=45, ha='right')
    plt.ylabel('Número de Imágenes')
    plt.title('Impacto del Oversampling en el Dataset')
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# USARLO:
plot_class_balance(objs_train, objs_train_balanced)

# %%
import math
import numpy as np

print('Training model')
epochs = 100
train_steps = math.ceil(len(objs_train_balanced)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_gen, steps_per_epoch=train_steps, validation_data=valid_gen, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2688 - loss: 0.4607
# Epoch 1: val_accuracy improved from -inf to 0.35840, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 67s 86ms/step - accuracy: 0.2689 - loss: 0.4606 - val_accuracy: 0.3584 - val_loss: 0.4113 - learning_rate: 0.0050
# Epoch 2/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3823 - loss: 0.3917
# Epoch 2: val_accuracy improved from 0.35840 to 0.38293, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 137s 187ms/step - accuracy: 0.3824 - loss: 0.3917 - val_accuracy: 0.3829 - val_loss: 0.3907 - learning_rate: 0.0050
# Epoch 3/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4326 - loss: 0.3685
# Epoch 3: val_accuracy improved from 0.38293 to 0.39627, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 124s 169ms/step - accuracy: 0.4326 - loss: 0.3685 - val_accuracy: 0.3963 - val_loss: 0.3743 - learning_rate: 0.0050
# Epoch 4/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4510 - loss: 0.3572
# Epoch 4: val_accuracy improved from 0.39627 to 0.40587, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 185s 253ms/step - accuracy: 0.4510 - loss: 0.3572 - val_accuracy: 0.4059 - val_loss: 0.3675 - learning_rate: 0.0050
# Epoch 5/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4782 - loss: 0.3413
# Epoch 5: val_accuracy improved from 0.40587 to 0.41707, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 134s 183ms/step - accuracy: 0.4782 - loss: 0.3413 - val_accuracy: 0.4171 - val_loss: 0.3628 - learning_rate: 0.0050
# Epoch 6/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4867 - loss: 0.3361
# Epoch 6: val_accuracy improved from 0.41707 to 0.45920, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 183s 250ms/step - accuracy: 0.4867 - loss: 0.3361 - val_accuracy: 0.4592 - val_loss: 0.3374 - learning_rate: 0.0050
# Epoch 7/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4947 - loss: 0.3327
# Epoch 7: val_accuracy did not improve from 0.45920
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 34s 46ms/step - accuracy: 0.4947 - loss: 0.3327 - val_accuracy: 0.4523 - val_loss: 0.3462 - learning_rate: 0.0050
# Epoch 8/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5138 - loss: 0.3234
# Epoch 8: val_accuracy did not improve from 0.45920
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 33s 45ms/step - accuracy: 0.5138 - loss: 0.3234 - val_accuracy: 0.4331 - val_loss: 0.3545 - learning_rate: 0.0050
# Epoch 9/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5215 - loss: 0.3184
# Epoch 9: val_accuracy did not improve from 0.45920
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 41s 56ms/step - accuracy: 0.5215 - loss: 0.3184 - val_accuracy: 0.4528 - val_loss: 0.3312 - learning_rate: 0.0050
# Epoch 10/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5284 - loss: 0.3163
# Epoch 10: val_accuracy improved from 0.45920 to 0.48267, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 138s 188ms/step - accuracy: 0.5284 - loss: 0.3163 - val_accuracy: 0.4827 - val_loss: 0.3342 - learning_rate: 0.0050
# Epoch 11/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5328 - loss: 0.3122
# Epoch 11: val_accuracy did not improve from 0.48267
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 33s 44ms/step - accuracy: 0.5328 - loss: 0.3122 - val_accuracy: 0.4656 - val_loss: 0.3300 - learning_rate: 0.0050
# Epoch 12/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5423 - loss: 0.3102
# Epoch 12: val_accuracy did not improve from 0.48267
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 33s 46ms/step - accuracy: 0.5423 - loss: 0.3102 - val_accuracy: 0.4741 - val_loss: 0.3357 - learning_rate: 0.0050
# Epoch 13/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5419 - loss: 0.3065
# Epoch 13: val_accuracy improved from 0.48267 to 0.48533, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 187s 255ms/step - accuracy: 0.5419 - loss: 0.3065 - val_accuracy: 0.4853 - val_loss: 0.3286 - learning_rate: 0.0050
# Epoch 14/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5586 - loss: 0.3008
# Epoch 14: val_accuracy did not improve from 0.48533
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 34s 47ms/step - accuracy: 0.5586 - loss: 0.3008 - val_accuracy: 0.4725 - val_loss: 0.3322 - learning_rate: 0.0050
# Epoch 15/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5574 - loss: 0.2998
# Epoch 15: val_accuracy did not improve from 0.48533
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 35s 47ms/step - accuracy: 0.5574 - loss: 0.2998 - val_accuracy: 0.4789 - val_loss: 0.3257 - learning_rate: 0.0050
# Epoch 16/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5634 - loss: 0.2963
# Epoch 16: val_accuracy did not improve from 0.48533
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 34s 47ms/step - accuracy: 0.5634 - loss: 0.2963 - val_accuracy: 0.4731 - val_loss: 0.3305 - learning_rate: 0.0050
# Epoch 17/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5639 - loss: 0.2950
# Epoch 17: val_accuracy improved from 0.48533 to 0.52960, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 160s 218ms/step - accuracy: 0.5639 - loss: 0.2950 - val_accuracy: 0.5296 - val_loss: 0.3096 - learning_rate: 0.0050
# Epoch 18/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5703 - loss: 0.2927
# Epoch 18: val_accuracy did not improve from 0.52960
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 75s 102ms/step - accuracy: 0.5703 - loss: 0.2927 - val_accuracy: 0.4885 - val_loss: 0.3176 - learning_rate: 0.0050
# Epoch 19/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5743 - loss: 0.2905
# Epoch 19: val_accuracy did not improve from 0.52960
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 44ms/step - accuracy: 0.5743 - loss: 0.2905 - val_accuracy: 0.4992 - val_loss: 0.3205 - learning_rate: 0.0050
# Epoch 20/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5750 - loss: 0.2924
# Epoch 20: val_accuracy did not improve from 0.52960
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 35s 47ms/step - accuracy: 0.5750 - loss: 0.2924 - val_accuracy: 0.5136 - val_loss: 0.3165 - learning_rate: 0.0050
# Epoch 21/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5773 - loss: 0.2894
# Epoch 21: val_accuracy did not improve from 0.52960
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 44ms/step - accuracy: 0.5773 - loss: 0.2894 - val_accuracy: 0.5077 - val_loss: 0.3149 - learning_rate: 0.0050
# Epoch 22/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5841 - loss: 0.2842
# Epoch 22: val_accuracy did not improve from 0.52960
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 43ms/step - accuracy: 0.5841 - loss: 0.2842 - val_accuracy: 0.5189 - val_loss: 0.3108 - learning_rate: 0.0050
# Epoch 23/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6002 - loss: 0.2791
# Epoch 23: val_accuracy did not improve from 0.52960
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 33s 44ms/step - accuracy: 0.6002 - loss: 0.2791 - val_accuracy: 0.5291 - val_loss: 0.3082 - learning_rate: 0.0025
# Epoch 24/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6088 - loss: 0.2755
# Epoch 24: val_accuracy did not improve from 0.52960
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 33s 45ms/step - accuracy: 0.6088 - loss: 0.2755 - val_accuracy: 0.5157 - val_loss: 0.3101 - learning_rate: 0.0025
# Epoch 25/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6124 - loss: 0.2748
# Epoch 25: val_accuracy did not improve from 0.52960
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 31s 42ms/step - accuracy: 0.6124 - loss: 0.2748 - val_accuracy: 0.5104 - val_loss: 0.3148 - learning_rate: 0.0025
# Epoch 26/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6151 - loss: 0.2719
# Epoch 26: val_accuracy improved from 0.52960 to 0.53653, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 182s 249ms/step - accuracy: 0.6151 - loss: 0.2719 - val_accuracy: 0.5365 - val_loss: 0.3050 - learning_rate: 0.0025
# Epoch 27/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6075 - loss: 0.2739
# Epoch 27: val_accuracy did not improve from 0.53653
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 33s 46ms/step - accuracy: 0.6075 - loss: 0.2738 - val_accuracy: 0.5221 - val_loss: 0.3068 - learning_rate: 0.0025
# Epoch 28/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6110 - loss: 0.2719
# Epoch 28: val_accuracy improved from 0.53653 to 0.55360, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 140s 192ms/step - accuracy: 0.6110 - loss: 0.2719 - val_accuracy: 0.5536 - val_loss: 0.3040 - learning_rate: 0.0025
# Epoch 29/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6199 - loss: 0.2688
# Epoch 29: val_accuracy did not improve from 0.55360
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 31s 42ms/step - accuracy: 0.6199 - loss: 0.2688 - val_accuracy: 0.5509 - val_loss: 0.3001 - learning_rate: 0.0025
# Epoch 30/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6185 - loss: 0.2698
# Epoch 30: val_accuracy did not improve from 0.55360
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 31s 43ms/step - accuracy: 0.6185 - loss: 0.2698 - val_accuracy: 0.5381 - val_loss: 0.3011 - learning_rate: 0.0025
# Epoch 31/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6249 - loss: 0.2678
# Epoch 31: val_accuracy did not improve from 0.55360
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 31s 43ms/step - accuracy: 0.6249 - loss: 0.2678 - val_accuracy: 0.5413 - val_loss: 0.3018 - learning_rate: 0.0025
# Epoch 32/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6248 - loss: 0.2690
# Epoch 32: val_accuracy did not improve from 0.55360
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 44ms/step - accuracy: 0.6248 - loss: 0.2690 - val_accuracy: 0.5365 - val_loss: 0.2994 - learning_rate: 0.0025
# Epoch 33/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6203 - loss: 0.2683
# Epoch 33: val_accuracy did not improve from 0.55360
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 44ms/step - accuracy: 0.6203 - loss: 0.2683 - val_accuracy: 0.5003 - val_loss: 0.3087 - learning_rate: 0.0025
# Epoch 34/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6184 - loss: 0.2689
# Epoch 34: val_accuracy did not improve from 0.55360
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 31s 43ms/step - accuracy: 0.6184 - loss: 0.2689 - val_accuracy: 0.5531 - val_loss: 0.2941 - learning_rate: 0.0025
# Epoch 35/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6241 - loss: 0.2679
# Epoch 35: val_accuracy did not improve from 0.55360
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 31s 43ms/step - accuracy: 0.6241 - loss: 0.2679 - val_accuracy: 0.5451 - val_loss: 0.2974 - learning_rate: 0.0025
# Epoch 36/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6178 - loss: 0.2677
# Epoch 36: val_accuracy did not improve from 0.55360
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 43ms/step - accuracy: 0.6179 - loss: 0.2677 - val_accuracy: 0.5381 - val_loss: 0.3053 - learning_rate: 0.0025
# Epoch 37/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6288 - loss: 0.2638
# Epoch 37: val_accuracy did not improve from 0.55360
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 31s 42ms/step - accuracy: 0.6288 - loss: 0.2638 - val_accuracy: 0.5472 - val_loss: 0.2961 - learning_rate: 0.0025
# Epoch 38/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6281 - loss: 0.2663
# Epoch 38: val_accuracy did not improve from 0.55360
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 43ms/step - accuracy: 0.6281 - loss: 0.2663 - val_accuracy: 0.5456 - val_loss: 0.2978 - learning_rate: 0.0025
# Epoch 39/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6317 - loss: 0.2641
# Epoch 39: val_accuracy did not improve from 0.55360
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 44ms/step - accuracy: 0.6317 - loss: 0.2641 - val_accuracy: 0.5323 - val_loss: 0.3038 - learning_rate: 0.0025
# Epoch 40/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6429 - loss: 0.2589
# Epoch 40: val_accuracy improved from 0.55360 to 0.56320, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 178s 243ms/step - accuracy: 0.6429 - loss: 0.2589 - val_accuracy: 0.5632 - val_loss: 0.2938 - learning_rate: 0.0012
# Epoch 41/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6341 - loss: 0.2597
# Epoch 41: val_accuracy did not improve from 0.56320
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 33s 45ms/step - accuracy: 0.6341 - loss: 0.2597 - val_accuracy: 0.5536 - val_loss: 0.2952 - learning_rate: 0.0012
# Epoch 42/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6447 - loss: 0.2572
# Epoch 42: val_accuracy did not improve from 0.56320
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 44ms/step - accuracy: 0.6447 - loss: 0.2572 - val_accuracy: 0.5536 - val_loss: 0.2926 - learning_rate: 0.0012
# Epoch 43/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6432 - loss: 0.2581
# Epoch 43: val_accuracy did not improve from 0.56320
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 33s 45ms/step - accuracy: 0.6432 - loss: 0.2581 - val_accuracy: 0.5605 - val_loss: 0.2932 - learning_rate: 0.0012
# Epoch 44/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6485 - loss: 0.2554
# Epoch 44: val_accuracy did not improve from 0.56320
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 41s 56ms/step - accuracy: 0.6485 - loss: 0.2554 - val_accuracy: 0.5632 - val_loss: 0.2915 - learning_rate: 0.0012
# Epoch 45/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6502 - loss: 0.2544
# Epoch 45: val_accuracy did not improve from 0.56320
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 43ms/step - accuracy: 0.6502 - loss: 0.2544 - val_accuracy: 0.5461 - val_loss: 0.2986 - learning_rate: 0.0012
# Epoch 46/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6435 - loss: 0.2582
# Epoch 46: val_accuracy did not improve from 0.56320
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 33s 45ms/step - accuracy: 0.6435 - loss: 0.2582 - val_accuracy: 0.5589 - val_loss: 0.2937 - learning_rate: 0.0012
# Epoch 47/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6392 - loss: 0.2576
# Epoch 47: val_accuracy did not improve from 0.56320
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 33s 45ms/step - accuracy: 0.6392 - loss: 0.2576 - val_accuracy: 0.5632 - val_loss: 0.2925 - learning_rate: 0.0012
# Epoch 48/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6523 - loss: 0.2541
# Epoch 48: val_accuracy did not improve from 0.56320
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 40s 55ms/step - accuracy: 0.6523 - loss: 0.2541 - val_accuracy: 0.5525 - val_loss: 0.2960 - learning_rate: 0.0012
# Epoch 49/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6543 - loss: 0.2538
# Epoch 49: val_accuracy did not improve from 0.56320
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 44ms/step - accuracy: 0.6543 - loss: 0.2538 - val_accuracy: 0.5547 - val_loss: 0.2913 - learning_rate: 0.0012
# Epoch 50/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6551 - loss: 0.2525
# Epoch 50: val_accuracy did not improve from 0.56320
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 43ms/step - accuracy: 0.6551 - loss: 0.2525 - val_accuracy: 0.5600 - val_loss: 0.2903 - learning_rate: 6.2500e-04
# Epoch 51/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6619 - loss: 0.2500
# Epoch 51: val_accuracy improved from 0.56320 to 0.56427, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 157s 214ms/step - accuracy: 0.6619 - loss: 0.2500 - val_accuracy: 0.5643 - val_loss: 0.2902 - learning_rate: 6.2500e-04
# Epoch 52/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6568 - loss: 0.2510
# Epoch 52: val_accuracy improved from 0.56427 to 0.56587, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 248s 339ms/step - accuracy: 0.6568 - loss: 0.2509 - val_accuracy: 0.5659 - val_loss: 0.2915 - learning_rate: 6.2500e-04
# Epoch 53/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6610 - loss: 0.2503
# Epoch 53: val_accuracy did not improve from 0.56587
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 44ms/step - accuracy: 0.6610 - loss: 0.2503 - val_accuracy: 0.5536 - val_loss: 0.2926 - learning_rate: 6.2500e-04
# Epoch 54/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6604 - loss: 0.2499
# Epoch 54: val_accuracy did not improve from 0.56587
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 41s 56ms/step - accuracy: 0.6604 - loss: 0.2499 - val_accuracy: 0.5568 - val_loss: 0.2904 - learning_rate: 6.2500e-04
# Epoch 55/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6643 - loss: 0.2498
# Epoch 55: val_accuracy did not improve from 0.56587
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 41s 55ms/step - accuracy: 0.6643 - loss: 0.2498 - val_accuracy: 0.5643 - val_loss: 0.2879 - learning_rate: 6.2500e-04
# Epoch 56/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6640 - loss: 0.2487
# Epoch 56: val_accuracy did not improve from 0.56587
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 44ms/step - accuracy: 0.6640 - loss: 0.2487 - val_accuracy: 0.5589 - val_loss: 0.2891 - learning_rate: 6.2500e-04
# Epoch 57/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6590 - loss: 0.2503
# Epoch 57: val_accuracy did not improve from 0.56587
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 31s 42ms/step - accuracy: 0.6590 - loss: 0.2503 - val_accuracy: 0.5621 - val_loss: 0.2922 - learning_rate: 6.2500e-04
# Epoch 58/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6632 - loss: 0.2481
# Epoch 58: val_accuracy did not improve from 0.56587
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 31s 43ms/step - accuracy: 0.6632 - loss: 0.2481 - val_accuracy: 0.5611 - val_loss: 0.2912 - learning_rate: 6.2500e-04
# Epoch 59/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6605 - loss: 0.2504
# Epoch 59: val_accuracy did not improve from 0.56587
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 31s 43ms/step - accuracy: 0.6605 - loss: 0.2504 - val_accuracy: 0.5605 - val_loss: 0.2899 - learning_rate: 6.2500e-04
# Epoch 60/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6625 - loss: 0.2511
# Epoch 60: val_accuracy improved from 0.56587 to 0.56853, saving model to model.keras
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 191s 260ms/step - accuracy: 0.6625 - loss: 0.2511 - val_accuracy: 0.5685 - val_loss: 0.2912 - learning_rate: 6.2500e-04
# Epoch 61/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6694 - loss: 0.2475
# Epoch 61: val_accuracy did not improve from 0.56853
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 43ms/step - accuracy: 0.6694 - loss: 0.2475 - val_accuracy: 0.5659 - val_loss: 0.2891 - learning_rate: 3.1250e-04
# Epoch 62/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6739 - loss: 0.2455
# Epoch 62: val_accuracy improved from 0.56853 to 0.57333, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 267s 365ms/step - accuracy: 0.6739 - loss: 0.2455 - val_accuracy: 0.5733 - val_loss: 0.2879 - learning_rate: 3.1250e-04
# Epoch 63/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6704 - loss: 0.2467
# Epoch 63: val_accuracy did not improve from 0.57333
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 31s 43ms/step - accuracy: 0.6704 - loss: 0.2467 - val_accuracy: 0.5659 - val_loss: 0.2892 - learning_rate: 3.1250e-04
# Epoch 64/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6654 - loss: 0.2482
# Epoch 64: val_accuracy improved from 0.57333 to 0.57387, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 184s 252ms/step - accuracy: 0.6654 - loss: 0.2482 - val_accuracy: 0.5739 - val_loss: 0.2866 - learning_rate: 3.1250e-04
# Epoch 65/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6736 - loss: 0.2455
# Epoch 65: val_accuracy improved from 0.57387 to 0.57973, saving model to model.keras
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 270s 369ms/step - accuracy: 0.6736 - loss: 0.2455 - val_accuracy: 0.5797 - val_loss: 0.2859 - learning_rate: 3.1250e-04
# Epoch 66/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6685 - loss: 0.2479
# Epoch 66: val_accuracy did not improve from 0.57973
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 44ms/step - accuracy: 0.6685 - loss: 0.2479 - val_accuracy: 0.5728 - val_loss: 0.2878 - learning_rate: 3.1250e-04
# Epoch 67/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6650 - loss: 0.2489
# Epoch 67: val_accuracy did not improve from 0.57973
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 40s 55ms/step - accuracy: 0.6650 - loss: 0.2489 - val_accuracy: 0.5701 - val_loss: 0.2876 - learning_rate: 3.1250e-04
# Epoch 68/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6718 - loss: 0.2457
# Epoch 68: val_accuracy did not improve from 0.57973
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 41s 56ms/step - accuracy: 0.6718 - loss: 0.2457 - val_accuracy: 0.5739 - val_loss: 0.2867 - learning_rate: 3.1250e-04
# Epoch 69/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6699 - loss: 0.2452
# Epoch 69: val_accuracy did not improve from 0.57973
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 31s 42ms/step - accuracy: 0.6699 - loss: 0.2452 - val_accuracy: 0.5739 - val_loss: 0.2870 - learning_rate: 3.1250e-04
# Epoch 70/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6696 - loss: 0.2468
# Epoch 70: val_accuracy did not improve from 0.57973
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 41s 56ms/step - accuracy: 0.6696 - loss: 0.2468 - val_accuracy: 0.5723 - val_loss: 0.2868 - learning_rate: 1.5625e-04
# Epoch 71/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6729 - loss: 0.2437
# Epoch 71: val_accuracy did not improve from 0.57973
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 41s 56ms/step - accuracy: 0.6729 - loss: 0.2437 - val_accuracy: 0.5680 - val_loss: 0.2877 - learning_rate: 1.5625e-04
# Epoch 72/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6676 - loss: 0.2454
# Epoch 72: val_accuracy did not improve from 0.57973
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 31s 43ms/step - accuracy: 0.6676 - loss: 0.2454 - val_accuracy: 0.5696 - val_loss: 0.2878 - learning_rate: 1.5625e-04
# Epoch 73/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6695 - loss: 0.2463
# Epoch 73: val_accuracy did not improve from 0.57973
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 33s 44ms/step - accuracy: 0.6695 - loss: 0.2463 - val_accuracy: 0.5691 - val_loss: 0.2867 - learning_rate: 1.5625e-04
# Epoch 74/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6683 - loss: 0.2468
# Epoch 74: val_accuracy did not improve from 0.57973
#
# Epoch 74: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 44ms/step - accuracy: 0.6683 - loss: 0.2468 - val_accuracy: 0.5696 - val_loss: 0.2871 - learning_rate: 1.5625e-04
# Epoch 75/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6653 - loss: 0.2487
# Epoch 75: val_accuracy did not improve from 0.57973
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 43ms/step - accuracy: 0.6653 - loss: 0.2487 - val_accuracy: 0.5685 - val_loss: 0.2868 - learning_rate: 7.8125e-05
# Epoch 76/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6660 - loss: 0.2473
# Epoch 76: val_accuracy did not improve from 0.57973
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 43ms/step - accuracy: 0.6660 - loss: 0.2473 - val_accuracy: 0.5707 - val_loss: 0.2864 - learning_rate: 7.8125e-05
# Epoch 77/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6718 - loss: 0.2466
# Epoch 77: val_accuracy did not improve from 0.57973
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 43ms/step - accuracy: 0.6718 - loss: 0.2466 - val_accuracy: 0.5739 - val_loss: 0.2860 - learning_rate: 7.8125e-05
# Epoch 78/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6656 - loss: 0.2481
# Epoch 78: val_accuracy did not improve from 0.57973
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 44ms/step - accuracy: 0.6656 - loss: 0.2481 - val_accuracy: 0.5707 - val_loss: 0.2866 - learning_rate: 7.8125e-05
# Epoch 79/100
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6787 - loss: 0.2436
# Epoch 79: val_accuracy did not improve from 0.57973
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 43ms/step - accuracy: 0.6787 - loss: 0.2436 - val_accuracy: 0.5707 - val_loss: 0.2863 - learning_rate: 7.8125e-05
# Epoch 80/100
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6722 - loss: 0.2455
# Epoch 80: val_accuracy did not improve from 0.57973
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 32s 43ms/step - accuracy: 0.6722 - loss: 0.2455 - val_accuracy: 0.5733 - val_loss: 0.2850 - learning_rate: 3.9062e-05
# Epoch 80: early stopping
# Restoring model weights from the end of the best epoch: 65.
# Best validation model: epoch 65  - val_accuracy 0.5797333121299744

# %%
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(16, 5))

    # Gráfica de Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training acc')
    plt.plot(epochs, val_acc, 'ro-', label='Validation acc')
    plt.title('Accuracy: Train vs Validation')
    plt.legend()
    plt.grid(True)

    # Gráfica de Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
    plt.title('Loss: Train vs Validation')
    plt.legend()
    plt.grid(True)

    plt.show()

# USARLO:
plot_history(h)

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
# 1. Usamos los datos que YA cargamos en RAM (Velocidad: 100x más rápido)
# model.predict procesa todo el bloque de golpe (Batch processing)
model.load_weights('model.keras')

print("Prediciendo todo el validación de golpe...")
predictions = model.predict(X_valid_ram.astype('float32') / 255.0, batch_size=32, verbose=1)

# 2. Sacamos la clase ganadora de cada foto
y_pred_indices = np.argmax(predictions, axis=1) # [0, 5, 2...]

# 3. Convertimos números a nombres (si lo necesitas en texto)
class_names = list(categories.values())
y_pred = [class_names[i] for i in y_pred_indices]

# 4. Sacamos el y_true (La realidad)
# Si y_valid_ram era texto:
y_true = y_valid_ram
# Si y_valid_ram era One-Hot o índices, adáptalo.
# Asumiendo que es la lista de textos que devolvía load_dataset_to_ram:
# (Si usaste mi última función, y_valid_ram es una lista de strings ['Helipad', 'Car'...])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 6 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Prediciendo todo el validación de golpe...
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 57.707%
# Mean Recall: 57.251%
# Mean Precision: 55.026%
# > Cargo plane: Recall: 81.356% Precision: 96.000% Specificity: 99.890% Dice: 88.073%
# > Small car: Recall: 79.939% Precision: 70.321% Specificity: 92.820% Dice: 74.822%
# > Bus: Recall: 45.402% Precision: 53.741% Specificity: 96.002% Dice: 49.221%
# > Truck: Recall: 21.577% Precision: 36.620% Specificity: 94.492% Dice: 27.154%
# > Motorboat: Recall: 53.211% Precision: 47.934% Specificity: 96.433% Dice: 50.435%
# > Fishing vessel: Recall: 64.384% Precision: 34.058% Specificity: 94.950% Dice: 44.550%
# > Dump truck: Recall: 39.831% Precision: 62.667% Specificity: 98.406% Dice: 48.705%
# > Excavator: Recall: 70.370% Precision: 48.305% Specificity: 96.600% Dice: 57.286%
# > Building: Recall: 73.554% Precision: 64.806% Specificity: 90.410% Dice: 68.903%
# > Helipad: Recall: 44.444% Precision: 36.364% Specificity: 99.625% Dice: 40.000%
# > Storage tank: Recall: 44.079% Precision: 74.444% Specificity: 98.665% Dice: 55.372%
# > Shipping container: Recall: 51.111% Precision: 50.735% Specificity: 96.149% Dice: 50.923%
# > Pylon: Recall: 75.000% Precision: 39.344% Specificity: 97.992% Dice: 51.613%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('../content/dataset/xview_recognition/xview_test'):
    for filename in filenames:
        image = GenericImage(dirpath[29:] + '/' + filename)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    # Fix: Remove 'gnition/' from the filename path which was incorrectly added in the previous cell
    image = load_geoimage(ann.filename[8:]) / 255.0
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 6 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)
