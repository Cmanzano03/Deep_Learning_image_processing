# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Yousef Medhat
# - Alumno 2: Carlos Manzano Izquierdo
# - Alumno 3: Guillermo Bermejo Babiano
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# The -q flag means "quiet" so it doesn't print 10,000 lines and crash your browser
# !unzip -q "/content/drive/MyDrive/DL/xview_recognition.zip" -d "/content/dataset"

print("✅ Unzipping complete!")
# Out:
# replace /content/dataset/xview_recognition/xview_ann_train.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# ✅ Unzipping complete!

# %%
data_dir = '/content/dataset/xview_recognition' # Or whatever the extracted folder is named

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open('../content/dataset/xview_recognition/'+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json

# Load database
json_file = '../content/dataset/xview_recognition/xview_ann_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 16871
# Number of validation images: 1875

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L2

model = Sequential([
    Flatten(input_shape=(64, 64, 3)),
    BatchNormalization(),

    # Block 1: 512 Neurons
    Dense(512, kernel_initializer='he_normal'), # Eliminado L2
    BatchNormalization(),
    Activation('swish'),
    Dropout(0.1), # Reducido de 0.3 a 0.1 para que retenga más información

    # Block 2: 256 Neurons
    Dense(256, kernel_initializer='he_normal'), # Eliminado L2
    BatchNormalization(),
    Activation('swish'),
    Dropout(0.1), # Reducido de 0.3 a 0.1

    # Block 3: 128 Neurons
    Dense(128, kernel_initializer='he_normal'), # Eliminado L2
    BatchNormalization(),
    Activation('swish'),
    Dropout(0.1), # Reducido de 0.2 a 0.1

    # Output Layer
    Dense(len(categories), activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_3 (Flatten)             │ (None, 12288)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 12288)          │        49,152 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 512)            │     6,291,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_9 (Activation)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_10 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_11 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,510,605 (24.84 MB)
#  Trainable params: 6,484,237 (24.74 MB)
#  Non-trainable params: 26,368 (103.00 KB)

# %%
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.losses import CategoricalFocalCrossentropy

focal_loss = CategoricalFocalCrossentropy(
    gamma=2.0,
    from_logits=False,
    label_smoothing=0.1
)

opt = AdamW(learning_rate=0.001, weight_decay=1e-4)

model.compile(optimizer=opt, loss=focal_loss, metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_delta=0.001,
    verbose=1
)
early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
import numpy as np
import cv2

def generator_from_ram(X_data, y_data, batch_size, class_weights_dict, do_shuffle=False, do_augment=False):
    # 1. PREPARACIÓN DE DATOS
    class_names = list(categories.values())
    class_map = {name: i for i, name in enumerate(class_names)}
    num_classes = len(class_names)

    # Convertimos etiquetas a índices numéricos para ir rápido
    if isinstance(y_data[0], str) or isinstance(y_data[0], np.str_):
        y_indices_all = np.array([class_map[cat] for cat in y_data], dtype='int32')
    else:
        # Si ya son one-hot, los pasamos a índices
        if len(y_data.shape) > 1:
            y_indices_all = np.argmax(y_data, axis=1)
        else:
            y_indices_all = y_data

    # CREAMOS UNA TABLA DE BÚSQUEDA RÁPIDA DE PESOS
    # Esto convierte el diccionario {0: 1.0, 3: 4.0} en un array [1.0, 1.0, 1.0, 4.0...]
    # Así el acceso es instantáneo para la CPU.
    weights_lookup = np.array([class_weights_dict[i] for i in range(len(class_weights_dict))], dtype='float32')

    indices = np.arange(len(X_data))

    while True:
        if do_shuffle:
            np.random.shuffle(indices)

        for i in range(0, len(indices), batch_size):
            batch_indices = indices[i:i+batch_size]
            current_batch_size = len(batch_indices)

            # Reservar memoria
            batch_x = np.zeros((current_batch_size, 64, 64, 3), dtype='float32')
            batch_y = np.zeros((current_batch_size, num_classes), dtype='float32')

            # Datos crudos
            raw_images = X_data[batch_indices]
            raw_labels_indices = y_indices_all[batch_indices] # Índices (0, 3, 5...)

            # --- AQUÍ ESTÁ EL TRUCO: SAMPLE WEIGHTS ---
            # Buscamos el peso que le toca a cada foto de este batch
            batch_weights = weights_lookup[raw_labels_indices]

            for j in range(current_batch_size):
                img = raw_images[j].copy() if do_augment else raw_images[j]

                # Augmentation
                if do_augment:
                    # Rotación
                    k = np.random.randint(0, 4)
                    if k > 0: img = np.rot90(img, k)
                    # Flip
                    if np.random.rand() > 0.5:
                        code = np.random.choice([0, 1])
                        img = cv2.flip(img, code)
                    # Brillo
                    if np.random.rand() > 0.2:
                        alpha = np.random.uniform(0.8, 1.2)
                        beta = np.random.uniform(-25, 25)
                        img = cv2.convertScaleAbs(img, alpha=alpha, beta=beta)

                batch_x[j] = img.astype('float32') / 255.0
                batch_y[j, raw_labels_indices[j]] = 1.0

            # DEVOLVEMOS 3 COSAS: X, Y, W
            yield batch_x, batch_y, batch_weights

# %%
import numpy as np
import cv2
from tqdm import tqdm  # Barra de progreso

def load_dataset_to_ram(objs_list, target_size=(64, 64)):
    print(f"Cargando {len(objs_list)} imágenes en RAM... ")

    X_data = []
    y_labels = []

    for filename, obj in tqdm(objs_list):
        # 1. Cargar
        img = load_geoimage(filename)

        # 2. Redimensionar a target size
        # (Es vital para poder apilarlas en un array de Numpy)
        if img.shape[:2] != target_size:
            img = cv2.resize(img, target_size, interpolation=cv2.INTER_AREA)

        # 3. Guardar tal cual (uint8, 0-255).
        # NO dividas por 255 aquí o ocuparás 4 veces más RAM.
        X_data.append(img)
        y_labels.append(obj.category)

    # Convertir a Bloque Numpy
    X_data = np.array(X_data, dtype='uint8')
    y_labels = np.array(y_labels)

    print(f"¡Carga lista! Ocupa en RAM: {X_data.nbytes / 1024 / 1024:.2f} MB")
    return X_data, y_labels

# %%
def balance_dataset_list(objs):
    # 1. Contamos cuántos hay de cada clase originalmente
    counts = {}
    for _, obj in objs:
        c = obj.category
        counts[c] = counts.get(c, 0) + 1

    print("--- CONTEO ORIGINAL ---")
    print(counts)

    balanced_objs = []

    # CONFIGURACIÓN DE OBJETIVOS
    TARGET_STANDARD = 2000  # Objetivo para la mayoría (Pylons, Barcos, Camiones...)
    TARGET_TINY = 1000      # Objetivo conservador para las muy pequeñas (Helipuertos)
    TINY_THRESHOLD = 200    # Si tiene menos de 200, usamos el objetivo 'Tiny'

    for filename, obj in objs:
        # Siempre añadimos la imagen original
        balanced_objs.append((filename, obj))

        current_count = counts[obj.category]

        # Determinamos el objetivo según el tamaño de la clase
        if current_count < TINY_THRESHOLD:
            target = TARGET_TINY  # Caso Helipuertos (111 -> ~1000)
        else:
            target = TARGET_STANDARD # Caso Pylons/Trucks (300 -> ~2000)

        # Si estamos por debajo del objetivo, calculamos copias
        if current_count < target:
            # Ejemplo Pylon (312): 2000 / 312 = 6.4 -> Multiplicador 6 (Total 7 copias)
            # Ejemplo Helipuerto (111): 1000 / 111 = 9.0 -> Multiplicador 9 (Total 10 copias)
            # Restamos 1 porque ya añadimos la original arriba
            multiplier = int(target / current_count) - 1

            # Solo añadimos si el multiplicador es positivo
            if multiplier > 0:
                for _ in range(multiplier):
                    balanced_objs.append((filename, obj))

    print(f"\n--- DATASET BALANCEADO ---")
    print(f"De {len(objs)} imágenes pasamos a {len(balanced_objs)} imágenes virtuales.")

    return balanced_objs

# %%
manual_weights_dict = {
    0: 1.0,
    1: 1.0,  # Small car: Volvemos a 1.0 (bajarlo a 0.8 fue demasiado castigo)
    2: 1.5,  # Bus: Bajamos de 2.0 a 1.5
    3: 2.5,  # TRUCK: Bajamos de 4.0 a 2.5 (Suficiente para que aprenda, sin volverse loco)
    4: 1.0,
    5: 1.0,
    6: 1.5,  # Dump truck: Bajamos de 2.0 a 1.5
    7: 1.0, 8: 1.0, 9: 1.2,
    10: 1.5, # Storage tank
    11: 1.0, 12: 1.0
}

# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]

# PASO 1: Balanceo de clases
print("--- FASE 1: Balanceo ---")
objs_train_balanced = balance_dataset_list(objs_train)


# PASO 2: Cargar todo en RAM
# -------------------------------------------------------
print("\n--- FASE 2: Carga en RAM ---")
# Train con lista inflada
X_train_ram, y_train_ram = load_dataset_to_ram(objs_train_balanced)
# Valid con lista normal
X_valid_ram, y_valid_ram = load_dataset_to_ram(objs_valid)

# PASO 3: Crear Generadores Rápidos
# -------------------------------------------------------
batch_size = 32

train_gen = generator_from_ram(
    X_train_ram, y_train_ram,
    batch_size=batch_size,
    do_shuffle=True,
    do_augment=True,
    class_weights_dict=manual_weights_dict
)

valid_gen = generator_from_ram(
    X_valid_ram, y_valid_ram,
    batch_size=batch_size,
    do_shuffle=False,
    do_augment=False,
    class_weights_dict=manual_weights_dict
)
# Out:
# --- FASE 1: Balanceo ---
# --- CONTEO ORIGINAL ---
# {'Bus': 1594, 'Cargo plane': 576, 'Truck': 1969, 'Building': 3231, 'Fishing vessel': 633, 'Small car': 2995, 'Pylon': 280, 'Shipping container': 1388, 'Dump truck': 1118, 'Motorboat': 960, 'Storage tank': 1317, 'Excavator': 708, 'Helipad': 102}
#
# --- DATASET BALANCEADO ---
# De 16871 imágenes pasamos a 23453 imágenes virtuales.
#
# --- FASE 2: Carga en RAM ---
# Cargando 23453 imágenes en RAM...
# 100%|██████████| 23453/23453 [01:00<00:00, 389.62it/s]
# ¡Carga lista! Ocupa en RAM: 274.84 MB
# Cargando 1875 imágenes en RAM...
# 100%|██████████| 1875/1875 [00:04<00:00, 422.44it/s]
# ¡Carga lista! Ocupa en RAM: 21.97 MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_class_balance(original_objs, balanced_objs):
    # 1. Contar Originales
    counts_orig = {}
    for _, obj in original_objs:
        counts_orig[obj.category] = counts_orig.get(obj.category, 0) + 1

    # 2. Contar Balanceados
    counts_bal = {}
    for _, obj in balanced_objs:
        counts_bal[obj.category] = counts_bal.get(obj.category, 0) + 1

    # Preparar datos para plot
    classes = list(counts_orig.keys())
    # Ordenamos por cantidad original para que quede bonito
    classes.sort(key=lambda x: counts_orig[x], reverse=True)

    vals_orig = [counts_orig[c] for c in classes]
    vals_bal = [counts_bal[c] for c in classes]

    x = range(len(classes))
    width = 0.35

    plt.figure(figsize=(15, 6))
    plt.bar([i - width/2 for i in x], vals_orig, width, label='Original', color='red', alpha=0.6)
    plt.bar([i + width/2 for i in x], vals_bal, width, label='Balanceado (Virtual)', color='green', alpha=0.6)

    plt.xticks(x, classes, rotation=45, ha='right')
    plt.ylabel('Número de Imágenes')
    plt.title('Impacto del Oversampling en el Dataset')
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# USARLO:
plot_class_balance(objs_train, objs_train_balanced)

# %%
import matplotlib.pyplot as plt
import numpy as np

def visualize_ram_augmentation(X_data, y_data, generator_func, class_weights_dict):
    # 1. Buscar índices de Helipuertos (o la clase que quieras ver)
    # Asumimos que y_data tiene los nombres de las clases (strings)
    indices = np.where(y_data == 'Helipad')[0]

    if len(indices) == 0:
        print("No se encontraron Helipuertos en los datos proporcionados.")
        return

    idx = indices[0] # Cogemos el primer helipuerto que encontremos

    # 2. Extraer la imagen y la etiqueta originales de la RAM
    sample_img = X_data[idx]
    sample_cat = y_data[idx]

    # 3. Crear un "Mini Batch Falso" de 5 copias idénticas
    # Repetimos la imagen 5 veces: (5, 64, 64, 3)
    fake_X = np.array([sample_img] * 5)
    fake_y = np.array([sample_cat] * 5)

    # 4. Instanciar el generador con estos datos falsos
    # Le decimos batch_size=5 para que nos devuelva las 5 de golpe
    gen = generator_func(fake_X, fake_y, batch_size=5, do_shuffle=False, do_augment=True, class_weights_dict=class_weights_dict)

    images_aug, _, _ = next(gen) # Sacamos el batch procesado, IGNORAMOS Y y W

    # 5. Pintar
    plt.figure(figsize=(15, 4))
    for i in range(5):
        plt.subplot(1, 5, i+1)

        # Las imágenes vienen normalizadas (0-1) y en float32
        img_show = images_aug[i]

        # Si usaste cv2 para cargar, están en BGR. Matplotlib quiere RGB.
        # Hacemos el flip de canales con ::-1
        plt.imshow(img_show[:, :, ::-1])

        if i == 0:
            plt.title("Probablemente Original\n(o rotada)")
        else:
            plt.title(f"Variación {i}")
        plt.axis('off')

    plt.suptitle(f"Efecto del Data Augmentation en RAM ({sample_cat})")
    plt.show()

# --- CÓMO USARLO AHORA ---
# Importante: Pasa las variables _ram, NO la lista de objetos
visualize_ram_augmentation(X_train_ram, y_train_ram, generator_from_ram, manual_weights_dict)

# %%
import math
import numpy as np

print('Training model')
epochs = 100
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_gen, steps_per_epoch=train_steps,
              validation_data=valid_gen,
              validation_steps=valid_steps,
              epochs=epochs,
              callbacks=callbacks,
              verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2367 - loss: 0.5818
# Epoch 1: val_accuracy improved from -inf to 0.28427, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.2370 - loss: 0.5814 - val_accuracy: 0.2843 - val_loss: 0.5104 - learning_rate: 0.0010
# Epoch 2/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3324 - loss: 0.4865
# Epoch 2: val_accuracy improved from 0.28427 to 0.35627, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3325 - loss: 0.4865 - val_accuracy: 0.3563 - val_loss: 0.4802 - learning_rate: 0.0010
# Epoch 3/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3894 - loss: 0.4549
# Epoch 3: val_accuracy improved from 0.35627 to 0.39093, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3894 - loss: 0.4549 - val_accuracy: 0.3909 - val_loss: 0.4591 - learning_rate: 0.0010
# Epoch 4/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4114 - loss: 0.4349
# Epoch 4: val_accuracy improved from 0.39093 to 0.42187, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4114 - loss: 0.4349 - val_accuracy: 0.4219 - val_loss: 0.4484 - learning_rate: 0.0010
# Epoch 5/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4215 - loss: 0.4359
# Epoch 5: val_accuracy improved from 0.42187 to 0.42720, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4215 - loss: 0.4359 - val_accuracy: 0.4272 - val_loss: 0.4370 - learning_rate: 0.0010
# Epoch 6/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4360 - loss: 0.4240
# Epoch 6: val_accuracy improved from 0.42720 to 0.43200, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4360 - loss: 0.4240 - val_accuracy: 0.4320 - val_loss: 0.4280 - learning_rate: 0.0010
# Epoch 7/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4477 - loss: 0.4160
# Epoch 7: val_accuracy improved from 0.43200 to 0.45600, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4478 - loss: 0.4160 - val_accuracy: 0.4560 - val_loss: 0.4200 - learning_rate: 0.0010
# Epoch 8/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4703 - loss: 0.4056
# Epoch 8: val_accuracy improved from 0.45600 to 0.47520, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4703 - loss: 0.4056 - val_accuracy: 0.4752 - val_loss: 0.4153 - learning_rate: 0.0010
# Epoch 9/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4673 - loss: 0.4068
# Epoch 9: val_accuracy did not improve from 0.47520
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4672 - loss: 0.4068 - val_accuracy: 0.4688 - val_loss: 0.4148 - learning_rate: 0.0010
# Epoch 10/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4816 - loss: 0.3988
# Epoch 10: val_accuracy did not improve from 0.47520
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4816 - loss: 0.3988 - val_accuracy: 0.4720 - val_loss: 0.4106 - learning_rate: 0.0010
# Epoch 11/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4805 - loss: 0.3966
# Epoch 11: val_accuracy improved from 0.47520 to 0.47627, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4805 - loss: 0.3966 - val_accuracy: 0.4763 - val_loss: 0.4053 - learning_rate: 0.0010
# Epoch 12/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4981 - loss: 0.3897
# Epoch 12: val_accuracy improved from 0.47627 to 0.48800, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4981 - loss: 0.3897 - val_accuracy: 0.4880 - val_loss: 0.4055 - learning_rate: 0.0010
# Epoch 13/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4950 - loss: 0.3854
# Epoch 13: val_accuracy did not improve from 0.48800
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4950 - loss: 0.3854 - val_accuracy: 0.4795 - val_loss: 0.4071 - learning_rate: 0.0010
# Epoch 14/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5073 - loss: 0.3845
# Epoch 14: val_accuracy improved from 0.48800 to 0.50720, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5073 - loss: 0.3845 - val_accuracy: 0.5072 - val_loss: 0.4020 - learning_rate: 0.0010
# Epoch 15/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5190 - loss: 0.3771
# Epoch 15: val_accuracy did not improve from 0.50720
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5190 - loss: 0.3771 - val_accuracy: 0.4864 - val_loss: 0.4029 - learning_rate: 0.0010
# Epoch 16/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5006 - loss: 0.3842
# Epoch 16: val_accuracy did not improve from 0.50720
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5007 - loss: 0.3841 - val_accuracy: 0.5045 - val_loss: 0.3983 - learning_rate: 0.0010
# Epoch 17/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5192 - loss: 0.3758
# Epoch 17: val_accuracy did not improve from 0.50720
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5192 - loss: 0.3758 - val_accuracy: 0.5019 - val_loss: 0.3838 - learning_rate: 0.0010
# Epoch 18/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5204 - loss: 0.3684
# Epoch 18: val_accuracy did not improve from 0.50720
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5205 - loss: 0.3684 - val_accuracy: 0.5029 - val_loss: 0.3930 - learning_rate: 0.0010
# Epoch 19/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5226 - loss: 0.3701
# Epoch 19: val_accuracy did not improve from 0.50720
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5226 - loss: 0.3701 - val_accuracy: 0.5045 - val_loss: 0.3980 - learning_rate: 0.0010
# Epoch 20/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5260 - loss: 0.3683
# Epoch 20: val_accuracy did not improve from 0.50720
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5260 - loss: 0.3683 - val_accuracy: 0.5051 - val_loss: 0.3913 - learning_rate: 0.0010
# Epoch 21/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5295 - loss: 0.3655
# Epoch 21: val_accuracy improved from 0.50720 to 0.51787, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5295 - loss: 0.3655 - val_accuracy: 0.5179 - val_loss: 0.3855 - learning_rate: 0.0010
# Epoch 22/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5513 - loss: 0.3532
# Epoch 22: val_accuracy improved from 0.51787 to 0.52640, saving model to model.keras
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5513 - loss: 0.3532 - val_accuracy: 0.5264 - val_loss: 0.3871 - learning_rate: 0.0010
# Epoch 23/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5467 - loss: 0.3567
# Epoch 23: val_accuracy improved from 0.52640 to 0.54293, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5467 - loss: 0.3567 - val_accuracy: 0.5429 - val_loss: 0.3684 - learning_rate: 2.0000e-04
# Epoch 24/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5645 - loss: 0.3469
# Epoch 24: val_accuracy improved from 0.54293 to 0.54880, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5645 - loss: 0.3469 - val_accuracy: 0.5488 - val_loss: 0.3649 - learning_rate: 2.0000e-04
# Epoch 25/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5737 - loss: 0.3408
# Epoch 25: val_accuracy improved from 0.54880 to 0.55307, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5736 - loss: 0.3408 - val_accuracy: 0.5531 - val_loss: 0.3663 - learning_rate: 2.0000e-04
# Epoch 26/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5791 - loss: 0.3372
# Epoch 26: val_accuracy did not improve from 0.55307
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5791 - loss: 0.3372 - val_accuracy: 0.5472 - val_loss: 0.3669 - learning_rate: 2.0000e-04
# Epoch 27/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5741 - loss: 0.3416
# Epoch 27: val_accuracy did not improve from 0.55307
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.5741 - loss: 0.3415 - val_accuracy: 0.5515 - val_loss: 0.3675 - learning_rate: 2.0000e-04
# Epoch 28/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5788 - loss: 0.3372
# Epoch 28: val_accuracy improved from 0.55307 to 0.55787, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5788 - loss: 0.3372 - val_accuracy: 0.5579 - val_loss: 0.3673 - learning_rate: 2.0000e-04
# Epoch 29/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5778 - loss: 0.3377
# Epoch 29: val_accuracy did not improve from 0.55787
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.5779 - loss: 0.3377 - val_accuracy: 0.5557 - val_loss: 0.3644 - learning_rate: 2.0000e-04
# Epoch 30/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5843 - loss: 0.3309
# Epoch 30: val_accuracy improved from 0.55787 to 0.56000, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5843 - loss: 0.3309 - val_accuracy: 0.5600 - val_loss: 0.3617 - learning_rate: 4.0000e-05
# Epoch 31/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5941 - loss: 0.3308
# Epoch 31: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5941 - loss: 0.3308 - val_accuracy: 0.5573 - val_loss: 0.3626 - learning_rate: 4.0000e-05
# Epoch 32/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5903 - loss: 0.3303
# Epoch 32: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5903 - loss: 0.3304 - val_accuracy: 0.5589 - val_loss: 0.3612 - learning_rate: 4.0000e-05
# Epoch 33/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5971 - loss: 0.3280
# Epoch 33: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5970 - loss: 0.3280 - val_accuracy: 0.5515 - val_loss: 0.3611 - learning_rate: 4.0000e-05
# Epoch 34/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5891 - loss: 0.3300
# Epoch 34: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5891 - loss: 0.3300 - val_accuracy: 0.5541 - val_loss: 0.3611 - learning_rate: 4.0000e-05
# Epoch 35/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5934 - loss: 0.3263
# Epoch 35: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5934 - loss: 0.3263 - val_accuracy: 0.5552 - val_loss: 0.3593 - learning_rate: 4.0000e-05
# Epoch 36/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5806 - loss: 0.3348
# Epoch 36: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5806 - loss: 0.3348 - val_accuracy: 0.5541 - val_loss: 0.3577 - learning_rate: 4.0000e-05
# Epoch 37/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5898 - loss: 0.3285
# Epoch 37: val_accuracy improved from 0.56000 to 0.56480, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5898 - loss: 0.3285 - val_accuracy: 0.5648 - val_loss: 0.3572 - learning_rate: 4.0000e-05
# Epoch 38/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5863 - loss: 0.3297
# Epoch 38: val_accuracy did not improve from 0.56480
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5863 - loss: 0.3297 - val_accuracy: 0.5637 - val_loss: 0.3565 - learning_rate: 4.0000e-05
# Epoch 39/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5959 - loss: 0.3278
# Epoch 39: val_accuracy did not improve from 0.56480
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5959 - loss: 0.3278 - val_accuracy: 0.5605 - val_loss: 0.3574 - learning_rate: 4.0000e-05
# Epoch 40/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5907 - loss: 0.3294
# Epoch 40: val_accuracy did not improve from 0.56480
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5908 - loss: 0.3294 - val_accuracy: 0.5568 - val_loss: 0.3567 - learning_rate: 4.0000e-05
# Epoch 41/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5908 - loss: 0.3289
# Epoch 41: val_accuracy improved from 0.56480 to 0.56640, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5909 - loss: 0.3289 - val_accuracy: 0.5664 - val_loss: 0.3564 - learning_rate: 4.0000e-05
# Epoch 42/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5943 - loss: 0.3279
# Epoch 42: val_accuracy did not improve from 0.56640
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5943 - loss: 0.3279 - val_accuracy: 0.5627 - val_loss: 0.3570 - learning_rate: 4.0000e-05
# Epoch 43/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5904 - loss: 0.3321
# Epoch 43: val_accuracy did not improve from 0.56640
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5904 - loss: 0.3321 - val_accuracy: 0.5632 - val_loss: 0.3576 - learning_rate: 4.0000e-05
# Epoch 44/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5944 - loss: 0.3253
# Epoch 44: val_accuracy did not improve from 0.56640
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5945 - loss: 0.3253 - val_accuracy: 0.5627 - val_loss: 0.3556 - learning_rate: 8.0000e-06
# Epoch 45/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5899 - loss: 0.3299
# Epoch 45: val_accuracy did not improve from 0.56640
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5900 - loss: 0.3299 - val_accuracy: 0.5600 - val_loss: 0.3576 - learning_rate: 8.0000e-06
# Epoch 46/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5931 - loss: 0.3291
# Epoch 46: val_accuracy did not improve from 0.56640
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5931 - loss: 0.3291 - val_accuracy: 0.5637 - val_loss: 0.3577 - learning_rate: 8.0000e-06
# Epoch 47/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5937 - loss: 0.3295
# Epoch 47: val_accuracy did not improve from 0.56640
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5937 - loss: 0.3295 - val_accuracy: 0.5648 - val_loss: 0.3573 - learning_rate: 8.0000e-06
# Epoch 48/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6025 - loss: 0.3260
# Epoch 48: val_accuracy did not improve from 0.56640
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6025 - loss: 0.3260 - val_accuracy: 0.5595 - val_loss: 0.3549 - learning_rate: 8.0000e-06
# Epoch 49/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5890 - loss: 0.3320
# Epoch 49: val_accuracy improved from 0.56640 to 0.56800, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5890 - loss: 0.3320 - val_accuracy: 0.5680 - val_loss: 0.3541 - learning_rate: 8.0000e-06
# Epoch 50/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5926 - loss: 0.3317
# Epoch 50: val_accuracy did not improve from 0.56800
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5925 - loss: 0.3316 - val_accuracy: 0.5675 - val_loss: 0.3555 - learning_rate: 8.0000e-06
# Epoch 51/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5991 - loss: 0.3232
# Epoch 51: val_accuracy improved from 0.56800 to 0.57067, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5991 - loss: 0.3232 - val_accuracy: 0.5707 - val_loss: 0.3550 - learning_rate: 8.0000e-06
# Epoch 52/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5959 - loss: 0.3281
# Epoch 52: val_accuracy did not improve from 0.57067
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5959 - loss: 0.3281 - val_accuracy: 0.5595 - val_loss: 0.3575 - learning_rate: 8.0000e-06
# Epoch 53/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5959 - loss: 0.3275
# Epoch 53: val_accuracy did not improve from 0.57067
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5959 - loss: 0.3275 - val_accuracy: 0.5675 - val_loss: 0.3542 - learning_rate: 8.0000e-06
# Epoch 54/100
# 521/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5899 - loss: 0.3296
# Epoch 54: val_accuracy did not improve from 0.57067
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5899 - loss: 0.3296 - val_accuracy: 0.5707 - val_loss: 0.3535 - learning_rate: 1.6000e-06
# Epoch 55/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6013 - loss: 0.3281
# Epoch 55: val_accuracy did not improve from 0.57067
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6012 - loss: 0.3281 - val_accuracy: 0.5707 - val_loss: 0.3539 - learning_rate: 1.6000e-06
# Epoch 56/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5973 - loss: 0.3281
# Epoch 56: val_accuracy did not improve from 0.57067
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5974 - loss: 0.3281 - val_accuracy: 0.5685 - val_loss: 0.3538 - learning_rate: 1.6000e-06
# Epoch 57/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5901 - loss: 0.3260
# Epoch 57: val_accuracy did not improve from 0.57067
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5901 - loss: 0.3260 - val_accuracy: 0.5637 - val_loss: 0.3560 - learning_rate: 1.6000e-06
# Epoch 58/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5989 - loss: 0.3275
# Epoch 58: val_accuracy did not improve from 0.57067
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5989 - loss: 0.3275 - val_accuracy: 0.5648 - val_loss: 0.3564 - learning_rate: 1.6000e-06
# Epoch 59/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5972 - loss: 0.3272
# Epoch 59: val_accuracy did not improve from 0.57067
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5972 - loss: 0.3272 - val_accuracy: 0.5611 - val_loss: 0.3563 - learning_rate: 1.6000e-06
# Epoch 60/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6029 - loss: 0.3282
# Epoch 60: val_accuracy did not improve from 0.57067
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.6029 - loss: 0.3282 - val_accuracy: 0.5669 - val_loss: 0.3566 - learning_rate: 3.2000e-07
# Epoch 61/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6002 - loss: 0.3267
# Epoch 61: val_accuracy did not improve from 0.57067
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6001 - loss: 0.3267 - val_accuracy: 0.5605 - val_loss: 0.3567 - learning_rate: 3.2000e-07
# Epoch 62/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6064 - loss: 0.3230
# Epoch 62: val_accuracy did not improve from 0.57067
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6064 - loss: 0.3230 - val_accuracy: 0.5589 - val_loss: 0.3568 - learning_rate: 3.2000e-07
# Epoch 63/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5851 - loss: 0.3313
# Epoch 63: val_accuracy did not improve from 0.57067
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5851 - loss: 0.3313 - val_accuracy: 0.5675 - val_loss: 0.3532 - learning_rate: 3.2000e-07
# Epoch 64/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5883 - loss: 0.3302
# Epoch 64: val_accuracy did not improve from 0.57067
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5884 - loss: 0.3302 - val_accuracy: 0.5691 - val_loss: 0.3530 - learning_rate: 3.2000e-07
# Epoch 65/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5856 - loss: 0.3338
# Epoch 65: val_accuracy did not improve from 0.57067
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5856 - loss: 0.3338 - val_accuracy: 0.5659 - val_loss: 0.3541 - learning_rate: 6.4000e-08
# Epoch 66/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5870 - loss: 0.3288
# Epoch 66: val_accuracy did not improve from 0.57067
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5870 - loss: 0.3288 - val_accuracy: 0.5648 - val_loss: 0.3555 - learning_rate: 6.4000e-08
# Epoch 66: early stopping
# Restoring model weights from the end of the best epoch: 51.
# Best validation model: epoch 51  - val_accuracy 0.5706666707992554

# %%
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(16, 5))

    # Gráfica de Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training acc')
    plt.plot(epochs, val_acc, 'ro-', label='Validation acc')
    plt.title('Accuracy: Train vs Validation')
    plt.legend()
    plt.grid(True)

    # Gráfica de Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
    plt.title('Loss: Train vs Validation')
    plt.legend()
    plt.grid(True)

    plt.show()

# USARLO:
plot_history(h)

# %%
from sklearn.metrics import classification_report
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

def plot_classification_report(model, valid_gen, steps):
    print("Generando predicciones... esto puede tardar unos segundos.")

    # 1. Predecir
    y_pred = model.predict(valid_gen, steps=steps, verbose=1)
    y_pred_classes = np.argmax(y_pred, axis=1) # Convierte [0.1, 0.9, 0] -> 1

    # 2. Etiquetas reales (CORREGIDO)
    # Como y_valid_ram tiene textos ('Helipad'), hay que pasarlos a números (0, 1, 2...)
    # Usamos el orden de 'categories' para saber qué número es cada texto.
    class_names = list(categories.values()) # ['Cargo plane', 'Small car', ...]

    # Mapeamos cada texto de la RAM a su número
    y_true = np.array([class_names.index(cat) for cat in y_valid_ram])

    # AJUSTE VITAL:
    # Al usar steps = len // batch_size, es posible que 'y_pred' sea un poco más corto
    # que 'y_true' (porque se descarta el último batch incompleto).
    # Cortamos y_true para que tenga la misma longitud exacta que y_pred.
    y_true = y_true[:len(y_pred_classes)]

    # 3. Reporte
    report = classification_report(
        y_true,
        y_pred_classes,
        target_names=class_names,
        output_dict=True,
        zero_division=0 # Evita errores si alguna clase no se predice nunca
    )

    # Convertimos a DataFrame y limpiamos
    df = pd.DataFrame(report).transpose()
    df = df.drop(['accuracy', 'macro avg', 'weighted avg'])

    # 4. Heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(df.iloc[:, :3], annot=True, cmap='RdYlGn', fmt='.2f', vmin=0, vmax=1)
    plt.title('Boletín de Notas: Precision vs Recall')
    plt.show()

# USARLO:
# Asegúrate de pasar el BATCH_SIZE correcto (el mismo que usaste en valid_gen)
plot_classification_report(model, valid_gen, len(X_valid_ram)//batch_size)
# Out:
# Generando predicciones... esto puede tardar unos segundos.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt

def visualize_errors(model, X_data, y_data):
    print("Analizando errores... (Prediciendo todo el set)")

    # 1. Predecir todo
    # Normalizamos al vuelo (/255.0) porque en RAM están como uint8
    preds = model.predict(X_data.astype('float32') / 255.0, verbose=0)

    # Obtenemos la clase predicha (Número)
    pred_classes = np.argmax(preds, axis=1)

    # 2. Obtener la clase real (CORRECCIÓN AQUÍ)
    # Como y_data son textos ('Helipad'), los convertimos a números
    class_names = list(categories.values()) # ['Cargo plane', 'Small car', ...]

    # Mapeamos: 'Helipad' -> 9 (o el número que sea)
    true_classes = np.array([class_names.index(cat) for cat in y_data])

    # 3. Buscar discrepancias
    errors = np.where(pred_classes != true_classes)[0]
    print(f"Total de errores: {len(errors)} de {len(X_data)} ({(len(errors)/len(X_data))*100:.2f}%)")

    # Si no hay errores, salimos
    if len(errors) == 0:
        print("¡Increíble! 0 errores encontrados.")
        return

    # 4. Mostrar 10 errores aleatorios
    # Si hay menos de 10 errores, los mostramos todos
    n_show = min(10, len(errors))
    indices_to_show = np.random.choice(errors, size=n_show, replace=False)

    plt.figure(figsize=(20, 8))
    for i, idx in enumerate(indices_to_show):
        plt.subplot(2, 5, i+1)

        # Imagen (Original de RAM)
        img = X_data[idx]

        # Si usas OpenCV, recuerda que carga en BGR, matplotlib quiere RGB
        # Si ves los colores raros (azul en vez de rojo), descomenta la linea de abajo:
        # img = img[:, :, ::-1]
        plt.imshow(img)

        # Etiquetas
        true_label = class_names[true_classes[idx]]
        pred_label = class_names[pred_classes[idx]]

        # Confianza: ¿Cómo de seguro estaba el modelo de su error?
        conf = np.max(preds[idx]) * 100

        # T = Truth (Verdad), P = Prediction (Predicción)
        plt.title(f"Real: {true_label}\nPred: {pred_label}\nConf: {conf:.1f}%", color='red', fontsize=10)
        plt.axis('off')

    plt.suptitle("Galería de los Horrores: Errores del Modelo", fontsize=16)
    plt.tight_layout()
    plt.show()

# USARLO:
visualize_errors(model, X_valid_ram, y_valid_ram)
# Out:
# Analizando errores... (Prediciendo todo el set)
# Total de errores: 822 de 1875 (43.84%)

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
# 1. Usamos los datos que YA cargamos en RAM (Velocidad: 100x más rápido)
# model.predict procesa todo el bloque de golpe (Batch processing)
print("Prediciendo todo el validación de golpe...")
predictions = model.predict(X_valid_ram.astype('float32') / 255.0, batch_size=32, verbose=1)

# 2. Sacamos la clase ganadora de cada foto
y_pred_indices = np.argmax(predictions, axis=1) # [0, 5, 2...]

# 3. Convertimos números a nombres (si lo necesitas en texto)
class_names = list(categories.values())
y_pred = [class_names[i] for i in y_pred_indices]

# 4. Sacamos el y_true (La realidad)
# Si y_valid_ram era texto:
y_true = y_valid_ram
# Si y_valid_ram era One-Hot o índices, adáptalo.
# Asumiendo que es la lista de textos que devolvía load_dataset_to_ram:
# (Si usaste mi última función, y_valid_ram es una lista de strings ['Helipad', 'Car'...])
# Out:
# Prediciendo todo el validación de golpe...
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 56.160%
# Mean Recall: 57.315%
# Mean Precision: 59.291%
# > Cargo plane: Recall: 84.746% Precision: 94.340% Specificity: 99.835% Dice: 89.286%
# > Small car: Recall: 64.742% Precision: 83.858% Specificity: 97.348% Dice: 73.070%
# > Bus: Recall: 35.057% Precision: 54.955% Specificity: 97.061% Dice: 42.807%
# > Truck: Recall: 62.241% Precision: 27.778% Specificity: 76.132% Dice: 38.412%
# > Motorboat: Recall: 45.872% Precision: 52.632% Specificity: 97.452% Dice: 49.020%
# > Fishing vessel: Recall: 64.384% Precision: 55.952% Specificity: 97.947% Dice: 59.873%
# > Dump truck: Recall: 39.831% Precision: 67.143% Specificity: 98.691% Dice: 50.000%
# > Excavator: Recall: 56.790% Precision: 63.014% Specificity: 98.495% Dice: 59.740%
# > Building: Recall: 59.780% Precision: 74.061% Specificity: 94.974% Dice: 66.159%
# > Helipad: Recall: 55.556% Precision: 31.250% Specificity: 99.411% Dice: 40.000%
# > Storage tank: Recall: 57.237% Precision: 66.923% Specificity: 97.504% Dice: 61.702%
# > Shipping container: Recall: 40.741% Precision: 57.895% Specificity: 97.701% Dice: 47.826%
# > Pylon: Recall: 78.125% Precision: 40.984% Specificity: 98.047% Dice: 53.763%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('../content/dataset/xview_recognition/xview_test'):
    for filename in filenames:
        image = GenericImage(dirpath[29:] + '/' + filename)
        image.tile = np.array([0, 0, 64, 64])
        obj = GenericObject()
        obj.bb = (0, 0, 64, 64)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))

# %%
import numpy as np
import tensorflow as tf

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}

for idx, ann in enumerate(anns):
    image_data = {
        "image_id": ann.filename.split('/')[-1],
        "filename": ann.filename,
        "width": int(ann.tile[2]),
        "height": int(ann.tile[3])
    }
    predictions_data["images"][idx] = image_data

    # 1. Cargar imagen original
    # Fix: Remove 'gnition/' from the filename path which was incorrectly added
    try:
        image = load_geoimage(ann.filename[8:]) / 255.0
    except Exception as e:
        print(f"Error al cargar la ruta {ann.filename[8:]}. Saltando...")
        continue

    # --- FIX CRÍTICO: Comprobar que la imagen existe y redimensionar a 64x64 ---
    if image is None or image.size == 0:
        print(f"Advertencia: La imagen {ann.filename[8:]} se cargó vacía.")
        continue

    # Redimensionamos explícitamente al input_shape que espera nuestro modelo
    image_resized = tf.image.resize(image, (64, 64)).numpy()

    for obj_pred in ann.objects:
        # Generate prediction usando la imagen redimensionada
        warped_image = np.expand_dims(image_resized, 0)
        predictions = model.predict(warped_image, verbose=0)

        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = float(np.max(predictions)) # Casteado a float estándar de Python para evitar fallos en JSON

        annotation_data = {
            "image_id": ann.filename.split('/')[-1],
            "category_id": pred_category,
            "bbox": [int(x) for x in obj_pred.bb]
        }
        predictions_data["annotations"][idx] = annotation_data

print("Predicciones finalizadas correctamente.")

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)
