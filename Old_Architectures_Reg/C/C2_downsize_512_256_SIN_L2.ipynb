# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Yousef Medhat
# - Alumno 2: Carlos Manzano Izquierdo
# - Alumno 3: Guillermo Bermejo Babiano
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# The -q flag means "quiet" so it doesn't print 10,000 lines and crash your browser
# !unzip -q "/content/drive/MyDrive/DL/xview_recognition.zip" -d "/content/dataset"

print("✅ Unzipping complete!")
# Out:
# replace /content/dataset/xview_recognition/xview_ann_train.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# ✅ Unzipping complete!

# %%
data_dir = '/content/dataset/xview_recognition' # Or whatever the extracted folder is named

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
import warnings
import rasterio
import numpy as np
import cv2

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open('../content/dataset/xview_recognition/'+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)

    img_resized = cv2.resize(img, (64, 64), interpolation=cv2.INTER_AREA)

    return img_resized

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json

# Load database
json_file = '../content/dataset/xview_recognition/xview_ann_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 16871
# Number of validation images: 1875

# %%
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L2
from tensorflow.keras.activations import swish

print('Load model')
model = Sequential()
model.add(Flatten(input_shape=(64, 64, 3)))

# Mantenemos 512, pero añadimos L2 suave para controlar los pesos
model.add(Dense(512, kernel_initializer='he_normal'))
model.add(BatchNormalization())
model.add(Activation('swish'))
# Subimos Dropout a 0.3 o 0.4. El 0.1 actual es muy poco y por eso la linea azul se escapa.
model.add(Dropout(0.3))

# --- CAPA 2: Refinamiento (NUEVA) ---
# Esta capa combina las características de la anterior. Vital para subir accuracy.
model.add(Dense(256, kernel_initializer='he_normal'))
model.add(BatchNormalization())
model.add(Activation('swish'))
model.add(Dropout(0.2))

model.add(Dense(len(categories)))
model.add(Activation('softmax'))
model.summary()
# Out:
# Load model
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)             │ (None, 12288)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 512)            │     6,291,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 13)             │         3,341 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 13)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,429,709 (24.53 MB)
#  Trainable params: 6,428,173 (24.52 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.losses import CategoricalFocalCrossentropy

focal_loss = CategoricalFocalCrossentropy(
    gamma=2.0,        # Fuerza el enfoque en lo difícil
    alpha=0.25,       # Balancea la importancia general
    label_smoothing=0.1,  # Label smoothing para overfitting
    from_logits=False # False porque usamos Softmax al final
)

# Learning rate is changed to 0.005
# opt = SGD(
#     learning_rate=0.005,
#     momentum=0.9,
#     nesterov=True,
#     clipnorm=1.0
# )
opt = AdamW(learning_rate=0.001, weight_decay=1e-4)
model.compile(optimizer=opt, loss=focal_loss, metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_delta=0.001,
    cooldown=1,
    min_lr=1e-6,
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
def generator_from_ram(X_data, y_data, batch_size, do_shuffle=False, do_augment=False):
    # Índices para saber qué foto toca
    indices = np.arange(len(X_data))

    while True:
        if do_shuffle:
            np.random.shuffle(indices)

        # Troceamos los índices en batches
        for i in range(0, len(indices), batch_size):
            batch_indices = indices[i:i+batch_size]

            # Cogemos las imágenes crudas de la RAM
            batch_images_raw = X_data[batch_indices]
            batch_cats = y_data[batch_indices]

            images, labels = [], []

            for j in range(len(batch_images_raw)):
                # Copiamos la imagen para no modificar la original en RAM
                img = batch_images_raw[j].copy()
                cat = batch_cats[j]

                # ==========================================
                # AUGMENTATION "SAFE MODE" (Solo Brillo y Giros)
                # ==========================================
                if do_augment:
                    # 1. ROTACIÓN (90, 180, 270)
                    k = np.random.randint(0, 4)
                    if k > 0: img = np.rot90(img, k)

                    # 2. FLIP (Espejo)
                    if np.random.rand() > 0.5:
                        code = np.random.choice([0, 1])
                        img = cv2.flip(img, code)

                    # 3. BRILLO/CONTRASTE (Sin Traslación)
                    # Lo aplicamos el 80% de las veces para dar variedad de color
                    if np.random.rand() > 0.2:
                        alpha = np.random.uniform(0.8, 1.2) # Contraste
                        beta = np.random.uniform(-25, 25)   # Brillo
                        img = cv2.convertScaleAbs(img, alpha=alpha, beta=beta)
                # ==========================================

                # Normalización (Aquí pasamos a float)
                img_float = img.astype(np.float32) / 255.0

                # One-Hot Encoding
                prob = np.zeros(len(categories))
                prob[list(categories.values()).index(cat)] = 1

                images.append(img_float)
                labels.append(prob)

            yield np.array(images), np.array(labels)

# %%
import numpy as np
import cv2
from tqdm import tqdm  # Barra de progreso

def load_dataset_to_ram(objs_list, target_size=(64, 64)):
    print(f"Cargando {len(objs_list)} imágenes en RAM... ")

    X_data = []
    y_labels = []

    for filename, obj in tqdm(objs_list):
        # 1. Cargar
        img = load_geoimage(filename)

        # 2. Redimensionar siempre a 64x64
        # (Es vital para poder apilarlas en un array de Numpy)
        if img.shape[:2] != target_size:
            img = cv2.resize(img, target_size, interpolation=cv2.INTER_AREA)

        # 3. Guardar tal cual (uint8, 0-255).
        # NO dividas por 255 aquí o ocuparás 4 veces más RAM.
        X_data.append(img)
        y_labels.append(obj.category)

    # Convertir a Bloque Numpy
    X_data = np.array(X_data, dtype='uint8')
    y_labels = np.array(y_labels)

    print(f"¡Carga lista! Ocupa en RAM: {X_data.nbytes / 1024 / 1024:.2f} MB")
    return X_data, y_labels

# %%
def balance_dataset_list(objs):
    # 1. Contamos cuántos hay de cada clase originalmente
    counts = {}
    for _, obj in objs:
        c = obj.category
        counts[c] = counts.get(c, 0) + 1

    print("--- CONTEO ORIGINAL ---")
    print(counts)

    balanced_objs = []

    # CONFIGURACIÓN DE OBJETIVOS
    TARGET_STANDARD = 2000  # Objetivo para la mayoría (Pylons, Barcos, Camiones...)
    TARGET_TINY = 1000      # Objetivo conservador para las muy pequeñas (Helipuertos)
    TINY_THRESHOLD = 200    # Si tiene menos de 200, usamos el objetivo 'Tiny'

    for filename, obj in objs:
        # Siempre añadimos la imagen original
        balanced_objs.append((filename, obj))

        current_count = counts[obj.category]

        # Determinamos el objetivo según el tamaño de la clase
        if current_count < TINY_THRESHOLD:
            target = TARGET_TINY  # Caso Helipuertos (111 -> ~1000)
        else:
            target = TARGET_STANDARD # Caso Pylons/Trucks (300 -> ~2000)

        # Si estamos por debajo del objetivo, calculamos copias
        if current_count < target:
            # Ejemplo Pylon (312): 2000 / 312 = 6.4 -> Multiplicador 6 (Total 7 copias)
            # Ejemplo Helipuerto (111): 1000 / 111 = 9.0 -> Multiplicador 9 (Total 10 copias)
            # Restamos 1 porque ya añadimos la original arriba
            multiplier = int(target / current_count) - 1

            # Solo añadimos si el multiplicador es positivo
            if multiplier > 0:
                for _ in range(multiplier):
                    balanced_objs.append((filename, obj))

    print(f"\n--- DATASET BALANCEADO ---")
    print(f"De {len(objs)} imágenes pasamos a {len(balanced_objs)} imágenes virtuales.")

    return balanced_objs

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]

# PASO 1: Balanceo de clases
print("--- FASE 1: Balanceo ---")
objs_train_balanced = balance_dataset_list(objs_train)


# PASO 2: Cargar todo en RAM
# -------------------------------------------------------
print("\n--- FASE 2: Carga en RAM ---")
# Train con lista inflada
X_train_ram, y_train_ram = load_dataset_to_ram(objs_train_balanced)
# Valid con lista normal
X_valid_ram, y_valid_ram = load_dataset_to_ram(objs_valid)

# PASO 3: Crear Generadores Rápidos
# -------------------------------------------------------
batch_size = 32

train_gen = generator_from_ram(
    X_train_ram, y_train_ram,
    batch_size=batch_size,
    do_shuffle=True,
    do_augment=True
)

valid_gen = generator_from_ram(
    X_valid_ram, y_valid_ram,
    batch_size=batch_size,
    do_shuffle=False,
    do_augment=False
)
# Out:
# --- FASE 1: Balanceo ---
# --- CONTEO ORIGINAL ---
# {'Bus': 1594, 'Cargo plane': 576, 'Truck': 1969, 'Building': 3231, 'Fishing vessel': 633, 'Small car': 2995, 'Pylon': 280, 'Shipping container': 1388, 'Dump truck': 1118, 'Motorboat': 960, 'Storage tank': 1317, 'Excavator': 708, 'Helipad': 102}
#
# --- DATASET BALANCEADO ---
# De 16871 imágenes pasamos a 23453 imágenes virtuales.
#
# --- FASE 2: Carga en RAM ---
# Cargando 23453 imágenes en RAM...
# 100%|██████████| 23453/23453 [01:10<00:00, 332.65it/s]
# ¡Carga lista! Ocupa en RAM: 274.84 MB
# Cargando 1875 imágenes en RAM...
# 100%|██████████| 1875/1875 [00:06<00:00, 290.56it/s]
# ¡Carga lista! Ocupa en RAM: 21.97 MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_class_balance(original_objs, balanced_objs):
    # 1. Contar Originales
    counts_orig = {}
    for _, obj in original_objs:
        counts_orig[obj.category] = counts_orig.get(obj.category, 0) + 1

    # 2. Contar Balanceados
    counts_bal = {}
    for _, obj in balanced_objs:
        counts_bal[obj.category] = counts_bal.get(obj.category, 0) + 1

    # Preparar datos para plot
    classes = list(counts_orig.keys())
    # Ordenamos por cantidad original para que quede bonito
    classes.sort(key=lambda x: counts_orig[x], reverse=True)

    vals_orig = [counts_orig[c] for c in classes]
    vals_bal = [counts_bal[c] for c in classes]

    x = range(len(classes))
    width = 0.35

    plt.figure(figsize=(15, 6))
    plt.bar([i - width/2 for i in x], vals_orig, width, label='Original', color='red', alpha=0.6)
    plt.bar([i + width/2 for i in x], vals_bal, width, label='Balanceado (Virtual)', color='green', alpha=0.6)

    plt.xticks(x, classes, rotation=45, ha='right')
    plt.ylabel('Número de Imágenes')
    plt.title('Impacto del Oversampling en el Dataset')
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# USARLO:
plot_class_balance(objs_train, objs_train_balanced)

# %%
import math
import numpy as np

print('Training model')
epochs = 100
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_gen, steps_per_epoch=train_steps, validation_data=valid_gen, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2523 - loss: 0.4815
# Epoch 1: val_accuracy improved from -inf to 0.32000, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.2529 - loss: 0.4810 - val_accuracy: 0.3200 - val_loss: 0.4066 - learning_rate: 0.0010
# Epoch 2/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3629 - loss: 0.4037
# Epoch 2: val_accuracy improved from 0.32000 to 0.32640, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.3630 - loss: 0.4036 - val_accuracy: 0.3264 - val_loss: 0.3995 - learning_rate: 0.0010
# Epoch 3/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3999 - loss: 0.3792
# Epoch 3: val_accuracy improved from 0.32640 to 0.35947, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3999 - loss: 0.3792 - val_accuracy: 0.3595 - val_loss: 0.3975 - learning_rate: 0.0010
# Epoch 4/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4258 - loss: 0.3686
# Epoch 4: val_accuracy improved from 0.35947 to 0.37653, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4259 - loss: 0.3686 - val_accuracy: 0.3765 - val_loss: 0.3743 - learning_rate: 0.0010
# Epoch 5/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4373 - loss: 0.3596
# Epoch 5: val_accuracy improved from 0.37653 to 0.37813, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4373 - loss: 0.3596 - val_accuracy: 0.3781 - val_loss: 0.3695 - learning_rate: 0.0010
# Epoch 6/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4490 - loss: 0.3522
# Epoch 6: val_accuracy improved from 0.37813 to 0.39360, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4490 - loss: 0.3522 - val_accuracy: 0.3936 - val_loss: 0.3617 - learning_rate: 0.0010
# Epoch 7/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4541 - loss: 0.3463
# Epoch 7: val_accuracy did not improve from 0.39360
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4541 - loss: 0.3463 - val_accuracy: 0.3909 - val_loss: 0.3693 - learning_rate: 0.0010
# Epoch 8/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4748 - loss: 0.3368
# Epoch 8: val_accuracy improved from 0.39360 to 0.40427, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4748 - loss: 0.3369 - val_accuracy: 0.4043 - val_loss: 0.3639 - learning_rate: 0.0010
# Epoch 9/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4709 - loss: 0.3413
# Epoch 9: val_accuracy improved from 0.40427 to 0.43307, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4710 - loss: 0.3412 - val_accuracy: 0.4331 - val_loss: 0.3513 - learning_rate: 0.0010
# Epoch 10/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4793 - loss: 0.3304
# Epoch 10: val_accuracy did not improve from 0.43307
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4793 - loss: 0.3304 - val_accuracy: 0.4155 - val_loss: 0.3486 - learning_rate: 0.0010
# Epoch 11/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4829 - loss: 0.3298
# Epoch 11: val_accuracy did not improve from 0.43307
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4830 - loss: 0.3298 - val_accuracy: 0.4085 - val_loss: 0.3516 - learning_rate: 0.0010
# Epoch 12/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4908 - loss: 0.3263
# Epoch 12: val_accuracy improved from 0.43307 to 0.45653, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4908 - loss: 0.3263 - val_accuracy: 0.4565 - val_loss: 0.3369 - learning_rate: 0.0010
# Epoch 13/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4996 - loss: 0.3254
# Epoch 13: val_accuracy improved from 0.45653 to 0.46347, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.4995 - loss: 0.3254 - val_accuracy: 0.4635 - val_loss: 0.3343 - learning_rate: 0.0010
# Epoch 14/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5027 - loss: 0.3225
# Epoch 14: val_accuracy did not improve from 0.46347
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5028 - loss: 0.3225 - val_accuracy: 0.4128 - val_loss: 0.3589 - learning_rate: 0.0010
# Epoch 15/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5072 - loss: 0.3202
# Epoch 15: val_accuracy improved from 0.46347 to 0.47147, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5072 - loss: 0.3202 - val_accuracy: 0.4715 - val_loss: 0.3355 - learning_rate: 0.0010
# Epoch 16/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4998 - loss: 0.3177
# Epoch 16: val_accuracy did not improve from 0.47147
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4999 - loss: 0.3177 - val_accuracy: 0.4160 - val_loss: 0.3482 - learning_rate: 0.0010
# Epoch 17/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5203 - loss: 0.3109
# Epoch 17: val_accuracy improved from 0.47147 to 0.48747, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5203 - loss: 0.3109 - val_accuracy: 0.4875 - val_loss: 0.3303 - learning_rate: 0.0010
# Epoch 18/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5208 - loss: 0.3121
# Epoch 18: val_accuracy improved from 0.48747 to 0.48800, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5208 - loss: 0.3121 - val_accuracy: 0.4880 - val_loss: 0.3248 - learning_rate: 0.0010
# Epoch 19/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5249 - loss: 0.3076
# Epoch 19: val_accuracy did not improve from 0.48800
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.5249 - loss: 0.3076 - val_accuracy: 0.4565 - val_loss: 0.3361 - learning_rate: 0.0010
# Epoch 20/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5288 - loss: 0.3101
# Epoch 20: val_accuracy did not improve from 0.48800
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5288 - loss: 0.3101 - val_accuracy: 0.4720 - val_loss: 0.3315 - learning_rate: 0.0010
# Epoch 21/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5348 - loss: 0.3058
# Epoch 21: val_accuracy did not improve from 0.48800
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5348 - loss: 0.3058 - val_accuracy: 0.4816 - val_loss: 0.3199 - learning_rate: 0.0010
# Epoch 22/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5355 - loss: 0.3057
# Epoch 22: val_accuracy did not improve from 0.48800
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5355 - loss: 0.3057 - val_accuracy: 0.4869 - val_loss: 0.3332 - learning_rate: 0.0010
# Epoch 23/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5254 - loss: 0.3034
# Epoch 23: val_accuracy did not improve from 0.48800
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5254 - loss: 0.3034 - val_accuracy: 0.4683 - val_loss: 0.3254 - learning_rate: 0.0010
# Epoch 24/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5430 - loss: 0.3008
# Epoch 24: val_accuracy improved from 0.48800 to 0.49227, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5430 - loss: 0.3009 - val_accuracy: 0.4923 - val_loss: 0.3216 - learning_rate: 0.0010
# Epoch 25/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5441 - loss: 0.2990
# Epoch 25: val_accuracy did not improve from 0.49227
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5440 - loss: 0.2990 - val_accuracy: 0.4779 - val_loss: 0.3184 - learning_rate: 0.0010
# Epoch 26/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5414 - loss: 0.3001
# Epoch 26: val_accuracy did not improve from 0.49227
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5414 - loss: 0.3001 - val_accuracy: 0.4640 - val_loss: 0.3300 - learning_rate: 0.0010
# Epoch 27/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5359 - loss: 0.3005
# Epoch 27: val_accuracy improved from 0.49227 to 0.51200, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5359 - loss: 0.3005 - val_accuracy: 0.5120 - val_loss: 0.3141 - learning_rate: 0.0010
# Epoch 28/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5562 - loss: 0.2947
# Epoch 28: val_accuracy did not improve from 0.51200
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5562 - loss: 0.2947 - val_accuracy: 0.4987 - val_loss: 0.3119 - learning_rate: 0.0010
# Epoch 29/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5483 - loss: 0.2984
# Epoch 29: val_accuracy did not improve from 0.51200
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5483 - loss: 0.2983 - val_accuracy: 0.5115 - val_loss: 0.3091 - learning_rate: 0.0010
# Epoch 30/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5538 - loss: 0.2924
# Epoch 30: val_accuracy improved from 0.51200 to 0.52587, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5538 - loss: 0.2925 - val_accuracy: 0.5259 - val_loss: 0.3012 - learning_rate: 0.0010
# Epoch 31/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5530 - loss: 0.2933
# Epoch 31: val_accuracy did not improve from 0.52587
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5530 - loss: 0.2932 - val_accuracy: 0.4651 - val_loss: 0.3195 - learning_rate: 0.0010
# Epoch 32/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5661 - loss: 0.2891
# Epoch 32: val_accuracy did not improve from 0.52587
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5661 - loss: 0.2891 - val_accuracy: 0.4931 - val_loss: 0.3129 - learning_rate: 0.0010
# Epoch 33/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5659 - loss: 0.2900
# Epoch 33: val_accuracy did not improve from 0.52587
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5659 - loss: 0.2900 - val_accuracy: 0.4989 - val_loss: 0.3180 - learning_rate: 0.0010
# Epoch 34/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5650 - loss: 0.2870
# Epoch 34: val_accuracy did not improve from 0.52587
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5650 - loss: 0.2870 - val_accuracy: 0.4949 - val_loss: 0.3126 - learning_rate: 0.0010
# Epoch 35/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5666 - loss: 0.2861
# Epoch 35: val_accuracy did not improve from 0.52587
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5666 - loss: 0.2861 - val_accuracy: 0.5008 - val_loss: 0.3120 - learning_rate: 0.0010
# Epoch 36/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5749 - loss: 0.2828
# Epoch 36: val_accuracy improved from 0.52587 to 0.54827, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5750 - loss: 0.2828 - val_accuracy: 0.5483 - val_loss: 0.2944 - learning_rate: 5.0000e-04
# Epoch 37/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5736 - loss: 0.2807
# Epoch 37: val_accuracy did not improve from 0.54827
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5736 - loss: 0.2806 - val_accuracy: 0.5269 - val_loss: 0.2984 - learning_rate: 5.0000e-04
# Epoch 38/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5821 - loss: 0.2797
# Epoch 38: val_accuracy did not improve from 0.54827
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5821 - loss: 0.2797 - val_accuracy: 0.5317 - val_loss: 0.2960 - learning_rate: 5.0000e-04
# Epoch 39/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5889 - loss: 0.2781
# Epoch 39: val_accuracy did not improve from 0.54827
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5889 - loss: 0.2781 - val_accuracy: 0.5355 - val_loss: 0.2962 - learning_rate: 5.0000e-04
# Epoch 40/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5850 - loss: 0.2775
# Epoch 40: val_accuracy improved from 0.54827 to 0.55413, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5850 - loss: 0.2775 - val_accuracy: 0.5541 - val_loss: 0.2869 - learning_rate: 5.0000e-04
# Epoch 41/100
# 521/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5874 - loss: 0.2767
# Epoch 41: val_accuracy did not improve from 0.55413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5874 - loss: 0.2767 - val_accuracy: 0.5195 - val_loss: 0.3021 - learning_rate: 5.0000e-04
# Epoch 42/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5876 - loss: 0.2764
# Epoch 42: val_accuracy improved from 0.55413 to 0.55680, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5876 - loss: 0.2764 - val_accuracy: 0.5568 - val_loss: 0.2853 - learning_rate: 5.0000e-04
# Epoch 43/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5890 - loss: 0.2737
# Epoch 43: val_accuracy improved from 0.55680 to 0.56000, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5890 - loss: 0.2737 - val_accuracy: 0.5600 - val_loss: 0.2827 - learning_rate: 5.0000e-04
# Epoch 44/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6043 - loss: 0.2696
# Epoch 44: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6043 - loss: 0.2696 - val_accuracy: 0.5483 - val_loss: 0.2926 - learning_rate: 5.0000e-04
# Epoch 45/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5891 - loss: 0.2745
# Epoch 45: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5891 - loss: 0.2745 - val_accuracy: 0.5589 - val_loss: 0.2850 - learning_rate: 5.0000e-04
# Epoch 46/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6034 - loss: 0.2694
# Epoch 46: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6034 - loss: 0.2694 - val_accuracy: 0.5488 - val_loss: 0.2878 - learning_rate: 5.0000e-04
# Epoch 47/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5952 - loss: 0.2710
# Epoch 47: val_accuracy improved from 0.56000 to 0.56533, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5952 - loss: 0.2710 - val_accuracy: 0.5653 - val_loss: 0.2835 - learning_rate: 5.0000e-04
# Epoch 48/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6011 - loss: 0.2703
# Epoch 48: val_accuracy did not improve from 0.56533
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6011 - loss: 0.2703 - val_accuracy: 0.5253 - val_loss: 0.2979 - learning_rate: 5.0000e-04
# Epoch 49/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6044 - loss: 0.2692
# Epoch 49: val_accuracy did not improve from 0.56533
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6044 - loss: 0.2692 - val_accuracy: 0.5504 - val_loss: 0.2835 - learning_rate: 2.5000e-04
# Epoch 50/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6090 - loss: 0.2661
# Epoch 50: val_accuracy improved from 0.56533 to 0.56587, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6090 - loss: 0.2661 - val_accuracy: 0.5659 - val_loss: 0.2792 - learning_rate: 2.5000e-04
# Epoch 51/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6090 - loss: 0.2647
# Epoch 51: val_accuracy did not improve from 0.56587
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6090 - loss: 0.2647 - val_accuracy: 0.5648 - val_loss: 0.2800 - learning_rate: 2.5000e-04
# Epoch 52/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6063 - loss: 0.2649
# Epoch 52: val_accuracy did not improve from 0.56587
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6064 - loss: 0.2649 - val_accuracy: 0.5413 - val_loss: 0.2840 - learning_rate: 2.5000e-04
# Epoch 53/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6190 - loss: 0.2620
# Epoch 53: val_accuracy improved from 0.56587 to 0.57440, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6190 - loss: 0.2620 - val_accuracy: 0.5744 - val_loss: 0.2758 - learning_rate: 2.5000e-04
# Epoch 54/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6027 - loss: 0.2663
# Epoch 54: val_accuracy did not improve from 0.57440
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6027 - loss: 0.2663 - val_accuracy: 0.5600 - val_loss: 0.2804 - learning_rate: 2.5000e-04
# Epoch 55/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6204 - loss: 0.2624
# Epoch 55: val_accuracy improved from 0.57440 to 0.57867, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6204 - loss: 0.2624 - val_accuracy: 0.5787 - val_loss: 0.2721 - learning_rate: 2.5000e-04
# Epoch 56/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6125 - loss: 0.2627
# Epoch 56: val_accuracy did not improve from 0.57867
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6125 - loss: 0.2627 - val_accuracy: 0.5659 - val_loss: 0.2779 - learning_rate: 2.5000e-04
# Epoch 57/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6045 - loss: 0.2672
# Epoch 57: val_accuracy improved from 0.57867 to 0.58080, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6045 - loss: 0.2672 - val_accuracy: 0.5808 - val_loss: 0.2742 - learning_rate: 2.5000e-04
# Epoch 58/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6171 - loss: 0.2628
# Epoch 58: val_accuracy did not improve from 0.58080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6170 - loss: 0.2628 - val_accuracy: 0.5744 - val_loss: 0.2785 - learning_rate: 2.5000e-04
# Epoch 59/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6164 - loss: 0.2600
# Epoch 59: val_accuracy did not improve from 0.58080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6163 - loss: 0.2600 - val_accuracy: 0.5803 - val_loss: 0.2756 - learning_rate: 2.5000e-04
# Epoch 60/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6237 - loss: 0.2609
# Epoch 60: val_accuracy did not improve from 0.58080
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6237 - loss: 0.2609 - val_accuracy: 0.5664 - val_loss: 0.2793 - learning_rate: 2.5000e-04
# Epoch 61/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6146 - loss: 0.2603
# Epoch 61: val_accuracy did not improve from 0.58080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6146 - loss: 0.2603 - val_accuracy: 0.5605 - val_loss: 0.2763 - learning_rate: 1.2500e-04
# Epoch 62/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6230 - loss: 0.2589
# Epoch 62: val_accuracy improved from 0.58080 to 0.58400, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6229 - loss: 0.2589 - val_accuracy: 0.5840 - val_loss: 0.2719 - learning_rate: 1.2500e-04
# Epoch 63/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6174 - loss: 0.2603
# Epoch 63: val_accuracy improved from 0.58400 to 0.58560, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6174 - loss: 0.2603 - val_accuracy: 0.5856 - val_loss: 0.2728 - learning_rate: 1.2500e-04
# Epoch 64/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6235 - loss: 0.2559
# Epoch 64: val_accuracy did not improve from 0.58560
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6235 - loss: 0.2559 - val_accuracy: 0.5723 - val_loss: 0.2725 - learning_rate: 1.2500e-04
# Epoch 65/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6211 - loss: 0.2594
# Epoch 65: val_accuracy did not improve from 0.58560
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6212 - loss: 0.2594 - val_accuracy: 0.5736 - val_loss: 0.2731 - learning_rate: 1.2500e-04
# Epoch 66/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6343 - loss: 0.2528
# Epoch 66: val_accuracy did not improve from 0.58560
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6343 - loss: 0.2529 - val_accuracy: 0.5832 - val_loss: 0.2698 - learning_rate: 6.2500e-05
# Epoch 67/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6254 - loss: 0.2573
# Epoch 67: val_accuracy did not improve from 0.58560
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6254 - loss: 0.2573 - val_accuracy: 0.5792 - val_loss: 0.2720 - learning_rate: 6.2500e-05
# Epoch 68/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6244 - loss: 0.2559
# Epoch 68: val_accuracy did not improve from 0.58560
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6244 - loss: 0.2559 - val_accuracy: 0.5835 - val_loss: 0.2715 - learning_rate: 6.2500e-05
# Epoch 69/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6316 - loss: 0.2542
# Epoch 69: val_accuracy improved from 0.58560 to 0.58613, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.6315 - loss: 0.2542 - val_accuracy: 0.5861 - val_loss: 0.2700 - learning_rate: 6.2500e-05
# Epoch 70/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6278 - loss: 0.2576
# Epoch 70: val_accuracy did not improve from 0.58613
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6278 - loss: 0.2576 - val_accuracy: 0.5851 - val_loss: 0.2698 - learning_rate: 6.2500e-05
# Epoch 71/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6243 - loss: 0.2573
# Epoch 71: val_accuracy improved from 0.58613 to 0.58827, saving model to model.keras
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6243 - loss: 0.2573 - val_accuracy: 0.5883 - val_loss: 0.2698 - learning_rate: 6.2500e-05
# Epoch 72/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6336 - loss: 0.2562
# Epoch 72: val_accuracy did not improve from 0.58827
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6335 - loss: 0.2562 - val_accuracy: 0.5829 - val_loss: 0.2699 - learning_rate: 3.1250e-05
# Epoch 73/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6194 - loss: 0.2595
# Epoch 73: val_accuracy did not improve from 0.58827
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6194 - loss: 0.2595 - val_accuracy: 0.5856 - val_loss: 0.2697 - learning_rate: 3.1250e-05
# Epoch 74/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6292 - loss: 0.2541
# Epoch 74: val_accuracy improved from 0.58827 to 0.59093, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.6292 - loss: 0.2541 - val_accuracy: 0.5909 - val_loss: 0.2684 - learning_rate: 3.1250e-05
# Epoch 75/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6279 - loss: 0.2567
# Epoch 75: val_accuracy did not improve from 0.59093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6279 - loss: 0.2567 - val_accuracy: 0.5845 - val_loss: 0.2693 - learning_rate: 3.1250e-05
# Epoch 76/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6259 - loss: 0.2542
# Epoch 76: val_accuracy did not improve from 0.59093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.6259 - loss: 0.2542 - val_accuracy: 0.5813 - val_loss: 0.2714 - learning_rate: 3.1250e-05
# Epoch 77/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6297 - loss: 0.2561
# Epoch 77: val_accuracy did not improve from 0.59093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6297 - loss: 0.2561 - val_accuracy: 0.5776 - val_loss: 0.2723 - learning_rate: 3.1250e-05
# Epoch 78/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6293 - loss: 0.2566
# Epoch 78: val_accuracy did not improve from 0.59093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6293 - loss: 0.2566 - val_accuracy: 0.5797 - val_loss: 0.2694 - learning_rate: 3.1250e-05
# Epoch 79/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6353 - loss: 0.2544
# Epoch 79: val_accuracy did not improve from 0.59093
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6353 - loss: 0.2544 - val_accuracy: 0.5899 - val_loss: 0.2695 - learning_rate: 3.1250e-05
# Epoch 80/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6328 - loss: 0.2551
# Epoch 80: val_accuracy did not improve from 0.59093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6328 - loss: 0.2551 - val_accuracy: 0.5856 - val_loss: 0.2695 - learning_rate: 1.5625e-05
# Epoch 81/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6279 - loss: 0.2536
# Epoch 81: val_accuracy did not improve from 0.59093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.6279 - loss: 0.2536 - val_accuracy: 0.5856 - val_loss: 0.2700 - learning_rate: 1.5625e-05
# Epoch 82/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6214 - loss: 0.2549
# Epoch 82: val_accuracy did not improve from 0.59093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6214 - loss: 0.2549 - val_accuracy: 0.5861 - val_loss: 0.2702 - learning_rate: 1.5625e-05
# Epoch 83/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6303 - loss: 0.2547
# Epoch 83: val_accuracy did not improve from 0.59093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6303 - loss: 0.2547 - val_accuracy: 0.5856 - val_loss: 0.2707 - learning_rate: 1.5625e-05
# Epoch 84/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6312 - loss: 0.2548
# Epoch 84: val_accuracy did not improve from 0.59093
#
# Epoch 84: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6311 - loss: 0.2548 - val_accuracy: 0.5851 - val_loss: 0.2704 - learning_rate: 1.5625e-05
# Epoch 85/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6295 - loss: 0.2551
# Epoch 85: val_accuracy did not improve from 0.59093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6295 - loss: 0.2551 - val_accuracy: 0.5883 - val_loss: 0.2694 - learning_rate: 7.8125e-06
# Epoch 86/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6273 - loss: 0.2569
# Epoch 86: val_accuracy did not improve from 0.59093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6273 - loss: 0.2569 - val_accuracy: 0.5835 - val_loss: 0.2701 - learning_rate: 7.8125e-06
# Epoch 87/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6309 - loss: 0.2546
# Epoch 87: val_accuracy did not improve from 0.59093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6309 - loss: 0.2546 - val_accuracy: 0.5835 - val_loss: 0.2698 - learning_rate: 7.8125e-06
# Epoch 88/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6378 - loss: 0.2537
# Epoch 88: val_accuracy did not improve from 0.59093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6377 - loss: 0.2537 - val_accuracy: 0.5851 - val_loss: 0.2703 - learning_rate: 7.8125e-06
# Epoch 89/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6310 - loss: 0.2543
# Epoch 89: val_accuracy did not improve from 0.59093
#
# Epoch 89: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6310 - loss: 0.2543 - val_accuracy: 0.5840 - val_loss: 0.2705 - learning_rate: 7.8125e-06
# Epoch 89: early stopping
# Restoring model weights from the end of the best epoch: 74.
# Best validation model: epoch 74  - val_accuracy 0.5909333229064941

# %%
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(16, 5))

    # Gráfica de Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training acc')
    plt.plot(epochs, val_acc, 'ro-', label='Validation acc')
    plt.title('Accuracy: Train vs Validation')
    plt.legend()
    plt.grid(True)

    # Gráfica de Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
    plt.title('Loss: Train vs Validation')
    plt.legend()
    plt.grid(True)

    plt.show()

# USARLO:
plot_history(h)

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
# 1. Usamos los datos que YA cargamos en RAM (Velocidad: 100x más rápido)
# model.predict procesa todo el bloque de golpe (Batch processing)
print("Prediciendo todo el validación de golpe...")
predictions = model.predict(X_valid_ram.astype('float32') / 255.0, batch_size=32, verbose=1)

# 2. Sacamos la clase ganadora de cada foto
y_pred_indices = np.argmax(predictions, axis=1) # [0, 5, 2...]

# 3. Convertimos números a nombres (si lo necesitas en texto)
class_names = list(categories.values())
y_pred = [class_names[i] for i in y_pred_indices]

# 4. Sacamos el y_true (La realidad)
# Si y_valid_ram era texto:
y_true = y_valid_ram
# Si y_valid_ram era One-Hot o índices, adáptalo.
# Asumiendo que es la lista de textos que devolvía load_dataset_to_ram:
# (Si usaste mi última función, y_valid_ram es una lista de strings ['Helipad', 'Car'...])
# Out:
# Prediciendo todo el validación de golpe...
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 58.613%
# Mean Recall: 60.036%
# Mean Precision: 57.470%
# > Cargo plane: Recall: 84.746% Precision: 94.340% Specificity: 99.835% Dice: 89.286%
# > Small car: Recall: 81.459% Precision: 71.277% Specificity: 93.014% Dice: 76.028%
# > Bus: Recall: 51.149% Precision: 57.792% Specificity: 96.179% Dice: 54.268%
# > Truck: Recall: 19.087% Precision: 38.655% Specificity: 95.532% Dice: 25.556%
# > Motorboat: Recall: 55.046% Precision: 43.796% Specificity: 95.640% Dice: 48.780%
# > Fishing vessel: Recall: 68.493% Precision: 38.760% Specificity: 95.616% Dice: 49.505%
# > Dump truck: Recall: 45.763% Precision: 57.447% Specificity: 97.723% Dice: 50.943%
# > Excavator: Recall: 74.074% Precision: 52.632% Specificity: 96.990% Dice: 61.538%
# > Building: Recall: 69.972% Precision: 65.974% Specificity: 91.336% Dice: 67.914%
# > Helipad: Recall: 55.556% Precision: 62.500% Specificity: 99.839% Dice: 58.824%
# > Storage tank: Recall: 41.447% Precision: 79.747% Specificity: 99.071% Dice: 54.545%
# > Shipping container: Recall: 55.556% Precision: 46.875% Specificity: 95.115% Dice: 50.847%
# > Pylon: Recall: 78.125% Precision: 37.313% Specificity: 97.721% Dice: 50.505%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('../content/dataset/xview_recognition/xview_test'):
    for filename in filenames:
        image = GenericImage(dirpath[29:] + '/' + filename)
        image.tile = np.array([0, 0, 64, 64])
        obj = GenericObject()
        obj.bb = (0, 0, 64, 64)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    # Fix: Remove 'gnition/' from the filename path which was incorrectly added in the previous cell
    image = load_geoimage(ann.filename[8:]) / 255.0
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)
