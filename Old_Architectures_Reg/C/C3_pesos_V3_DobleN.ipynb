# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Yousef Medhat
# - Alumno 2: Carlos Manzano Izquierdo
# - Alumno 3: Guillermo Bermejo Babiano
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# The -q flag means "quiet" so it doesn't print 10,000 lines and crash your browser
# !unzip -q "/content/drive/MyDrive/DL/xview_recognition.zip" -d "/content/dataset"

print("✅ Unzipping complete!")
# Out:
# replace /content/dataset/xview_recognition/xview_ann_train.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# ✅ Unzipping complete!

# %%
data_dir = '/content/dataset/xview_recognition' # Or whatever the extracted folder is named

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open('../content/dataset/xview_recognition/'+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json

# Load database
json_file = '../content/dataset/xview_recognition/xview_ann_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 16871
# Number of validation images: 1875

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L2

model = Sequential([
    Flatten(input_shape=(64, 64, 3)),
    BatchNormalization(),

    # Block 1: 512 Neurons
    Dense(1024, kernel_initializer='he_normal'), # Eliminado L2
    BatchNormalization(),
    Activation('swish'),
    Dropout(0.1), # Reducido de 0.3 a 0.1 para que retenga más información

    # Block 2: 256 Neurons
    Dense(512, kernel_initializer='he_normal'), # Eliminado L2
    BatchNormalization(),
    Activation('swish'),
    Dropout(0.1), # Reducido de 0.3 a 0.1

    # Block 3: 128 Neurons
    Dense(256, kernel_initializer='he_normal'), # Eliminado L2
    BatchNormalization(),
    Activation('swish'),
    Dropout(0.1), # Reducido de 0.2 a 0.1

    # Output Layer
    Dense(len(categories), activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_4 (Flatten)             │ (None, 12288)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 12288)          │        49,152 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 1024)           │    12,583,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_12 (Activation)      │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_13 (Activation)      │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_14 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 13)             │         3,341 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,299,725 (50.73 MB)
#  Trainable params: 13,271,565 (50.63 MB)
#  Non-trainable params: 28,160 (110.00 KB)

# %%
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.losses import CategoricalFocalCrossentropy

focal_loss = CategoricalFocalCrossentropy(
    gamma=2.0,
    from_logits=False,
    label_smoothing=0.1
)

opt = AdamW(learning_rate=0.001, weight_decay=1e-4)

model.compile(optimizer=opt, loss=focal_loss, metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_delta=0.001,
    verbose=1
)
early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
import numpy as np
import cv2

def generator_from_ram(X_data, y_data, batch_size, class_weights_dict, do_shuffle=False, do_augment=False):
    # 1. PREPARACIÓN DE DATOS
    class_names = list(categories.values())
    class_map = {name: i for i, name in enumerate(class_names)}
    num_classes = len(class_names)

    # Convertimos etiquetas a índices numéricos para ir rápido
    if isinstance(y_data[0], str) or isinstance(y_data[0], np.str_):
        y_indices_all = np.array([class_map[cat] for cat in y_data], dtype='int32')
    else:
        # Si ya son one-hot, los pasamos a índices
        if len(y_data.shape) > 1:
            y_indices_all = np.argmax(y_data, axis=1)
        else:
            y_indices_all = y_data

    # CREAMOS UNA TABLA DE BÚSQUEDA RÁPIDA DE PESOS
    # Esto convierte el diccionario {0: 1.0, 3: 4.0} en un array [1.0, 1.0, 1.0, 4.0...]
    # Así el acceso es instantáneo para la CPU.
    weights_lookup = np.array([class_weights_dict[i] for i in range(len(class_weights_dict))], dtype='float32')

    indices = np.arange(len(X_data))

    while True:
        if do_shuffle:
            np.random.shuffle(indices)

        for i in range(0, len(indices), batch_size):
            batch_indices = indices[i:i+batch_size]
            current_batch_size = len(batch_indices)

            # Reservar memoria
            batch_x = np.zeros((current_batch_size, 64, 64, 3), dtype='float32')
            batch_y = np.zeros((current_batch_size, num_classes), dtype='float32')

            # Datos crudos
            raw_images = X_data[batch_indices]
            raw_labels_indices = y_indices_all[batch_indices] # Índices (0, 3, 5...)

            # --- AQUÍ ESTÁ EL TRUCO: SAMPLE WEIGHTS ---
            # Buscamos el peso que le toca a cada foto de este batch
            batch_weights = weights_lookup[raw_labels_indices]

            for j in range(current_batch_size):
                img = raw_images[j].copy() if do_augment else raw_images[j]

                # Augmentation
                if do_augment:
                    # Rotación
                    k = np.random.randint(0, 4)
                    if k > 0: img = np.rot90(img, k)
                    # Flip
                    if np.random.rand() > 0.5:
                        code = np.random.choice([0, 1])
                        img = cv2.flip(img, code)
                    # Brillo
                    if np.random.rand() > 0.2:
                        alpha = np.random.uniform(0.8, 1.2)
                        beta = np.random.uniform(-25, 25)
                        img = cv2.convertScaleAbs(img, alpha=alpha, beta=beta)

                batch_x[j] = img.astype('float32') / 255.0
                batch_y[j, raw_labels_indices[j]] = 1.0

            # DEVOLVEMOS 3 COSAS: X, Y, W
            yield batch_x, batch_y, batch_weights

# %%
import numpy as np
import cv2
from tqdm import tqdm  # Barra de progreso

def load_dataset_to_ram(objs_list, target_size=(64, 64)):
    print(f"Cargando {len(objs_list)} imágenes en RAM... ")

    X_data = []
    y_labels = []

    for filename, obj in tqdm(objs_list):
        # 1. Cargar
        img = load_geoimage(filename)

        # 2. Redimensionar a target size
        # (Es vital para poder apilarlas en un array de Numpy)
        if img.shape[:2] != target_size:
            img = cv2.resize(img, target_size, interpolation=cv2.INTER_AREA)

        # 3. Guardar tal cual (uint8, 0-255).
        # NO dividas por 255 aquí o ocuparás 4 veces más RAM.
        X_data.append(img)
        y_labels.append(obj.category)

    # Convertir a Bloque Numpy
    X_data = np.array(X_data, dtype='uint8')
    y_labels = np.array(y_labels)

    print(f"¡Carga lista! Ocupa en RAM: {X_data.nbytes / 1024 / 1024:.2f} MB")
    return X_data, y_labels

# %%
def balance_dataset_list(objs):
    # 1. Contamos cuántos hay de cada clase originalmente
    counts = {}
    for _, obj in objs:
        c = obj.category
        counts[c] = counts.get(c, 0) + 1

    print("--- CONTEO ORIGINAL ---")
    print(counts)

    balanced_objs = []

    # CONFIGURACIÓN DE OBJETIVOS
    TARGET_STANDARD = 2000  # Objetivo para la mayoría (Pylons, Barcos, Camiones...)
    TARGET_TINY = 1000      # Objetivo conservador para las muy pequeñas (Helipuertos)
    TINY_THRESHOLD = 200    # Si tiene menos de 200, usamos el objetivo 'Tiny'

    for filename, obj in objs:
        # Siempre añadimos la imagen original
        balanced_objs.append((filename, obj))

        current_count = counts[obj.category]

        # Determinamos el objetivo según el tamaño de la clase
        if current_count < TINY_THRESHOLD:
            target = TARGET_TINY  # Caso Helipuertos (111 -> ~1000)
        else:
            target = TARGET_STANDARD # Caso Pylons/Trucks (300 -> ~2000)

        # Si estamos por debajo del objetivo, calculamos copias
        if current_count < target:
            # Ejemplo Pylon (312): 2000 / 312 = 6.4 -> Multiplicador 6 (Total 7 copias)
            # Ejemplo Helipuerto (111): 1000 / 111 = 9.0 -> Multiplicador 9 (Total 10 copias)
            # Restamos 1 porque ya añadimos la original arriba
            multiplier = int(target / current_count) - 1

            # Solo añadimos si el multiplicador es positivo
            if multiplier > 0:
                for _ in range(multiplier):
                    balanced_objs.append((filename, obj))

    print(f"\n--- DATASET BALANCEADO ---")
    print(f"De {len(objs)} imágenes pasamos a {len(balanced_objs)} imágenes virtuales.")

    return balanced_objs

# %%
manual_weights_dict = {
    0: 1.0,
    1: 1.0,  # Small car: 1.0 (Ni se te ocurra bajarlo)
    2: 1.5,  # Bus: 1.5 (Ayudita suave)
    3: 2.0,  # TRUCK: 2.0 (Fuerte pero controlable por la red grande)
    4: 1.0,
    5: 1.0,
    6: 1.5,  # Dump Truck: 1.5
    7: 1.0, 8: 1.0, 9: 1.2,
    10: 1.5, # Storage Tank
    11: 1.2, # Shipping Container
    12: 1.2
}

# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]

# PASO 1: Balanceo de clases
print("--- FASE 1: Balanceo ---")
objs_train_balanced = balance_dataset_list(objs_train)


# PASO 2: Cargar todo en RAM
# -------------------------------------------------------
print("\n--- FASE 2: Carga en RAM ---")
# Train con lista inflada
X_train_ram, y_train_ram = load_dataset_to_ram(objs_train_balanced)
# Valid con lista normal
X_valid_ram, y_valid_ram = load_dataset_to_ram(objs_valid)

# PASO 3: Crear Generadores Rápidos
# -------------------------------------------------------
batch_size = 32

train_gen = generator_from_ram(
    X_train_ram, y_train_ram,
    batch_size=batch_size,
    do_shuffle=True,
    do_augment=True,
    class_weights_dict=manual_weights_dict
)

valid_gen = generator_from_ram(
    X_valid_ram, y_valid_ram,
    batch_size=batch_size,
    do_shuffle=False,
    do_augment=False,
    class_weights_dict=manual_weights_dict
)
# Out:
# --- FASE 1: Balanceo ---
# --- CONTEO ORIGINAL ---
# {'Bus': 1594, 'Cargo plane': 576, 'Truck': 1969, 'Building': 3231, 'Fishing vessel': 633, 'Small car': 2995, 'Pylon': 280, 'Shipping container': 1388, 'Dump truck': 1118, 'Motorboat': 960, 'Storage tank': 1317, 'Excavator': 708, 'Helipad': 102}
#
# --- DATASET BALANCEADO ---
# De 16871 imágenes pasamos a 23453 imágenes virtuales.
#
# --- FASE 2: Carga en RAM ---
# Cargando 23453 imágenes en RAM...
# 100%|██████████| 23453/23453 [01:02<00:00, 373.07it/s]
# ¡Carga lista! Ocupa en RAM: 274.84 MB
# Cargando 1875 imágenes en RAM...
# 100%|██████████| 1875/1875 [00:04<00:00, 379.41it/s]
# ¡Carga lista! Ocupa en RAM: 21.97 MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_class_balance(original_objs, balanced_objs):
    # 1. Contar Originales
    counts_orig = {}
    for _, obj in original_objs:
        counts_orig[obj.category] = counts_orig.get(obj.category, 0) + 1

    # 2. Contar Balanceados
    counts_bal = {}
    for _, obj in balanced_objs:
        counts_bal[obj.category] = counts_bal.get(obj.category, 0) + 1

    # Preparar datos para plot
    classes = list(counts_orig.keys())
    # Ordenamos por cantidad original para que quede bonito
    classes.sort(key=lambda x: counts_orig[x], reverse=True)

    vals_orig = [counts_orig[c] for c in classes]
    vals_bal = [counts_bal[c] for c in classes]

    x = range(len(classes))
    width = 0.35

    plt.figure(figsize=(15, 6))
    plt.bar([i - width/2 for i in x], vals_orig, width, label='Original', color='red', alpha=0.6)
    plt.bar([i + width/2 for i in x], vals_bal, width, label='Balanceado (Virtual)', color='green', alpha=0.6)

    plt.xticks(x, classes, rotation=45, ha='right')
    plt.ylabel('Número de Imágenes')
    plt.title('Impacto del Oversampling en el Dataset')
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# USARLO:
plot_class_balance(objs_train, objs_train_balanced)

# %%
import matplotlib.pyplot as plt
import numpy as np

def visualize_ram_augmentation(X_data, y_data, generator_func, class_weights_dict):
    # 1. Buscar índices de Helipuertos (o la clase que quieras ver)
    # Asumimos que y_data tiene los nombres de las clases (strings)
    indices = np.where(y_data == 'Helipad')[0]

    if len(indices) == 0:
        print("No se encontraron Helipuertos en los datos proporcionados.")
        return

    idx = indices[0] # Cogemos el primer helipuerto que encontremos

    # 2. Extraer la imagen y la etiqueta originales de la RAM
    sample_img = X_data[idx]
    sample_cat = y_data[idx]

    # 3. Crear un "Mini Batch Falso" de 5 copias idénticas
    # Repetimos la imagen 5 veces: (5, 64, 64, 3)
    fake_X = np.array([sample_img] * 5)
    fake_y = np.array([sample_cat] * 5)

    # 4. Instanciar el generador con estos datos falsos
    # Le decimos batch_size=5 para que nos devuelva las 5 de golpe
    gen = generator_func(fake_X, fake_y, batch_size=5, do_shuffle=False, do_augment=True, class_weights_dict=class_weights_dict)

    images_aug, _, _ = next(gen) # Sacamos el batch procesado, IGNORAMOS Y y W

    # 5. Pintar
    plt.figure(figsize=(15, 4))
    for i in range(5):
        plt.subplot(1, 5, i+1)

        # Las imágenes vienen normalizadas (0-1) y en float32
        img_show = images_aug[i]

        # Si usaste cv2 para cargar, están en BGR. Matplotlib quiere RGB.
        # Hacemos el flip de canales con ::-1
        plt.imshow(img_show[:, :, ::-1])

        if i == 0:
            plt.title("Probablemente Original\n(o rotada)")
        else:
            plt.title(f"Variación {i}")
        plt.axis('off')

    plt.suptitle(f"Efecto del Data Augmentation en RAM ({sample_cat})")
    plt.show()

# --- CÓMO USARLO AHORA ---
# Importante: Pasa las variables _ram, NO la lista de objetos
visualize_ram_augmentation(X_train_ram, y_train_ram, generator_from_ram, manual_weights_dict)

# %%
import math
import numpy as np

print('Training model')
epochs = 100
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_gen, steps_per_epoch=train_steps,
              validation_data=valid_gen,
              validation_steps=valid_steps,
              epochs=epochs,
              callbacks=callbacks,
              verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2380 - loss: 0.5786
# Epoch 1: val_accuracy improved from -inf to 0.29867, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.2386 - loss: 0.5781 - val_accuracy: 0.2987 - val_loss: 0.5159 - learning_rate: 0.0010
# Epoch 2/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3576 - loss: 0.4812
# Epoch 2: val_accuracy improved from 0.29867 to 0.36706, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.3577 - loss: 0.4812 - val_accuracy: 0.3671 - val_loss: 0.4705 - learning_rate: 0.0010
# Epoch 3/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4030 - loss: 0.4512
# Epoch 3: val_accuracy improved from 0.36706 to 0.39989, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.4030 - loss: 0.4511 - val_accuracy: 0.3999 - val_loss: 0.4582 - learning_rate: 0.0010
# Epoch 4/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4197 - loss: 0.4343
# Epoch 4: val_accuracy improved from 0.39989 to 0.41578, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4197 - loss: 0.4343 - val_accuracy: 0.4158 - val_loss: 0.4432 - learning_rate: 0.0010
# Epoch 5/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4400 - loss: 0.4235
# Epoch 5: val_accuracy did not improve from 0.41578
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.4400 - loss: 0.4235 - val_accuracy: 0.4110 - val_loss: 0.4368 - learning_rate: 0.0010
# Epoch 6/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4611 - loss: 0.4142
# Epoch 6: val_accuracy improved from 0.41578 to 0.42880, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4611 - loss: 0.4141 - val_accuracy: 0.4288 - val_loss: 0.4325 - learning_rate: 0.0010
# Epoch 7/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4644 - loss: 0.4050
# Epoch 7: val_accuracy improved from 0.42880 to 0.46613, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.4644 - loss: 0.4050 - val_accuracy: 0.4661 - val_loss: 0.4177 - learning_rate: 0.0010
# Epoch 8/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4757 - loss: 0.4000
# Epoch 8: val_accuracy improved from 0.46613 to 0.47573, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4757 - loss: 0.3999 - val_accuracy: 0.4757 - val_loss: 0.4120 - learning_rate: 0.0010
# Epoch 9/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4897 - loss: 0.3950
# Epoch 9: val_accuracy improved from 0.47573 to 0.48853, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.4896 - loss: 0.3950 - val_accuracy: 0.4885 - val_loss: 0.3963 - learning_rate: 0.0010
# Epoch 10/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4929 - loss: 0.3899
# Epoch 10: val_accuracy did not improve from 0.48853
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4929 - loss: 0.3899 - val_accuracy: 0.4672 - val_loss: 0.4116 - learning_rate: 0.0010
# Epoch 11/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5099 - loss: 0.3869
# Epoch 11: val_accuracy did not improve from 0.48853
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5099 - loss: 0.3869 - val_accuracy: 0.4635 - val_loss: 0.3931 - learning_rate: 0.0010
# Epoch 12/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5078 - loss: 0.3811
# Epoch 12: val_accuracy improved from 0.48853 to 0.49227, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5078 - loss: 0.3810 - val_accuracy: 0.4923 - val_loss: 0.3945 - learning_rate: 0.0010
# Epoch 13/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5188 - loss: 0.3764
# Epoch 13: val_accuracy did not improve from 0.49227
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.5188 - loss: 0.3764 - val_accuracy: 0.4763 - val_loss: 0.3996 - learning_rate: 0.0010
# Epoch 14/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5212 - loss: 0.3725
# Epoch 14: val_accuracy improved from 0.49227 to 0.49973, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5212 - loss: 0.3725 - val_accuracy: 0.4997 - val_loss: 0.3905 - learning_rate: 0.0010
# Epoch 15/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5267 - loss: 0.3700
# Epoch 15: val_accuracy improved from 0.49973 to 0.50133, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5267 - loss: 0.3699 - val_accuracy: 0.5013 - val_loss: 0.3785 - learning_rate: 0.0010
# Epoch 16/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5305 - loss: 0.3656
# Epoch 16: val_accuracy did not improve from 0.50133
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.5305 - loss: 0.3656 - val_accuracy: 0.5008 - val_loss: 0.3852 - learning_rate: 0.0010
# Epoch 17/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5359 - loss: 0.3643
# Epoch 17: val_accuracy improved from 0.50133 to 0.51307, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5359 - loss: 0.3643 - val_accuracy: 0.5131 - val_loss: 0.3850 - learning_rate: 0.0010
# Epoch 18/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5435 - loss: 0.3589
# Epoch 18: val_accuracy improved from 0.51307 to 0.51840, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.5435 - loss: 0.3589 - val_accuracy: 0.5184 - val_loss: 0.3756 - learning_rate: 0.0010
# Epoch 19/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5524 - loss: 0.3568
# Epoch 19: val_accuracy improved from 0.51840 to 0.54560, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5523 - loss: 0.3569 - val_accuracy: 0.5456 - val_loss: 0.3692 - learning_rate: 0.0010
# Epoch 20/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5577 - loss: 0.3499
# Epoch 20: val_accuracy did not improve from 0.54560
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.5576 - loss: 0.3499 - val_accuracy: 0.5429 - val_loss: 0.3656 - learning_rate: 0.0010
# Epoch 21/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5554 - loss: 0.3501
# Epoch 21: val_accuracy did not improve from 0.54560
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5554 - loss: 0.3501 - val_accuracy: 0.5285 - val_loss: 0.3692 - learning_rate: 0.0010
# Epoch 22/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5549 - loss: 0.3514
# Epoch 22: val_accuracy did not improve from 0.54560
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5549 - loss: 0.3514 - val_accuracy: 0.5371 - val_loss: 0.3769 - learning_rate: 0.0010
# Epoch 23/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5612 - loss: 0.3481
# Epoch 23: val_accuracy improved from 0.54560 to 0.55200, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5613 - loss: 0.3481 - val_accuracy: 0.5520 - val_loss: 0.3661 - learning_rate: 0.0010
# Epoch 24/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5679 - loss: 0.3446
# Epoch 24: val_accuracy did not improve from 0.55200
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5679 - loss: 0.3446 - val_accuracy: 0.5376 - val_loss: 0.3637 - learning_rate: 0.0010
# Epoch 25/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5670 - loss: 0.3425
# Epoch 25: val_accuracy did not improve from 0.55200
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.5671 - loss: 0.3425 - val_accuracy: 0.5088 - val_loss: 0.3658 - learning_rate: 0.0010
# Epoch 26/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5738 - loss: 0.3376
# Epoch 26: val_accuracy did not improve from 0.55200
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5738 - loss: 0.3376 - val_accuracy: 0.5147 - val_loss: 0.3718 - learning_rate: 0.0010
# Epoch 27/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5812 - loss: 0.3350
# Epoch 27: val_accuracy did not improve from 0.55200
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5812 - loss: 0.3350 - val_accuracy: 0.5392 - val_loss: 0.3661 - learning_rate: 0.0010
# Epoch 28/100
# 521/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5889 - loss: 0.3332
# Epoch 28: val_accuracy did not improve from 0.55200
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5888 - loss: 0.3332 - val_accuracy: 0.5232 - val_loss: 0.3680 - learning_rate: 0.0010
# Epoch 29/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5885 - loss: 0.3315
# Epoch 29: val_accuracy did not improve from 0.55200
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5885 - loss: 0.3315 - val_accuracy: 0.5488 - val_loss: 0.3560 - learning_rate: 0.0010
# Epoch 30/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5817 - loss: 0.3334
# Epoch 30: val_accuracy improved from 0.55200 to 0.56800, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5817 - loss: 0.3334 - val_accuracy: 0.5680 - val_loss: 0.3500 - learning_rate: 0.0010
# Epoch 31/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5854 - loss: 0.3309
# Epoch 31: val_accuracy did not improve from 0.56800
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5854 - loss: 0.3309 - val_accuracy: 0.5488 - val_loss: 0.3586 - learning_rate: 0.0010
# Epoch 32/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5951 - loss: 0.3244
# Epoch 32: val_accuracy did not improve from 0.56800
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5951 - loss: 0.3244 - val_accuracy: 0.5600 - val_loss: 0.3520 - learning_rate: 0.0010
# Epoch 33/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6051 - loss: 0.3236
# Epoch 33: val_accuracy did not improve from 0.56800
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.6050 - loss: 0.3236 - val_accuracy: 0.5627 - val_loss: 0.3543 - learning_rate: 0.0010
# Epoch 34/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5933 - loss: 0.3256
# Epoch 34: val_accuracy improved from 0.56800 to 0.57333, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5933 - loss: 0.3256 - val_accuracy: 0.5733 - val_loss: 0.3477 - learning_rate: 0.0010
# Epoch 35/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6000 - loss: 0.3228
# Epoch 35: val_accuracy did not improve from 0.57333
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.6000 - loss: 0.3228 - val_accuracy: 0.5568 - val_loss: 0.3573 - learning_rate: 0.0010
# Epoch 36/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6038 - loss: 0.3222
# Epoch 36: val_accuracy improved from 0.57333 to 0.58133, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6038 - loss: 0.3222 - val_accuracy: 0.5813 - val_loss: 0.3497 - learning_rate: 0.0010
# Epoch 37/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6103 - loss: 0.3176
# Epoch 37: val_accuracy did not improve from 0.58133
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.6103 - loss: 0.3176 - val_accuracy: 0.5685 - val_loss: 0.3519 - learning_rate: 0.0010
# Epoch 38/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6090 - loss: 0.3190
# Epoch 38: val_accuracy improved from 0.58133 to 0.58240, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6090 - loss: 0.3190 - val_accuracy: 0.5824 - val_loss: 0.3471 - learning_rate: 0.0010
# Epoch 39/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6177 - loss: 0.3135
# Epoch 39: val_accuracy did not improve from 0.58240
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6177 - loss: 0.3135 - val_accuracy: 0.5787 - val_loss: 0.3492 - learning_rate: 0.0010
# Epoch 40/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6404 - loss: 0.3012
# Epoch 40: val_accuracy improved from 0.58240 to 0.60213, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6404 - loss: 0.3012 - val_accuracy: 0.6021 - val_loss: 0.3358 - learning_rate: 2.0000e-04
# Epoch 41/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6496 - loss: 0.2977
# Epoch 41: val_accuracy did not improve from 0.60213
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6496 - loss: 0.2977 - val_accuracy: 0.5973 - val_loss: 0.3359 - learning_rate: 2.0000e-04
# Epoch 42/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6505 - loss: 0.2962
# Epoch 42: val_accuracy did not improve from 0.60213
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6506 - loss: 0.2962 - val_accuracy: 0.5925 - val_loss: 0.3347 - learning_rate: 2.0000e-04
# Epoch 43/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6487 - loss: 0.2927
# Epoch 43: val_accuracy improved from 0.60213 to 0.60320, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6487 - loss: 0.2927 - val_accuracy: 0.6032 - val_loss: 0.3343 - learning_rate: 2.0000e-04
# Epoch 44/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6622 - loss: 0.2887
# Epoch 44: val_accuracy improved from 0.60320 to 0.61280, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6622 - loss: 0.2887 - val_accuracy: 0.6128 - val_loss: 0.3298 - learning_rate: 2.0000e-04
# Epoch 45/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6480 - loss: 0.2941
# Epoch 45: val_accuracy did not improve from 0.61280
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6481 - loss: 0.2941 - val_accuracy: 0.6016 - val_loss: 0.3295 - learning_rate: 2.0000e-04
# Epoch 46/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6591 - loss: 0.2917
# Epoch 46: val_accuracy improved from 0.61280 to 0.61653, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6591 - loss: 0.2917 - val_accuracy: 0.6165 - val_loss: 0.3303 - learning_rate: 2.0000e-04
# Epoch 47/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6656 - loss: 0.2890
# Epoch 47: val_accuracy improved from 0.61653 to 0.62080, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.6656 - loss: 0.2890 - val_accuracy: 0.6208 - val_loss: 0.3294 - learning_rate: 2.0000e-04
# Epoch 48/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6687 - loss: 0.2860
# Epoch 48: val_accuracy did not improve from 0.62080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6686 - loss: 0.2861 - val_accuracy: 0.6037 - val_loss: 0.3297 - learning_rate: 2.0000e-04
# Epoch 49/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6655 - loss: 0.2873
# Epoch 49: val_accuracy did not improve from 0.62080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6655 - loss: 0.2873 - val_accuracy: 0.6181 - val_loss: 0.3273 - learning_rate: 2.0000e-04
# Epoch 50/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6626 - loss: 0.2909
# Epoch 50: val_accuracy did not improve from 0.62080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6626 - loss: 0.2909 - val_accuracy: 0.6107 - val_loss: 0.3275 - learning_rate: 2.0000e-04
# Epoch 51/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6648 - loss: 0.2872
# Epoch 51: val_accuracy did not improve from 0.62080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6648 - loss: 0.2872 - val_accuracy: 0.6027 - val_loss: 0.3327 - learning_rate: 2.0000e-04
# Epoch 52/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6690 - loss: 0.2865
# Epoch 52: val_accuracy did not improve from 0.62080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6690 - loss: 0.2865 - val_accuracy: 0.6032 - val_loss: 0.3322 - learning_rate: 2.0000e-04
# Epoch 53/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6651 - loss: 0.2873
# Epoch 53: val_accuracy did not improve from 0.62080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.6651 - loss: 0.2873 - val_accuracy: 0.6117 - val_loss: 0.3290 - learning_rate: 2.0000e-04
# Epoch 54/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6669 - loss: 0.2824
# Epoch 54: val_accuracy did not improve from 0.62080
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6669 - loss: 0.2825 - val_accuracy: 0.6107 - val_loss: 0.3315 - learning_rate: 2.0000e-04
# Epoch 55/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6802 - loss: 0.2794
# Epoch 55: val_accuracy did not improve from 0.62080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6801 - loss: 0.2795 - val_accuracy: 0.6144 - val_loss: 0.3293 - learning_rate: 4.0000e-05
# Epoch 56/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6753 - loss: 0.2813
# Epoch 56: val_accuracy did not improve from 0.62080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6752 - loss: 0.2813 - val_accuracy: 0.6139 - val_loss: 0.3297 - learning_rate: 4.0000e-05
# Epoch 57/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6726 - loss: 0.2817
# Epoch 57: val_accuracy did not improve from 0.62080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6726 - loss: 0.2817 - val_accuracy: 0.6187 - val_loss: 0.3283 - learning_rate: 4.0000e-05
# Epoch 58/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6760 - loss: 0.2816
# Epoch 58: val_accuracy did not improve from 0.62080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6760 - loss: 0.2816 - val_accuracy: 0.6155 - val_loss: 0.3293 - learning_rate: 4.0000e-05
# Epoch 59/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6793 - loss: 0.2812
# Epoch 59: val_accuracy did not improve from 0.62080
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6793 - loss: 0.2812 - val_accuracy: 0.6197 - val_loss: 0.3279 - learning_rate: 4.0000e-05
# Epoch 60/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6715 - loss: 0.2818
# Epoch 60: val_accuracy did not improve from 0.62080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6716 - loss: 0.2818 - val_accuracy: 0.6176 - val_loss: 0.3282 - learning_rate: 8.0000e-06
# Epoch 61/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6840 - loss: 0.2788
# Epoch 61: val_accuracy did not improve from 0.62080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6840 - loss: 0.2788 - val_accuracy: 0.6165 - val_loss: 0.3273 - learning_rate: 8.0000e-06
# Epoch 62/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6745 - loss: 0.2825
# Epoch 62: val_accuracy did not improve from 0.62080
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6745 - loss: 0.2825 - val_accuracy: 0.6165 - val_loss: 0.3286 - learning_rate: 8.0000e-06
# Epoch 62: early stopping
# Restoring model weights from the end of the best epoch: 47.
# Best validation model: epoch 47  - val_accuracy 0.6208000183105469

# %%
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(16, 5))

    # Gráfica de Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training acc')
    plt.plot(epochs, val_acc, 'ro-', label='Validation acc')
    plt.title('Accuracy: Train vs Validation')
    plt.legend()
    plt.grid(True)

    # Gráfica de Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
    plt.title('Loss: Train vs Validation')
    plt.legend()
    plt.grid(True)

    plt.show()

# USARLO:
plot_history(h)

# %%
from sklearn.metrics import classification_report
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

def plot_classification_report(model, valid_gen, steps):
    print("Generando predicciones... esto puede tardar unos segundos.")

    # 1. Predecir
    y_pred = model.predict(valid_gen, steps=steps, verbose=1)
    y_pred_classes = np.argmax(y_pred, axis=1) # Convierte [0.1, 0.9, 0] -> 1

    # 2. Etiquetas reales (CORREGIDO)
    # Como y_valid_ram tiene textos ('Helipad'), hay que pasarlos a números (0, 1, 2...)
    # Usamos el orden de 'categories' para saber qué número es cada texto.
    class_names = list(categories.values()) # ['Cargo plane', 'Small car', ...]

    # Mapeamos cada texto de la RAM a su número
    y_true = np.array([class_names.index(cat) for cat in y_valid_ram])

    # AJUSTE VITAL:
    # Al usar steps = len // batch_size, es posible que 'y_pred' sea un poco más corto
    # que 'y_true' (porque se descarta el último batch incompleto).
    # Cortamos y_true para que tenga la misma longitud exacta que y_pred.
    y_true = y_true[:len(y_pred_classes)]

    # 3. Reporte
    report = classification_report(
        y_true,
        y_pred_classes,
        target_names=class_names,
        output_dict=True,
        zero_division=0 # Evita errores si alguna clase no se predice nunca
    )

    # Convertimos a DataFrame y limpiamos
    df = pd.DataFrame(report).transpose()
    df = df.drop(['accuracy', 'macro avg', 'weighted avg'])

    # 4. Heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(df.iloc[:, :3], annot=True, cmap='RdYlGn', fmt='.2f', vmin=0, vmax=1)
    plt.title('Boletín de Notas: Precision vs Recall')
    plt.show()

# USARLO:
# Asegúrate de pasar el BATCH_SIZE correcto (el mismo que usaste en valid_gen)
plot_classification_report(model, valid_gen, len(X_valid_ram)//batch_size)
# Out:
# Generando predicciones... esto puede tardar unos segundos.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt

def visualize_errors(model, X_data, y_data):
    print("Analizando errores... (Prediciendo todo el set)")

    # 1. Predecir todo
    # Normalizamos al vuelo (/255.0) porque en RAM están como uint8
    preds = model.predict(X_data.astype('float32') / 255.0, verbose=0)

    # Obtenemos la clase predicha (Número)
    pred_classes = np.argmax(preds, axis=1)

    # 2. Obtener la clase real (CORRECCIÓN AQUÍ)
    # Como y_data son textos ('Helipad'), los convertimos a números
    class_names = list(categories.values()) # ['Cargo plane', 'Small car', ...]

    # Mapeamos: 'Helipad' -> 9 (o el número que sea)
    true_classes = np.array([class_names.index(cat) for cat in y_data])

    # 3. Buscar discrepancias
    errors = np.where(pred_classes != true_classes)[0]
    print(f"Total de errores: {len(errors)} de {len(X_data)} ({(len(errors)/len(X_data))*100:.2f}%)")

    # Si no hay errores, salimos
    if len(errors) == 0:
        print("¡Increíble! 0 errores encontrados.")
        return

    # 4. Mostrar 10 errores aleatorios
    # Si hay menos de 10 errores, los mostramos todos
    n_show = min(10, len(errors))
    indices_to_show = np.random.choice(errors, size=n_show, replace=False)

    plt.figure(figsize=(20, 8))
    for i, idx in enumerate(indices_to_show):
        plt.subplot(2, 5, i+1)

        # Imagen (Original de RAM)
        img = X_data[idx]

        # Si usas OpenCV, recuerda que carga en BGR, matplotlib quiere RGB
        # Si ves los colores raros (azul en vez de rojo), descomenta la linea de abajo:
        # img = img[:, :, ::-1]
        plt.imshow(img)

        # Etiquetas
        true_label = class_names[true_classes[idx]]
        pred_label = class_names[pred_classes[idx]]

        # Confianza: ¿Cómo de seguro estaba el modelo de su error?
        conf = np.max(preds[idx]) * 100

        # T = Truth (Verdad), P = Prediction (Predicción)
        plt.title(f"Real: {true_label}\nPred: {pred_label}\nConf: {conf:.1f}%", color='red', fontsize=10)
        plt.axis('off')

    plt.suptitle("Galería de los Horrores: Errores del Modelo", fontsize=16)
    plt.tight_layout()
    plt.show()

# USARLO:
visualize_errors(model, X_valid_ram, y_valid_ram)
# Out:
# Analizando errores... (Prediciendo todo el set)
# Total de errores: 718 de 1875 (38.29%)

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
# 1. Usamos los datos que YA cargamos en RAM (Velocidad: 100x más rápido)
# model.predict procesa todo el bloque de golpe (Batch processing)
print("Prediciendo todo el validación de golpe...")
predictions = model.predict(X_valid_ram.astype('float32') / 255.0, batch_size=32, verbose=1)

# 2. Sacamos la clase ganadora de cada foto
y_pred_indices = np.argmax(predictions, axis=1) # [0, 5, 2...]

# 3. Convertimos números a nombres (si lo necesitas en texto)
class_names = list(categories.values())
y_pred = [class_names[i] for i in y_pred_indices]

# 4. Sacamos el y_true (La realidad)
# Si y_valid_ram era texto:
y_true = y_valid_ram
# Si y_valid_ram era One-Hot o índices, adáptalo.
# Asumiendo que es la lista de textos que devolvía load_dataset_to_ram:
# (Si usaste mi última función, y_valid_ram es una lista de strings ['Helipad', 'Car'...])
# Out:
# Prediciendo todo el validación de golpe...
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 61.707%
# Mean Recall: 62.357%
# Mean Precision: 58.955%
# > Cargo plane: Recall: 86.441% Precision: 98.077% Specificity: 99.945% Dice: 91.892%
# > Small car: Recall: 76.292% Precision: 76.292% Specificity: 94.955% Dice: 76.292%
# > Bus: Recall: 50.000% Precision: 54.717% Specificity: 95.767% Dice: 52.252%
# > Truck: Recall: 39.004% Precision: 36.293% Specificity: 89.902% Dice: 37.600%
# > Motorboat: Recall: 48.624% Precision: 53.535% Specificity: 97.395% Dice: 50.962%
# > Fishing vessel: Recall: 67.123% Precision: 53.846% Specificity: 97.669% Dice: 59.756%
# > Dump truck: Recall: 48.305% Precision: 56.436% Specificity: 97.496% Dice: 52.055%
# > Excavator: Recall: 70.370% Precision: 61.957% Specificity: 98.049% Dice: 65.896%
# > Building: Recall: 68.871% Precision: 74.184% Specificity: 94.246% Dice: 71.429%
# > Helipad: Recall: 55.556% Precision: 26.316% Specificity: 99.250% Dice: 35.714%
# > Storage tank: Recall: 59.868% Precision: 73.387% Specificity: 98.085% Dice: 65.942%
# > Shipping container: Recall: 65.185% Precision: 54.321% Specificity: 95.747% Dice: 59.259%
# > Pylon: Recall: 75.000% Precision: 47.059% Specificity: 98.535% Dice: 57.831%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('../content/dataset/xview_recognition/xview_test'):
    for filename in filenames:
        image = GenericImage(dirpath[29:] + '/' + filename)
        image.tile = np.array([0, 0, 64, 64])
        obj = GenericObject()
        obj.bb = (0, 0, 64, 64)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np
import tensorflow as tf

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}

for idx, ann in enumerate(anns):
    image_data = {
        "image_id": ann.filename.split('/')[-1],
        "filename": ann.filename,
        "width": int(ann.tile[2]),
        "height": int(ann.tile[3])
    }
    predictions_data["images"][idx] = image_data

    # 1. Cargar imagen original
    # Fix: Remove 'gnition/' from the filename path which was incorrectly added
    try:
        image = load_geoimage(ann.filename[8:]) / 255.0
    except Exception as e:
        print(f"Error al cargar la ruta {ann.filename[8:]}. Saltando...")
        continue

    # --- FIX CRÍTICO: Comprobar que la imagen existe y redimensionar a 64x64 ---
    if image is None or image.size == 0:
        print(f"Advertencia: La imagen {ann.filename[8:]} se cargó vacía.")
        continue

    # Redimensionamos explícitamente al input_shape que espera nuestro modelo
    image_resized = tf.image.resize(image, (64, 64)).numpy()

    for obj_pred in ann.objects:
        # Generate prediction usando la imagen redimensionada
        warped_image = np.expand_dims(image_resized, 0)
        predictions = model.predict(warped_image, verbose=0)

        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = float(np.max(predictions)) # Casteado a float estándar de Python para evitar fallos en JSON

        annotation_data = {
            "image_id": ann.filename.split('/')[-1],
            "category_id": pred_category,
            "bbox": [int(x) for x in obj_pred.bb]
        }
        predictions_data["annotations"][idx] = annotation_data

print("Predicciones finalizadas correctamente.")
# Out:
# Predicciones finalizadas correctamente.

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)
