# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Yousef Medhat
# - Alumno 2: Carlos Manzano Izquierdo
# - Alumno 3: Guillermo Bermejo Babiano
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# The -q flag means "quiet" so it doesn't print 10,000 lines and crash your browser
# !unzip -q "/content/drive/MyDrive/DL/xview_recognition.zip" -d "/content/dataset"

print("✅ Unzipping complete!")
# Out:
# replace /content/dataset/xview_recognition/xview_ann_train.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# ✅ Unzipping complete!

# %%
data_dir = '/content/dataset/xview_recognition' # Or whatever the extracted folder is named

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
import warnings
import rasterio
import numpy as np
import cv2

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open('../content/dataset/xview_recognition/'+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)

    img_resized = cv2.resize(img, (64, 64), interpolation=cv2.INTER_AREA)

    return img_resized

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json

# Load database
json_file = '../content/dataset/xview_recognition/xview_ann_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 16871
# Number of validation images: 1875

# %%
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L2
from tensorflow.keras.activations import swish

print('Load model')
model = Sequential()
model.add(Flatten(input_shape=(64, 64, 3)))

# Mantenemos 512, pero añadimos L2 suave para controlar los pesos
model.add(Dense(512, kernel_initializer='he_normal', kernel_regularizer=L2(1e-4)))
model.add(BatchNormalization())
model.add(Activation('swish'))
# Subimos Dropout a 0.3 o 0.4. El 0.1 actual es muy poco y por eso la linea azul se escapa.
model.add(Dropout(0.4))

# --- CAPA 2: Refinamiento (NUEVA) ---
# Esta capa combina las características de la anterior. Vital para subir accuracy.
model.add(Dense(256, kernel_initializer='he_normal', kernel_regularizer=L2(1e-4)))
model.add(BatchNormalization())
model.add(Activation('swish'))
model.add(Dropout(0.3))

model.add(Dense(len(categories)))
model.add(Activation('softmax'))
model.summary()
# Out:
# Load model
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 12288)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │     6,291,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 13)             │         3,341 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 13)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,429,709 (24.53 MB)
#  Trainable params: 6,428,173 (24.52 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.losses import CategoricalFocalCrossentropy

focal_loss = CategoricalFocalCrossentropy(
    gamma=2.0,        # Fuerza el enfoque en lo difícil
    alpha=0.25,       # Balancea la importancia general
    label_smoothing=0.1,  # Label smoothing para overfitting
    from_logits=False # False porque usamos Softmax al final
)

# Learning rate is changed to 0.005
# opt = SGD(
#     learning_rate=0.005,
#     momentum=0.9,
#     nesterov=True,
#     clipnorm=1.0
# )
opt = AdamW(learning_rate=0.001, weight_decay=1e-4)
model.compile(optimizer=opt, loss=focal_loss, metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_delta=0.001,
    cooldown=1,
    min_lr=1e-6,
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
def generator_from_ram(X_data, y_data, batch_size, do_shuffle=False, do_augment=False):
    # Índices para saber qué foto toca
    indices = np.arange(len(X_data))

    while True:
        if do_shuffle:
            np.random.shuffle(indices)

        # Troceamos los índices en batches
        for i in range(0, len(indices), batch_size):
            batch_indices = indices[i:i+batch_size]

            # Cogemos las imágenes crudas de la RAM
            batch_images_raw = X_data[batch_indices]
            batch_cats = y_data[batch_indices]

            images, labels = [], []

            for j in range(len(batch_images_raw)):
                # Copiamos la imagen para no modificar la original en RAM
                img = batch_images_raw[j].copy()
                cat = batch_cats[j]

                # ==========================================
                # AUGMENTATION "SAFE MODE" (Solo Brillo y Giros)
                # ==========================================
                if do_augment:
                    # 1. ROTACIÓN (90, 180, 270)
                    k = np.random.randint(0, 4)
                    if k > 0: img = np.rot90(img, k)

                    # 2. FLIP (Espejo)
                    if np.random.rand() > 0.5:
                        code = np.random.choice([0, 1])
                        img = cv2.flip(img, code)

                    # 3. BRILLO/CONTRASTE (Sin Traslación)
                    # Lo aplicamos el 80% de las veces para dar variedad de color
                    if np.random.rand() > 0.2:
                        alpha = np.random.uniform(0.8, 1.2) # Contraste
                        beta = np.random.uniform(-25, 25)   # Brillo
                        img = cv2.convertScaleAbs(img, alpha=alpha, beta=beta)
                # ==========================================

                # Normalización (Aquí pasamos a float)
                img_float = img.astype(np.float32) / 255.0

                # One-Hot Encoding
                prob = np.zeros(len(categories))
                prob[list(categories.values()).index(cat)] = 1

                images.append(img_float)
                labels.append(prob)

            yield np.array(images), np.array(labels)

# %%
import numpy as np
import cv2
from tqdm import tqdm  # Barra de progreso

def load_dataset_to_ram(objs_list, target_size=(64, 64)):
    print(f"Cargando {len(objs_list)} imágenes en RAM... ")

    X_data = []
    y_labels = []

    for filename, obj in tqdm(objs_list):
        # 1. Cargar
        img = load_geoimage(filename)

        # 2. Redimensionar siempre a 64x64
        # (Es vital para poder apilarlas en un array de Numpy)
        if img.shape[:2] != target_size:
            img = cv2.resize(img, target_size, interpolation=cv2.INTER_AREA)

        # 3. Guardar tal cual (uint8, 0-255).
        # NO dividas por 255 aquí o ocuparás 4 veces más RAM.
        X_data.append(img)
        y_labels.append(obj.category)

    # Convertir a Bloque Numpy
    X_data = np.array(X_data, dtype='uint8')
    y_labels = np.array(y_labels)

    print(f"¡Carga lista! Ocupa en RAM: {X_data.nbytes / 1024 / 1024:.2f} MB")
    return X_data, y_labels

# %%
def balance_dataset_list(objs):
    # 1. Contamos cuántos hay de cada clase originalmente
    counts = {}
    for _, obj in objs:
        c = obj.category
        counts[c] = counts.get(c, 0) + 1

    print("--- CONTEO ORIGINAL ---")
    print(counts)

    balanced_objs = []

    # CONFIGURACIÓN DE OBJETIVOS
    TARGET_STANDARD = 2000  # Objetivo para la mayoría (Pylons, Barcos, Camiones...)
    TARGET_TINY = 1000      # Objetivo conservador para las muy pequeñas (Helipuertos)
    TINY_THRESHOLD = 200    # Si tiene menos de 200, usamos el objetivo 'Tiny'

    for filename, obj in objs:
        # Siempre añadimos la imagen original
        balanced_objs.append((filename, obj))

        current_count = counts[obj.category]

        # Determinamos el objetivo según el tamaño de la clase
        if current_count < TINY_THRESHOLD:
            target = TARGET_TINY  # Caso Helipuertos (111 -> ~1000)
        else:
            target = TARGET_STANDARD # Caso Pylons/Trucks (300 -> ~2000)

        # Si estamos por debajo del objetivo, calculamos copias
        if current_count < target:
            # Ejemplo Pylon (312): 2000 / 312 = 6.4 -> Multiplicador 6 (Total 7 copias)
            # Ejemplo Helipuerto (111): 1000 / 111 = 9.0 -> Multiplicador 9 (Total 10 copias)
            # Restamos 1 porque ya añadimos la original arriba
            multiplier = int(target / current_count) - 1

            # Solo añadimos si el multiplicador es positivo
            if multiplier > 0:
                for _ in range(multiplier):
                    balanced_objs.append((filename, obj))

    print(f"\n--- DATASET BALANCEADO ---")
    print(f"De {len(objs)} imágenes pasamos a {len(balanced_objs)} imágenes virtuales.")

    return balanced_objs

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]

# PASO 1: Balanceo de clases
print("--- FASE 1: Balanceo ---")
objs_train_balanced = balance_dataset_list(objs_train)


# PASO 2: Cargar todo en RAM
# -------------------------------------------------------
print("\n--- FASE 2: Carga en RAM ---")
# Train con lista inflada
X_train_ram, y_train_ram = load_dataset_to_ram(objs_train_balanced)
# Valid con lista normal
X_valid_ram, y_valid_ram = load_dataset_to_ram(objs_valid)

# PASO 3: Crear Generadores Rápidos
# -------------------------------------------------------
batch_size = 32

train_gen = generator_from_ram(
    X_train_ram, y_train_ram,
    batch_size=batch_size,
    do_shuffle=True,
    do_augment=True
)

valid_gen = generator_from_ram(
    X_valid_ram, y_valid_ram,
    batch_size=batch_size,
    do_shuffle=False,
    do_augment=False
)
# Out:
# --- FASE 1: Balanceo ---
# --- CONTEO ORIGINAL ---
# {'Bus': 1594, 'Cargo plane': 576, 'Truck': 1969, 'Building': 3231, 'Fishing vessel': 633, 'Small car': 2995, 'Pylon': 280, 'Shipping container': 1388, 'Dump truck': 1118, 'Motorboat': 960, 'Storage tank': 1317, 'Excavator': 708, 'Helipad': 102}
#
# --- DATASET BALANCEADO ---
# De 16871 imágenes pasamos a 23453 imágenes virtuales.
#
# --- FASE 2: Carga en RAM ---
# Cargando 23453 imágenes en RAM...
# 100%|██████████| 23453/23453 [01:11<00:00, 329.00it/s]
# ¡Carga lista! Ocupa en RAM: 274.84 MB
# Cargando 1875 imágenes en RAM...
# 100%|██████████| 1875/1875 [00:05<00:00, 370.01it/s]
# ¡Carga lista! Ocupa en RAM: 21.97 MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_class_balance(original_objs, balanced_objs):
    # 1. Contar Originales
    counts_orig = {}
    for _, obj in original_objs:
        counts_orig[obj.category] = counts_orig.get(obj.category, 0) + 1

    # 2. Contar Balanceados
    counts_bal = {}
    for _, obj in balanced_objs:
        counts_bal[obj.category] = counts_bal.get(obj.category, 0) + 1

    # Preparar datos para plot
    classes = list(counts_orig.keys())
    # Ordenamos por cantidad original para que quede bonito
    classes.sort(key=lambda x: counts_orig[x], reverse=True)

    vals_orig = [counts_orig[c] for c in classes]
    vals_bal = [counts_bal[c] for c in classes]

    x = range(len(classes))
    width = 0.35

    plt.figure(figsize=(15, 6))
    plt.bar([i - width/2 for i in x], vals_orig, width, label='Original', color='red', alpha=0.6)
    plt.bar([i + width/2 for i in x], vals_bal, width, label='Balanceado (Virtual)', color='green', alpha=0.6)

    plt.xticks(x, classes, rotation=45, ha='right')
    plt.ylabel('Número de Imágenes')
    plt.title('Impacto del Oversampling en el Dataset')
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# USARLO:
plot_class_balance(objs_train, objs_train_balanced)

# %%
import math
import numpy as np

print('Training model')
epochs = 100
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_gen, steps_per_epoch=train_steps, validation_data=valid_gen, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2348 - loss: 0.6533
# Epoch 1: val_accuracy improved from -inf to 0.31307, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.2351 - loss: 0.6529 - val_accuracy: 0.3131 - val_loss: 0.5302 - learning_rate: 0.0010
# Epoch 2/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3241 - loss: 0.5249
# Epoch 2: val_accuracy did not improve from 0.31307
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.3241 - loss: 0.5249 - val_accuracy: 0.3008 - val_loss: 0.5230 - learning_rate: 0.0010
# Epoch 3/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3378 - loss: 0.4953
# Epoch 3: val_accuracy did not improve from 0.31307
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3378 - loss: 0.4953 - val_accuracy: 0.2128 - val_loss: 0.5565 - learning_rate: 0.0010
# Epoch 4/100
# 521/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3397 - loss: 0.4873
# Epoch 4: val_accuracy did not improve from 0.31307
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3398 - loss: 0.4873 - val_accuracy: 0.2672 - val_loss: 0.5086 - learning_rate: 0.0010
# Epoch 5/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3487 - loss: 0.4740
# Epoch 5: val_accuracy did not improve from 0.31307
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3487 - loss: 0.4740 - val_accuracy: 0.2208 - val_loss: 0.5144 - learning_rate: 0.0010
# Epoch 6/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3421 - loss: 0.4719
# Epoch 6: val_accuracy did not improve from 0.31307
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3422 - loss: 0.4719 - val_accuracy: 0.2171 - val_loss: 0.5412 - learning_rate: 0.0010
# Epoch 7/100
# 521/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3537 - loss: 0.4666
# Epoch 7: val_accuracy did not improve from 0.31307
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3536 - loss: 0.4666 - val_accuracy: 0.2859 - val_loss: 0.4939 - learning_rate: 0.0010
# Epoch 8/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3536 - loss: 0.4616
# Epoch 8: val_accuracy improved from 0.31307 to 0.31680, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.3536 - loss: 0.4617 - val_accuracy: 0.3168 - val_loss: 0.4872 - learning_rate: 0.0010
# Epoch 9/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3516 - loss: 0.4597
# Epoch 9: val_accuracy did not improve from 0.31680
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3516 - loss: 0.4597 - val_accuracy: 0.2848 - val_loss: 0.4816 - learning_rate: 0.0010
# Epoch 10/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3581 - loss: 0.4577
# Epoch 10: val_accuracy did not improve from 0.31680
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3581 - loss: 0.4577 - val_accuracy: 0.2368 - val_loss: 0.5012 - learning_rate: 0.0010
# Epoch 11/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3512 - loss: 0.4601
# Epoch 11: val_accuracy did not improve from 0.31680
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3512 - loss: 0.4601 - val_accuracy: 0.2837 - val_loss: 0.4927 - learning_rate: 0.0010
# Epoch 12/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3577 - loss: 0.4542
# Epoch 12: val_accuracy did not improve from 0.31680
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3577 - loss: 0.4542 - val_accuracy: 0.2667 - val_loss: 0.4910 - learning_rate: 0.0010
# Epoch 13/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3488 - loss: 0.4551
# Epoch 13: val_accuracy did not improve from 0.31680
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3488 - loss: 0.4550 - val_accuracy: 0.2757 - val_loss: 0.4850 - learning_rate: 0.0010
# Epoch 14/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3587 - loss: 0.4517
# Epoch 14: val_accuracy did not improve from 0.31680
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3587 - loss: 0.4517 - val_accuracy: 0.2763 - val_loss: 0.4872 - learning_rate: 0.0010
# Epoch 15/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3702 - loss: 0.4395
# Epoch 15: val_accuracy improved from 0.31680 to 0.33173, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.3703 - loss: 0.4394 - val_accuracy: 0.3317 - val_loss: 0.4433 - learning_rate: 5.0000e-04
# Epoch 16/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3909 - loss: 0.4232
# Epoch 16: val_accuracy improved from 0.33173 to 0.34240, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3909 - loss: 0.4232 - val_accuracy: 0.3424 - val_loss: 0.4482 - learning_rate: 5.0000e-04
# Epoch 17/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3857 - loss: 0.4212
# Epoch 17: val_accuracy did not improve from 0.34240
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3857 - loss: 0.4212 - val_accuracy: 0.2837 - val_loss: 0.4534 - learning_rate: 5.0000e-04
# Epoch 18/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3970 - loss: 0.4181
# Epoch 18: val_accuracy did not improve from 0.34240
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.3970 - loss: 0.4181 - val_accuracy: 0.3147 - val_loss: 0.4421 - learning_rate: 5.0000e-04
# Epoch 19/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4068 - loss: 0.4122
# Epoch 19: val_accuracy did not improve from 0.34240
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4068 - loss: 0.4122 - val_accuracy: 0.3008 - val_loss: 0.4552 - learning_rate: 5.0000e-04
# Epoch 20/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4052 - loss: 0.4129
# Epoch 20: val_accuracy did not improve from 0.34240
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4052 - loss: 0.4129 - val_accuracy: 0.3205 - val_loss: 0.4457 - learning_rate: 5.0000e-04
# Epoch 21/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4066 - loss: 0.4087
# Epoch 21: val_accuracy improved from 0.34240 to 0.34933, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4066 - loss: 0.4087 - val_accuracy: 0.3493 - val_loss: 0.4325 - learning_rate: 5.0000e-04
# Epoch 22/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4029 - loss: 0.4125
# Epoch 22: val_accuracy did not improve from 0.34933
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4029 - loss: 0.4125 - val_accuracy: 0.3360 - val_loss: 0.4369 - learning_rate: 5.0000e-04
# Epoch 23/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4158 - loss: 0.4054
# Epoch 23: val_accuracy improved from 0.34933 to 0.36267, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4158 - loss: 0.4054 - val_accuracy: 0.3627 - val_loss: 0.4200 - learning_rate: 5.0000e-04
# Epoch 24/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4072 - loss: 0.4103
# Epoch 24: val_accuracy did not improve from 0.36267
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4072 - loss: 0.4103 - val_accuracy: 0.2800 - val_loss: 0.4615 - learning_rate: 5.0000e-04
# Epoch 25/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4143 - loss: 0.4056
# Epoch 25: val_accuracy did not improve from 0.36267
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4143 - loss: 0.4056 - val_accuracy: 0.3435 - val_loss: 0.4315 - learning_rate: 5.0000e-04
# Epoch 26/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4050 - loss: 0.4070
# Epoch 26: val_accuracy did not improve from 0.36267
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4050 - loss: 0.4070 - val_accuracy: 0.3205 - val_loss: 0.4391 - learning_rate: 5.0000e-04
# Epoch 27/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4186 - loss: 0.4004
# Epoch 27: val_accuracy did not improve from 0.36267
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4186 - loss: 0.4004 - val_accuracy: 0.3157 - val_loss: 0.4523 - learning_rate: 5.0000e-04
# Epoch 28/100
# 521/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4180 - loss: 0.4038
# Epoch 28: val_accuracy did not improve from 0.36267
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4180 - loss: 0.4039 - val_accuracy: 0.3264 - val_loss: 0.4386 - learning_rate: 5.0000e-04
# Epoch 29/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4325 - loss: 0.3911
# Epoch 29: val_accuracy improved from 0.36267 to 0.37659, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4326 - loss: 0.3911 - val_accuracy: 0.3766 - val_loss: 0.4126 - learning_rate: 2.5000e-04
# Epoch 30/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4459 - loss: 0.3832
# Epoch 30: val_accuracy improved from 0.37659 to 0.40466, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4460 - loss: 0.3832 - val_accuracy: 0.4047 - val_loss: 0.4027 - learning_rate: 2.5000e-04
# Epoch 31/100
# 521/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4322 - loss: 0.3847
# Epoch 31: val_accuracy improved from 0.40466 to 0.41280, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4323 - loss: 0.3847 - val_accuracy: 0.4128 - val_loss: 0.3879 - learning_rate: 2.5000e-04
# Epoch 32/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4445 - loss: 0.3811
# Epoch 32: val_accuracy did not improve from 0.41280
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4445 - loss: 0.3811 - val_accuracy: 0.4128 - val_loss: 0.3925 - learning_rate: 2.5000e-04
# Epoch 33/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4522 - loss: 0.3781
# Epoch 33: val_accuracy did not improve from 0.41280
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4522 - loss: 0.3781 - val_accuracy: 0.3909 - val_loss: 0.4053 - learning_rate: 2.5000e-04
# Epoch 34/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4474 - loss: 0.3785
# Epoch 34: val_accuracy did not improve from 0.41280
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4474 - loss: 0.3785 - val_accuracy: 0.3979 - val_loss: 0.3878 - learning_rate: 2.5000e-04
# Epoch 35/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4490 - loss: 0.3766
# Epoch 35: val_accuracy did not improve from 0.41280
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4490 - loss: 0.3766 - val_accuracy: 0.3893 - val_loss: 0.4000 - learning_rate: 2.5000e-04
# Epoch 36/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4461 - loss: 0.3760
# Epoch 36: val_accuracy did not improve from 0.41280
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4462 - loss: 0.3760 - val_accuracy: 0.3611 - val_loss: 0.4134 - learning_rate: 2.5000e-04
# Epoch 37/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4659 - loss: 0.3679
# Epoch 37: val_accuracy improved from 0.41280 to 0.42347, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4659 - loss: 0.3679 - val_accuracy: 0.4235 - val_loss: 0.3718 - learning_rate: 1.2500e-04
# Epoch 38/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4750 - loss: 0.3620
# Epoch 38: val_accuracy improved from 0.42347 to 0.43040, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.4750 - loss: 0.3620 - val_accuracy: 0.4304 - val_loss: 0.3636 - learning_rate: 1.2500e-04
# Epoch 39/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4658 - loss: 0.3605
# Epoch 39: val_accuracy improved from 0.43040 to 0.43093, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4659 - loss: 0.3605 - val_accuracy: 0.4309 - val_loss: 0.3648 - learning_rate: 1.2500e-04
# Epoch 40/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4810 - loss: 0.3565
# Epoch 40: val_accuracy did not improve from 0.43093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4810 - loss: 0.3565 - val_accuracy: 0.4149 - val_loss: 0.3738 - learning_rate: 1.2500e-04
# Epoch 41/100
# 520/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4727 - loss: 0.3607
# Epoch 41: val_accuracy improved from 0.43093 to 0.46347, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4727 - loss: 0.3607 - val_accuracy: 0.4635 - val_loss: 0.3537 - learning_rate: 1.2500e-04
# Epoch 42/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4762 - loss: 0.3595
# Epoch 42: val_accuracy did not improve from 0.46347
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.4762 - loss: 0.3595 - val_accuracy: 0.4635 - val_loss: 0.3492 - learning_rate: 1.2500e-04
# Epoch 43/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4776 - loss: 0.3565
# Epoch 43: val_accuracy did not improve from 0.46347
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4776 - loss: 0.3565 - val_accuracy: 0.4304 - val_loss: 0.3691 - learning_rate: 1.2500e-04
# Epoch 44/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4865 - loss: 0.3519
# Epoch 44: val_accuracy did not improve from 0.46347
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4865 - loss: 0.3519 - val_accuracy: 0.4389 - val_loss: 0.3643 - learning_rate: 1.2500e-04
# Epoch 45/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4755 - loss: 0.3561
# Epoch 45: val_accuracy did not improve from 0.46347
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4755 - loss: 0.3561 - val_accuracy: 0.4395 - val_loss: 0.3652 - learning_rate: 1.2500e-04
# Epoch 46/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4836 - loss: 0.3520
# Epoch 46: val_accuracy did not improve from 0.46347
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4835 - loss: 0.3520 - val_accuracy: 0.4581 - val_loss: 0.3528 - learning_rate: 1.2500e-04
# Epoch 47/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4763 - loss: 0.3545
# Epoch 47: val_accuracy improved from 0.46347 to 0.47573, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4763 - loss: 0.3545 - val_accuracy: 0.4757 - val_loss: 0.3477 - learning_rate: 1.2500e-04
# Epoch 48/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4802 - loss: 0.3543
# Epoch 48: val_accuracy did not improve from 0.47573
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4802 - loss: 0.3543 - val_accuracy: 0.4299 - val_loss: 0.3589 - learning_rate: 1.2500e-04
# Epoch 49/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4839 - loss: 0.3521
# Epoch 49: val_accuracy did not improve from 0.47573
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4839 - loss: 0.3521 - val_accuracy: 0.4261 - val_loss: 0.3674 - learning_rate: 1.2500e-04
# Epoch 50/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4887 - loss: 0.3524
# Epoch 50: val_accuracy did not improve from 0.47573
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4887 - loss: 0.3524 - val_accuracy: 0.4272 - val_loss: 0.3629 - learning_rate: 1.2500e-04
# Epoch 51/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4889 - loss: 0.3508
# Epoch 51: val_accuracy did not improve from 0.47573
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4889 - loss: 0.3508 - val_accuracy: 0.4683 - val_loss: 0.3527 - learning_rate: 1.2500e-04
# Epoch 52/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4872 - loss: 0.3504
# Epoch 52: val_accuracy did not improve from 0.47573
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4872 - loss: 0.3504 - val_accuracy: 0.4176 - val_loss: 0.3620 - learning_rate: 1.2500e-04
# Epoch 53/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4886 - loss: 0.3471
# Epoch 53: val_accuracy did not improve from 0.47573
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4886 - loss: 0.3471 - val_accuracy: 0.4715 - val_loss: 0.3410 - learning_rate: 6.2500e-05
# Epoch 54/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4988 - loss: 0.3451
# Epoch 54: val_accuracy did not improve from 0.47573
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4988 - loss: 0.3451 - val_accuracy: 0.4597 - val_loss: 0.3470 - learning_rate: 6.2500e-05
# Epoch 55/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4996 - loss: 0.3415
# Epoch 55: val_accuracy did not improve from 0.47573
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4996 - loss: 0.3416 - val_accuracy: 0.4720 - val_loss: 0.3428 - learning_rate: 6.2500e-05
# Epoch 56/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5041 - loss: 0.3379
# Epoch 56: val_accuracy improved from 0.47573 to 0.47733, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5041 - loss: 0.3379 - val_accuracy: 0.4773 - val_loss: 0.3416 - learning_rate: 6.2500e-05
# Epoch 57/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4983 - loss: 0.3432
# Epoch 57: val_accuracy improved from 0.47733 to 0.49440, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.4984 - loss: 0.3431 - val_accuracy: 0.4944 - val_loss: 0.3364 - learning_rate: 6.2500e-05
# Epoch 58/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5047 - loss: 0.3379
# Epoch 58: val_accuracy did not improve from 0.49440
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5047 - loss: 0.3380 - val_accuracy: 0.4384 - val_loss: 0.3528 - learning_rate: 6.2500e-05
# Epoch 59/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4968 - loss: 0.3392
# Epoch 59: val_accuracy did not improve from 0.49440
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4968 - loss: 0.3392 - val_accuracy: 0.4773 - val_loss: 0.3400 - learning_rate: 6.2500e-05
# Epoch 60/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5061 - loss: 0.3351
# Epoch 60: val_accuracy did not improve from 0.49440
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.5061 - loss: 0.3351 - val_accuracy: 0.4624 - val_loss: 0.3441 - learning_rate: 6.2500e-05
# Epoch 61/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5043 - loss: 0.3389
# Epoch 61: val_accuracy did not improve from 0.49440
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5043 - loss: 0.3389 - val_accuracy: 0.4453 - val_loss: 0.3486 - learning_rate: 6.2500e-05
# Epoch 62/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5001 - loss: 0.3416
# Epoch 62: val_accuracy did not improve from 0.49440
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5001 - loss: 0.3416 - val_accuracy: 0.4693 - val_loss: 0.3415 - learning_rate: 6.2500e-05
# Epoch 63/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5098 - loss: 0.3319
# Epoch 63: val_accuracy did not improve from 0.49440
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5098 - loss: 0.3319 - val_accuracy: 0.4910 - val_loss: 0.3287 - learning_rate: 3.1250e-05
# Epoch 64/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5155 - loss: 0.3313
# Epoch 64: val_accuracy did not improve from 0.49440
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5155 - loss: 0.3313 - val_accuracy: 0.4843 - val_loss: 0.3355 - learning_rate: 3.1250e-05
# Epoch 65/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5163 - loss: 0.3320
# Epoch 65: val_accuracy did not improve from 0.49440
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5163 - loss: 0.3320 - val_accuracy: 0.4896 - val_loss: 0.3295 - learning_rate: 3.1250e-05
# Epoch 66/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5207 - loss: 0.3302
# Epoch 66: val_accuracy did not improve from 0.49440
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5206 - loss: 0.3302 - val_accuracy: 0.4821 - val_loss: 0.3355 - learning_rate: 3.1250e-05
# Epoch 67/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5207 - loss: 0.3270
# Epoch 67: val_accuracy did not improve from 0.49440
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5207 - loss: 0.3270 - val_accuracy: 0.4907 - val_loss: 0.3317 - learning_rate: 3.1250e-05
# Epoch 68/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5138 - loss: 0.3293
# Epoch 68: val_accuracy did not improve from 0.49440
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5138 - loss: 0.3293 - val_accuracy: 0.4773 - val_loss: 0.3331 - learning_rate: 3.1250e-05
# Epoch 69/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5252 - loss: 0.3273
# Epoch 69: val_accuracy improved from 0.49440 to 0.49760, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5252 - loss: 0.3273 - val_accuracy: 0.4976 - val_loss: 0.3258 - learning_rate: 1.5625e-05
# Epoch 70/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5252 - loss: 0.3275
# Epoch 70: val_accuracy improved from 0.49760 to 0.49813, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5253 - loss: 0.3275 - val_accuracy: 0.4981 - val_loss: 0.3265 - learning_rate: 1.5625e-05
# Epoch 71/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5232 - loss: 0.3241
# Epoch 71: val_accuracy did not improve from 0.49813
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5232 - loss: 0.3241 - val_accuracy: 0.4864 - val_loss: 0.3295 - learning_rate: 1.5625e-05
# Epoch 72/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5253 - loss: 0.3227
# Epoch 72: val_accuracy improved from 0.49813 to 0.50987, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5252 - loss: 0.3227 - val_accuracy: 0.5099 - val_loss: 0.3224 - learning_rate: 1.5625e-05
# Epoch 73/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5319 - loss: 0.3213
# Epoch 73: val_accuracy did not improve from 0.50987
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5319 - loss: 0.3213 - val_accuracy: 0.5045 - val_loss: 0.3249 - learning_rate: 1.5625e-05
# Epoch 74/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5311 - loss: 0.3243
# Epoch 74: val_accuracy improved from 0.50987 to 0.51413, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5311 - loss: 0.3243 - val_accuracy: 0.5141 - val_loss: 0.3196 - learning_rate: 1.5625e-05
# Epoch 75/100
# 521/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5268 - loss: 0.3256
# Epoch 75: val_accuracy did not improve from 0.51413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5267 - loss: 0.3256 - val_accuracy: 0.5083 - val_loss: 0.3230 - learning_rate: 1.5625e-05
# Epoch 76/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5227 - loss: 0.3244
# Epoch 76: val_accuracy did not improve from 0.51413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5227 - loss: 0.3244 - val_accuracy: 0.5072 - val_loss: 0.3227 - learning_rate: 1.5625e-05
# Epoch 77/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5295 - loss: 0.3231
# Epoch 77: val_accuracy did not improve from 0.51413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5295 - loss: 0.3231 - val_accuracy: 0.5131 - val_loss: 0.3218 - learning_rate: 1.5625e-05
# Epoch 78/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5248 - loss: 0.3230
# Epoch 78: val_accuracy did not improve from 0.51413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5248 - loss: 0.3230 - val_accuracy: 0.4987 - val_loss: 0.3228 - learning_rate: 1.5625e-05
# Epoch 79/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5331 - loss: 0.3231
# Epoch 79: val_accuracy did not improve from 0.51413
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5330 - loss: 0.3231 - val_accuracy: 0.4987 - val_loss: 0.3250 - learning_rate: 1.5625e-05
# Epoch 80/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5260 - loss: 0.3230
# Epoch 80: val_accuracy did not improve from 0.51413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5260 - loss: 0.3230 - val_accuracy: 0.5104 - val_loss: 0.3197 - learning_rate: 7.8125e-06
# Epoch 81/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5351 - loss: 0.3192
# Epoch 81: val_accuracy improved from 0.51413 to 0.51627, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5351 - loss: 0.3192 - val_accuracy: 0.5163 - val_loss: 0.3190 - learning_rate: 7.8125e-06
# Epoch 82/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5272 - loss: 0.3219
# Epoch 82: val_accuracy did not improve from 0.51627
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5272 - loss: 0.3218 - val_accuracy: 0.5099 - val_loss: 0.3200 - learning_rate: 7.8125e-06
# Epoch 83/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5265 - loss: 0.3199
# Epoch 83: val_accuracy did not improve from 0.51627
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5265 - loss: 0.3199 - val_accuracy: 0.5120 - val_loss: 0.3213 - learning_rate: 7.8125e-06
# Epoch 84/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5350 - loss: 0.3180
# Epoch 84: val_accuracy did not improve from 0.51627
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5350 - loss: 0.3180 - val_accuracy: 0.5163 - val_loss: 0.3168 - learning_rate: 7.8125e-06
# Epoch 85/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5345 - loss: 0.3207
# Epoch 85: val_accuracy did not improve from 0.51627
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5345 - loss: 0.3207 - val_accuracy: 0.5072 - val_loss: 0.3202 - learning_rate: 7.8125e-06
# Epoch 86/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5361 - loss: 0.3195
# Epoch 86: val_accuracy did not improve from 0.51627
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5361 - loss: 0.3195 - val_accuracy: 0.5104 - val_loss: 0.3191 - learning_rate: 7.8125e-06
# Epoch 87/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5363 - loss: 0.3185
# Epoch 87: val_accuracy did not improve from 0.51627
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5363 - loss: 0.3185 - val_accuracy: 0.5131 - val_loss: 0.3172 - learning_rate: 7.8125e-06
# Epoch 88/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5432 - loss: 0.3165
# Epoch 88: val_accuracy did not improve from 0.51627
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5432 - loss: 0.3165 - val_accuracy: 0.5115 - val_loss: 0.3177 - learning_rate: 7.8125e-06
# Epoch 89/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5318 - loss: 0.3198
# Epoch 89: val_accuracy did not improve from 0.51627
#
# Epoch 89: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5318 - loss: 0.3198 - val_accuracy: 0.5067 - val_loss: 0.3240 - learning_rate: 7.8125e-06
# Epoch 90/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5361 - loss: 0.3170
# Epoch 90: val_accuracy did not improve from 0.51627
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5361 - loss: 0.3170 - val_accuracy: 0.5141 - val_loss: 0.3162 - learning_rate: 3.9063e-06
# Epoch 91/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5355 - loss: 0.3171
# Epoch 91: val_accuracy improved from 0.51627 to 0.51840, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5355 - loss: 0.3171 - val_accuracy: 0.5184 - val_loss: 0.3160 - learning_rate: 3.9063e-06
# Epoch 92/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5432 - loss: 0.3149
# Epoch 92: val_accuracy did not improve from 0.51840
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5432 - loss: 0.3149 - val_accuracy: 0.5152 - val_loss: 0.3157 - learning_rate: 3.9063e-06
# Epoch 93/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5401 - loss: 0.3178
# Epoch 93: val_accuracy did not improve from 0.51840
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5401 - loss: 0.3178 - val_accuracy: 0.5104 - val_loss: 0.3187 - learning_rate: 3.9063e-06
# Epoch 94/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5424 - loss: 0.3152
# Epoch 94: val_accuracy did not improve from 0.51840
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5423 - loss: 0.3152 - val_accuracy: 0.5152 - val_loss: 0.3186 - learning_rate: 3.9063e-06
# Epoch 95/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5358 - loss: 0.3167
# Epoch 95: val_accuracy did not improve from 0.51840
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5358 - loss: 0.3167 - val_accuracy: 0.5079 - val_loss: 0.3196 - learning_rate: 3.9063e-06
# Epoch 96/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5306 - loss: 0.3190
# Epoch 96: val_accuracy did not improve from 0.51840
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5307 - loss: 0.3190 - val_accuracy: 0.5179 - val_loss: 0.3163 - learning_rate: 3.9063e-06
# Epoch 97/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5314 - loss: 0.3190
# Epoch 97: val_accuracy improved from 0.51840 to 0.51893, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5314 - loss: 0.3190 - val_accuracy: 0.5189 - val_loss: 0.3144 - learning_rate: 3.9063e-06
# Epoch 98/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5375 - loss: 0.3159
# Epoch 98: val_accuracy improved from 0.51893 to 0.52053, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5374 - loss: 0.3159 - val_accuracy: 0.5205 - val_loss: 0.3131 - learning_rate: 3.9063e-06
# Epoch 99/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5378 - loss: 0.3144
# Epoch 99: val_accuracy did not improve from 0.52053
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5378 - loss: 0.3144 - val_accuracy: 0.5168 - val_loss: 0.3167 - learning_rate: 3.9063e-06
# Epoch 100/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5410 - loss: 0.3150
# Epoch 100: val_accuracy did not improve from 0.52053
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5410 - loss: 0.3150 - val_accuracy: 0.5061 - val_loss: 0.3194 - learning_rate: 3.9063e-06
# Restoring model weights from the end of the best epoch: 98.
# Best validation model: epoch 98  - val_accuracy 0.5205333232879639

# %%
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(16, 5))

    # Gráfica de Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training acc')
    plt.plot(epochs, val_acc, 'ro-', label='Validation acc')
    plt.title('Accuracy: Train vs Validation')
    plt.legend()
    plt.grid(True)

    # Gráfica de Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
    plt.title('Loss: Train vs Validation')
    plt.legend()
    plt.grid(True)

    plt.show()

# USARLO:
plot_history(h)

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
# 1. Usamos los datos que YA cargamos en RAM (Velocidad: 100x más rápido)
# model.predict procesa todo el bloque de golpe (Batch processing)
print("Prediciendo todo el validación de golpe...")
predictions = model.predict(X_valid_ram.astype('float32') / 255.0, batch_size=32, verbose=1)

# 2. Sacamos la clase ganadora de cada foto
y_pred_indices = np.argmax(predictions, axis=1) # [0, 5, 2...]

# 3. Convertimos números a nombres (si lo necesitas en texto)
class_names = list(categories.values())
y_pred = [class_names[i] for i in y_pred_indices]

# 4. Sacamos el y_true (La realidad)
# Si y_valid_ram era texto:
y_true = y_valid_ram
# Si y_valid_ram era One-Hot o índices, adáptalo.
# Asumiendo que es la lista de textos que devolvía load_dataset_to_ram:
# (Si usaste mi última función, y_valid_ram es una lista de strings ['Helipad', 'Car'...])
# Out:
# Prediciendo todo el validación de golpe...
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 51.947%
# Mean Recall: 53.627%
# Mean Precision: 52.841%
# > Cargo plane: Recall: 83.051% Precision: 80.328% Specificity: 99.339% Dice: 81.667%
# > Small car: Recall: 76.292% Precision: 66.755% Specificity: 91.915% Dice: 71.206%
# > Bus: Recall: 47.701% Precision: 50.920% Specificity: 95.297% Dice: 49.258%
# > Truck: Recall: 12.033% Precision: 32.955% Specificity: 96.389% Dice: 17.629%
# > Motorboat: Recall: 49.541% Precision: 39.130% Specificity: 95.243% Dice: 43.725%
# > Fishing vessel: Recall: 65.753% Precision: 32.653% Specificity: 94.506% Dice: 43.636%
# > Dump truck: Recall: 33.051% Precision: 46.988% Specificity: 97.496% Dice: 38.806%
# > Excavator: Recall: 74.074% Precision: 43.796% Specificity: 95.708% Dice: 55.046%
# > Building: Recall: 65.289% Precision: 57.805% Specificity: 88.558% Dice: 61.320%
# > Helipad: Recall: 44.444% Precision: 80.000% Specificity: 99.946% Dice: 57.143%
# > Storage tank: Recall: 20.395% Precision: 81.579% Specificity: 99.594% Dice: 32.632%
# > Shipping container: Recall: 47.407% Precision: 43.537% Specificity: 95.230% Dice: 45.390%
# > Pylon: Recall: 78.125% Precision: 30.488% Specificity: 96.907% Dice: 43.860%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('../content/dataset/xview_recognition/xview_test'):
    for filename in filenames:
        image = GenericImage(dirpath[29:] + '/' + filename)
        image.tile = np.array([0, 0, 64, 64])
        obj = GenericObject()
        obj.bb = (0, 0, 64, 64)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    # Fix: Remove 'gnition/' from the filename path which was incorrectly added in the previous cell
    image = load_geoimage(ann.filename[8:]) / 255.0
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)
