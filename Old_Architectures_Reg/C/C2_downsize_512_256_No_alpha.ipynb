# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Yousef Medhat
# - Alumno 2: Carlos Manzano Izquierdo
# - Alumno 3: Guillermo Bermejo Babiano
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# The -q flag means "quiet" so it doesn't print 10,000 lines and crash your browser
# !unzip -q "/content/drive/MyDrive/DL/xview_recognition.zip" -d "/content/dataset"

print("✅ Unzipping complete!")
# Out:
# ✅ Unzipping complete!

# %%
data_dir = '/content/dataset/xview_recognition' # Or whatever the extracted folder is named

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
import warnings
import rasterio
import numpy as np
import cv2

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open('../content/dataset/xview_recognition/'+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)

    img_resized = cv2.resize(img, (64, 64), interpolation=cv2.INTER_AREA)

    return img_resized

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json

# Load database
json_file = '../content/dataset/xview_recognition/xview_ann_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 16871
# Number of validation images: 1875

# %%
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L2
from tensorflow.keras.activations import swish

print('Load model')
model = Sequential()
model.add(Flatten(input_shape=(64, 64, 3)))

# Mantenemos 512, pero añadimos L2 suave para controlar los pesos
model.add(Dense(512, kernel_initializer='he_normal'))
model.add(BatchNormalization())
model.add(Activation('swish'))
# Subimos Dropout a 0.3 o 0.4. El 0.1 actual es muy poco y por eso la linea azul se escapa.
model.add(Dropout(0.3))

# --- CAPA 2: Refinamiento (NUEVA) ---
# Esta capa combina las características de la anterior. Vital para subir accuracy.
model.add(Dense(256, kernel_initializer='he_normal'))
model.add(BatchNormalization())
model.add(Activation('swish'))
model.add(Dropout(0.2))

model.add(Dense(len(categories)))
model.add(Activation('softmax'))
model.summary()
# Out:
# Load model
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 12288)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     6,291,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 13)             │         3,341 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 13)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,429,709 (24.53 MB)
#  Trainable params: 6,428,173 (24.52 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.losses import CategoricalFocalCrossentropy

focal_loss = CategoricalFocalCrossentropy(
    gamma=2.0,        # Fuerza el enfoque en lo difícil
    label_smoothing=0.1,  # Label smoothing para overfitting
    from_logits=False # False porque usamos Softmax al final
)

# Learning rate is changed to 0.005
# opt = SGD(
#     learning_rate=0.005,
#     momentum=0.9,
#     nesterov=True,
#     clipnorm=1.0
# )
opt = AdamW(learning_rate=0.001, weight_decay=1e-4)
model.compile(optimizer=opt, loss=focal_loss, metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_delta=0.001,
    cooldown=1,
    min_lr=1e-6,
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
def generator_from_ram(X_data, y_data, batch_size, do_shuffle=False, do_augment=False):
    # Índices para saber qué foto toca
    indices = np.arange(len(X_data))

    while True:
        if do_shuffle:
            np.random.shuffle(indices)

        # Troceamos los índices en batches
        for i in range(0, len(indices), batch_size):
            batch_indices = indices[i:i+batch_size]

            # Cogemos las imágenes crudas de la RAM
            batch_images_raw = X_data[batch_indices]
            batch_cats = y_data[batch_indices]

            images, labels = [], []

            for j in range(len(batch_images_raw)):
                # Copiamos la imagen para no modificar la original en RAM
                img = batch_images_raw[j].copy()
                cat = batch_cats[j]

                # ==========================================
                # AUGMENTATION "SAFE MODE" (Solo Brillo y Giros)
                # ==========================================
                if do_augment:
                    # 1. ROTACIÓN (90, 180, 270)
                    k = np.random.randint(0, 4)
                    if k > 0: img = np.rot90(img, k)

                    # 2. FLIP (Espejo)
                    if np.random.rand() > 0.5:
                        code = np.random.choice([0, 1])
                        img = cv2.flip(img, code)

                    # 3. BRILLO/CONTRASTE (Sin Traslación)
                    # Lo aplicamos el 80% de las veces para dar variedad de color
                    if np.random.rand() > 0.2:
                        alpha = np.random.uniform(0.8, 1.2) # Contraste
                        beta = np.random.uniform(-25, 25)   # Brillo
                        img = cv2.convertScaleAbs(img, alpha=alpha, beta=beta)
                # ==========================================

                # Normalización (Aquí pasamos a float)
                img_float = img.astype(np.float32) / 255.0

                # One-Hot Encoding
                prob = np.zeros(len(categories))
                prob[list(categories.values()).index(cat)] = 1

                images.append(img_float)
                labels.append(prob)

            yield np.array(images), np.array(labels)

# %%
import numpy as np
import cv2
from tqdm import tqdm  # Barra de progreso

def load_dataset_to_ram(objs_list, target_size=(64, 64)):
    print(f"Cargando {len(objs_list)} imágenes en RAM... ")

    X_data = []
    y_labels = []

    for filename, obj in tqdm(objs_list):
        # 1. Cargar
        img = load_geoimage(filename)

        # 2. Redimensionar siempre a 64x64
        # (Es vital para poder apilarlas en un array de Numpy)
        if img.shape[:2] != target_size:
            img = cv2.resize(img, target_size, interpolation=cv2.INTER_AREA)

        # 3. Guardar tal cual (uint8, 0-255).
        # NO dividas por 255 aquí o ocuparás 4 veces más RAM.
        X_data.append(img)
        y_labels.append(obj.category)

    # Convertir a Bloque Numpy
    X_data = np.array(X_data, dtype='uint8')
    y_labels = np.array(y_labels)

    print(f"¡Carga lista! Ocupa en RAM: {X_data.nbytes / 1024 / 1024:.2f} MB")
    return X_data, y_labels

# %%
def balance_dataset_list(objs):
    # 1. Contamos cuántos hay de cada clase originalmente
    counts = {}
    for _, obj in objs:
        c = obj.category
        counts[c] = counts.get(c, 0) + 1

    print("--- CONTEO ORIGINAL ---")
    print(counts)

    balanced_objs = []

    # CONFIGURACIÓN DE OBJETIVOS
    TARGET_STANDARD = 2000  # Objetivo para la mayoría (Pylons, Barcos, Camiones...)
    TARGET_TINY = 1000      # Objetivo conservador para las muy pequeñas (Helipuertos)
    TINY_THRESHOLD = 200    # Si tiene menos de 200, usamos el objetivo 'Tiny'

    for filename, obj in objs:
        # Siempre añadimos la imagen original
        balanced_objs.append((filename, obj))

        current_count = counts[obj.category]

        # Determinamos el objetivo según el tamaño de la clase
        if current_count < TINY_THRESHOLD:
            target = TARGET_TINY  # Caso Helipuertos (111 -> ~1000)
        else:
            target = TARGET_STANDARD # Caso Pylons/Trucks (300 -> ~2000)

        # Si estamos por debajo del objetivo, calculamos copias
        if current_count < target:
            # Ejemplo Pylon (312): 2000 / 312 = 6.4 -> Multiplicador 6 (Total 7 copias)
            # Ejemplo Helipuerto (111): 1000 / 111 = 9.0 -> Multiplicador 9 (Total 10 copias)
            # Restamos 1 porque ya añadimos la original arriba
            multiplier = int(target / current_count) - 1

            # Solo añadimos si el multiplicador es positivo
            if multiplier > 0:
                for _ in range(multiplier):
                    balanced_objs.append((filename, obj))

    print(f"\n--- DATASET BALANCEADO ---")
    print(f"De {len(objs)} imágenes pasamos a {len(balanced_objs)} imágenes virtuales.")

    return balanced_objs

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]

# PASO 1: Balanceo de clases
print("--- FASE 1: Balanceo ---")
objs_train_balanced = balance_dataset_list(objs_train)


# PASO 2: Cargar todo en RAM
# -------------------------------------------------------
print("\n--- FASE 2: Carga en RAM ---")
# Train con lista inflada
X_train_ram, y_train_ram = load_dataset_to_ram(objs_train_balanced)
# Valid con lista normal
X_valid_ram, y_valid_ram = load_dataset_to_ram(objs_valid)

# PASO 3: Crear Generadores Rápidos
# -------------------------------------------------------
batch_size = 32

train_gen = generator_from_ram(
    X_train_ram, y_train_ram,
    batch_size=batch_size,
    do_shuffle=True,
    do_augment=True
)

valid_gen = generator_from_ram(
    X_valid_ram, y_valid_ram,
    batch_size=batch_size,
    do_shuffle=False,
    do_augment=False
)
# Out:
# --- FASE 1: Balanceo ---
# --- CONTEO ORIGINAL ---
# {'Bus': 1594, 'Cargo plane': 576, 'Truck': 1969, 'Building': 3231, 'Fishing vessel': 633, 'Small car': 2995, 'Pylon': 280, 'Shipping container': 1388, 'Dump truck': 1118, 'Motorboat': 960, 'Storage tank': 1317, 'Excavator': 708, 'Helipad': 102}
#
# --- DATASET BALANCEADO ---
# De 16871 imágenes pasamos a 23453 imágenes virtuales.
#
# --- FASE 2: Carga en RAM ---
# Cargando 23453 imágenes en RAM...
# 100%|██████████| 23453/23453 [01:07<00:00, 350.03it/s]
# ¡Carga lista! Ocupa en RAM: 274.84 MB
# Cargando 1875 imágenes en RAM...
# 100%|██████████| 1875/1875 [00:05<00:00, 342.06it/s]
# ¡Carga lista! Ocupa en RAM: 21.97 MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_class_balance(original_objs, balanced_objs):
    # 1. Contar Originales
    counts_orig = {}
    for _, obj in original_objs:
        counts_orig[obj.category] = counts_orig.get(obj.category, 0) + 1

    # 2. Contar Balanceados
    counts_bal = {}
    for _, obj in balanced_objs:
        counts_bal[obj.category] = counts_bal.get(obj.category, 0) + 1

    # Preparar datos para plot
    classes = list(counts_orig.keys())
    # Ordenamos por cantidad original para que quede bonito
    classes.sort(key=lambda x: counts_orig[x], reverse=True)

    vals_orig = [counts_orig[c] for c in classes]
    vals_bal = [counts_bal[c] for c in classes]

    x = range(len(classes))
    width = 0.35

    plt.figure(figsize=(15, 6))
    plt.bar([i - width/2 for i in x], vals_orig, width, label='Original', color='red', alpha=0.6)
    plt.bar([i + width/2 for i in x], vals_bal, width, label='Balanceado (Virtual)', color='green', alpha=0.6)

    plt.xticks(x, classes, rotation=45, ha='right')
    plt.ylabel('Número de Imágenes')
    plt.title('Impacto del Oversampling en el Dataset')
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# USARLO:
plot_class_balance(objs_train, objs_train_balanced)

# %%
import math
import numpy as np

print('Training model')
epochs = 100
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_gen, steps_per_epoch=train_steps, validation_data=valid_gen, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2516 - loss: 0.4815
# Epoch 1: val_accuracy improved from -inf to 0.32107, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.2521 - loss: 0.4811 - val_accuracy: 0.3211 - val_loss: 0.4110 - learning_rate: 0.0010
# Epoch 2/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3525 - loss: 0.4067
# Epoch 2: val_accuracy improved from 0.32107 to 0.32373, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.3527 - loss: 0.4066 - val_accuracy: 0.3237 - val_loss: 0.4006 - learning_rate: 0.0010
# Epoch 3/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3890 - loss: 0.3864
# Epoch 3: val_accuracy improved from 0.32373 to 0.33600, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3891 - loss: 0.3864 - val_accuracy: 0.3360 - val_loss: 0.3897 - learning_rate: 0.0010
# Epoch 4/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4220 - loss: 0.3684
# Epoch 4: val_accuracy improved from 0.33600 to 0.35787, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.4220 - loss: 0.3684 - val_accuracy: 0.3579 - val_loss: 0.3834 - learning_rate: 0.0010
# Epoch 5/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4414 - loss: 0.3550
# Epoch 5: val_accuracy improved from 0.35787 to 0.36960, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4414 - loss: 0.3550 - val_accuracy: 0.3696 - val_loss: 0.3749 - learning_rate: 0.0010
# Epoch 6/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4519 - loss: 0.3543
# Epoch 6: val_accuracy improved from 0.36960 to 0.40373, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4519 - loss: 0.3543 - val_accuracy: 0.4037 - val_loss: 0.3629 - learning_rate: 0.0010
# Epoch 7/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4623 - loss: 0.3436
# Epoch 7: val_accuracy did not improve from 0.40373
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4623 - loss: 0.3436 - val_accuracy: 0.3819 - val_loss: 0.3673 - learning_rate: 0.0010
# Epoch 8/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4812 - loss: 0.3369
# Epoch 8: val_accuracy did not improve from 0.40373
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4812 - loss: 0.3369 - val_accuracy: 0.3707 - val_loss: 0.3727 - learning_rate: 0.0010
# Epoch 9/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4734 - loss: 0.3365
# Epoch 9: val_accuracy did not improve from 0.40373
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4734 - loss: 0.3365 - val_accuracy: 0.4021 - val_loss: 0.3523 - learning_rate: 0.0010
# Epoch 10/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4895 - loss: 0.3316
# Epoch 10: val_accuracy improved from 0.40373 to 0.42400, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.4894 - loss: 0.3316 - val_accuracy: 0.4240 - val_loss: 0.3489 - learning_rate: 0.0010
# Epoch 11/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4860 - loss: 0.3305
# Epoch 11: val_accuracy improved from 0.42400 to 0.44693, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4861 - loss: 0.3305 - val_accuracy: 0.4469 - val_loss: 0.3323 - learning_rate: 0.0010
# Epoch 12/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4861 - loss: 0.3300
# Epoch 12: val_accuracy did not improve from 0.44693
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4861 - loss: 0.3300 - val_accuracy: 0.4331 - val_loss: 0.3447 - learning_rate: 0.0010
# Epoch 13/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5058 - loss: 0.3210
# Epoch 13: val_accuracy improved from 0.44693 to 0.44907, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5058 - loss: 0.3210 - val_accuracy: 0.4491 - val_loss: 0.3369 - learning_rate: 0.0010
# Epoch 14/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5065 - loss: 0.3209
# Epoch 14: val_accuracy did not improve from 0.44907
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5065 - loss: 0.3209 - val_accuracy: 0.4379 - val_loss: 0.3418 - learning_rate: 0.0010
# Epoch 15/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5104 - loss: 0.3189
# Epoch 15: val_accuracy did not improve from 0.44907
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5104 - loss: 0.3189 - val_accuracy: 0.4224 - val_loss: 0.3360 - learning_rate: 0.0010
# Epoch 16/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5137 - loss: 0.3166
# Epoch 16: val_accuracy improved from 0.44907 to 0.49600, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.5137 - loss: 0.3166 - val_accuracy: 0.4960 - val_loss: 0.3160 - learning_rate: 0.0010
# Epoch 17/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5239 - loss: 0.3114
# Epoch 17: val_accuracy improved from 0.49600 to 0.50453, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5239 - loss: 0.3114 - val_accuracy: 0.5045 - val_loss: 0.3162 - learning_rate: 0.0010
# Epoch 18/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5104 - loss: 0.3158
# Epoch 18: val_accuracy did not improve from 0.50453
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5104 - loss: 0.3158 - val_accuracy: 0.3952 - val_loss: 0.3624 - learning_rate: 0.0010
# Epoch 19/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5270 - loss: 0.3085
# Epoch 19: val_accuracy did not improve from 0.50453
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5270 - loss: 0.3085 - val_accuracy: 0.4347 - val_loss: 0.3337 - learning_rate: 0.0010
# Epoch 20/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5255 - loss: 0.3070
# Epoch 20: val_accuracy did not improve from 0.50453
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5255 - loss: 0.3070 - val_accuracy: 0.4640 - val_loss: 0.3279 - learning_rate: 0.0010
# Epoch 21/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5314 - loss: 0.3063
# Epoch 21: val_accuracy did not improve from 0.50453
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5314 - loss: 0.3063 - val_accuracy: 0.4677 - val_loss: 0.3284 - learning_rate: 0.0010
# Epoch 22/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5356 - loss: 0.3030
# Epoch 22: val_accuracy improved from 0.50453 to 0.52320, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.5357 - loss: 0.3030 - val_accuracy: 0.5232 - val_loss: 0.3024 - learning_rate: 5.0000e-04
# Epoch 23/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5575 - loss: 0.2940
# Epoch 23: val_accuracy did not improve from 0.52320
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5575 - loss: 0.2940 - val_accuracy: 0.5056 - val_loss: 0.3087 - learning_rate: 5.0000e-04
# Epoch 24/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5541 - loss: 0.2959
# Epoch 24: val_accuracy improved from 0.52320 to 0.52480, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5541 - loss: 0.2959 - val_accuracy: 0.5248 - val_loss: 0.2978 - learning_rate: 5.0000e-04
# Epoch 25/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5575 - loss: 0.2930
# Epoch 25: val_accuracy did not improve from 0.52480
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5575 - loss: 0.2930 - val_accuracy: 0.5024 - val_loss: 0.3124 - learning_rate: 5.0000e-04
# Epoch 26/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5566 - loss: 0.2915
# Epoch 26: val_accuracy did not improve from 0.52480
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5566 - loss: 0.2915 - val_accuracy: 0.4816 - val_loss: 0.3200 - learning_rate: 5.0000e-04
# Epoch 27/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5653 - loss: 0.2896
# Epoch 27: val_accuracy did not improve from 0.52480
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5653 - loss: 0.2896 - val_accuracy: 0.5088 - val_loss: 0.3092 - learning_rate: 5.0000e-04
# Epoch 28/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5524 - loss: 0.2928
# Epoch 28: val_accuracy improved from 0.52480 to 0.53973, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.5524 - loss: 0.2928 - val_accuracy: 0.5397 - val_loss: 0.2955 - learning_rate: 5.0000e-04
# Epoch 29/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5674 - loss: 0.2878
# Epoch 29: val_accuracy did not improve from 0.53973
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5674 - loss: 0.2878 - val_accuracy: 0.5333 - val_loss: 0.2998 - learning_rate: 5.0000e-04
# Epoch 30/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5623 - loss: 0.2873
# Epoch 30: val_accuracy did not improve from 0.53973
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5623 - loss: 0.2873 - val_accuracy: 0.5339 - val_loss: 0.2964 - learning_rate: 5.0000e-04
# Epoch 31/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5613 - loss: 0.2881
# Epoch 31: val_accuracy did not improve from 0.53973
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.5613 - loss: 0.2881 - val_accuracy: 0.5285 - val_loss: 0.2965 - learning_rate: 5.0000e-04
# Epoch 32/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5621 - loss: 0.2869
# Epoch 32: val_accuracy improved from 0.53973 to 0.54347, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5622 - loss: 0.2869 - val_accuracy: 0.5435 - val_loss: 0.2945 - learning_rate: 5.0000e-04
# Epoch 33/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5808 - loss: 0.2819
# Epoch 33: val_accuracy did not improve from 0.54347
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5808 - loss: 0.2819 - val_accuracy: 0.5339 - val_loss: 0.2983 - learning_rate: 5.0000e-04
# Epoch 34/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5775 - loss: 0.2808
# Epoch 34: val_accuracy improved from 0.54347 to 0.54560, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5775 - loss: 0.2808 - val_accuracy: 0.5456 - val_loss: 0.2906 - learning_rate: 5.0000e-04
# Epoch 35/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5745 - loss: 0.2822
# Epoch 35: val_accuracy did not improve from 0.54560
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5745 - loss: 0.2822 - val_accuracy: 0.5408 - val_loss: 0.2943 - learning_rate: 5.0000e-04
# Epoch 36/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5766 - loss: 0.2840
# Epoch 36: val_accuracy did not improve from 0.54560
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.5766 - loss: 0.2840 - val_accuracy: 0.5232 - val_loss: 0.3012 - learning_rate: 5.0000e-04
# Epoch 37/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5782 - loss: 0.2814
# Epoch 37: val_accuracy did not improve from 0.54560
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5782 - loss: 0.2814 - val_accuracy: 0.5339 - val_loss: 0.2957 - learning_rate: 5.0000e-04
# Epoch 38/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5711 - loss: 0.2837
# Epoch 38: val_accuracy improved from 0.54560 to 0.56160, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5711 - loss: 0.2837 - val_accuracy: 0.5616 - val_loss: 0.2859 - learning_rate: 5.0000e-04
# Epoch 39/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5686 - loss: 0.2832
# Epoch 39: val_accuracy did not improve from 0.56160
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.5687 - loss: 0.2832 - val_accuracy: 0.5424 - val_loss: 0.2915 - learning_rate: 5.0000e-04
# Epoch 40/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5793 - loss: 0.2789
# Epoch 40: val_accuracy did not improve from 0.56160
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5793 - loss: 0.2789 - val_accuracy: 0.5355 - val_loss: 0.2957 - learning_rate: 5.0000e-04
# Epoch 41/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5920 - loss: 0.2760
# Epoch 41: val_accuracy did not improve from 0.56160
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5920 - loss: 0.2760 - val_accuracy: 0.5344 - val_loss: 0.2979 - learning_rate: 5.0000e-04
# Epoch 42/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5823 - loss: 0.2774
# Epoch 42: val_accuracy did not improve from 0.56160
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5823 - loss: 0.2774 - val_accuracy: 0.5376 - val_loss: 0.2894 - learning_rate: 5.0000e-04
# Epoch 43/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5815 - loss: 0.2785
# Epoch 43: val_accuracy did not improve from 0.56160
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5816 - loss: 0.2785 - val_accuracy: 0.5227 - val_loss: 0.3010 - learning_rate: 5.0000e-04
# Epoch 44/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5973 - loss: 0.2733
# Epoch 44: val_accuracy improved from 0.56160 to 0.56693, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5973 - loss: 0.2733 - val_accuracy: 0.5669 - val_loss: 0.2851 - learning_rate: 2.5000e-04
# Epoch 45/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6039 - loss: 0.2686
# Epoch 45: val_accuracy did not improve from 0.56693
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.6039 - loss: 0.2686 - val_accuracy: 0.5621 - val_loss: 0.2829 - learning_rate: 2.5000e-04
# Epoch 46/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5914 - loss: 0.2734
# Epoch 46: val_accuracy did not improve from 0.56693
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5915 - loss: 0.2734 - val_accuracy: 0.5493 - val_loss: 0.2887 - learning_rate: 2.5000e-04
# Epoch 47/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6070 - loss: 0.2707
# Epoch 47: val_accuracy improved from 0.56693 to 0.58293, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6070 - loss: 0.2707 - val_accuracy: 0.5829 - val_loss: 0.2779 - learning_rate: 2.5000e-04
# Epoch 48/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5949 - loss: 0.2747
# Epoch 48: val_accuracy did not improve from 0.58293
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5950 - loss: 0.2747 - val_accuracy: 0.5547 - val_loss: 0.2839 - learning_rate: 2.5000e-04
# Epoch 49/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6030 - loss: 0.2693
# Epoch 49: val_accuracy did not improve from 0.58293
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6030 - loss: 0.2693 - val_accuracy: 0.5712 - val_loss: 0.2822 - learning_rate: 2.5000e-04
# Epoch 50/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6130 - loss: 0.2671
# Epoch 50: val_accuracy did not improve from 0.58293
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6130 - loss: 0.2671 - val_accuracy: 0.5669 - val_loss: 0.2822 - learning_rate: 2.5000e-04
# Epoch 51/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6087 - loss: 0.2667
# Epoch 51: val_accuracy did not improve from 0.58293
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6087 - loss: 0.2667 - val_accuracy: 0.5605 - val_loss: 0.2806 - learning_rate: 2.5000e-04
# Epoch 52/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6132 - loss: 0.2643
# Epoch 52: val_accuracy did not improve from 0.58293
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6131 - loss: 0.2644 - val_accuracy: 0.5760 - val_loss: 0.2817 - learning_rate: 2.5000e-04
# Epoch 53/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6130 - loss: 0.2648
# Epoch 53: val_accuracy improved from 0.58293 to 0.59413, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6130 - loss: 0.2648 - val_accuracy: 0.5941 - val_loss: 0.2719 - learning_rate: 1.2500e-04
# Epoch 54/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6182 - loss: 0.2618
# Epoch 54: val_accuracy did not improve from 0.59413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6182 - loss: 0.2618 - val_accuracy: 0.5787 - val_loss: 0.2765 - learning_rate: 1.2500e-04
# Epoch 55/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6021 - loss: 0.2675
# Epoch 55: val_accuracy did not improve from 0.59413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6021 - loss: 0.2675 - val_accuracy: 0.5621 - val_loss: 0.2800 - learning_rate: 1.2500e-04
# Epoch 56/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6047 - loss: 0.2617
# Epoch 56: val_accuracy did not improve from 0.59413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6048 - loss: 0.2617 - val_accuracy: 0.5701 - val_loss: 0.2784 - learning_rate: 1.2500e-04
# Epoch 57/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6149 - loss: 0.2658
# Epoch 57: val_accuracy did not improve from 0.59413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6149 - loss: 0.2658 - val_accuracy: 0.5797 - val_loss: 0.2769 - learning_rate: 1.2500e-04
# Epoch 58/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6128 - loss: 0.2665
# Epoch 58: val_accuracy did not improve from 0.59413
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6128 - loss: 0.2665 - val_accuracy: 0.5813 - val_loss: 0.2757 - learning_rate: 1.2500e-04
# Epoch 59/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6076 - loss: 0.2614
# Epoch 59: val_accuracy did not improve from 0.59413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6077 - loss: 0.2614 - val_accuracy: 0.5861 - val_loss: 0.2739 - learning_rate: 6.2500e-05
# Epoch 60/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6112 - loss: 0.2634
# Epoch 60: val_accuracy did not improve from 0.59413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6112 - loss: 0.2634 - val_accuracy: 0.5787 - val_loss: 0.2743 - learning_rate: 6.2500e-05
# Epoch 61/100
# 521/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6092 - loss: 0.2647
# Epoch 61: val_accuracy did not improve from 0.59413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6092 - loss: 0.2646 - val_accuracy: 0.5842 - val_loss: 0.2727 - learning_rate: 6.2500e-05
# Epoch 62/100
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6110 - loss: 0.2643
# Epoch 62: val_accuracy did not improve from 0.59413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6110 - loss: 0.2643 - val_accuracy: 0.5851 - val_loss: 0.2737 - learning_rate: 6.2500e-05
# Epoch 63/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6124 - loss: 0.2612
# Epoch 63: val_accuracy did not improve from 0.59413
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6124 - loss: 0.2612 - val_accuracy: 0.5749 - val_loss: 0.2748 - learning_rate: 6.2500e-05
# Epoch 64/100
# 522/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6161 - loss: 0.2633
# Epoch 64: val_accuracy did not improve from 0.59413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6162 - loss: 0.2632 - val_accuracy: 0.5845 - val_loss: 0.2743 - learning_rate: 3.1250e-05
# Epoch 65/100
# 525/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6225 - loss: 0.2597
# Epoch 65: val_accuracy did not improve from 0.59413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6225 - loss: 0.2597 - val_accuracy: 0.5899 - val_loss: 0.2718 - learning_rate: 3.1250e-05
# Epoch 66/100
# 526/528 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6164 - loss: 0.2617
# Epoch 66: val_accuracy did not improve from 0.59413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6164 - loss: 0.2617 - val_accuracy: 0.5829 - val_loss: 0.2721 - learning_rate: 3.1250e-05
# Epoch 67/100
# 524/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6226 - loss: 0.2610
# Epoch 67: val_accuracy did not improve from 0.59413
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6226 - loss: 0.2610 - val_accuracy: 0.5819 - val_loss: 0.2733 - learning_rate: 3.1250e-05
# Epoch 68/100
# 523/528 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6178 - loss: 0.2620
# Epoch 68: val_accuracy did not improve from 0.59413
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6178 - loss: 0.2620 - val_accuracy: 0.5845 - val_loss: 0.2734 - learning_rate: 3.1250e-05
# Epoch 68: early stopping
# Restoring model weights from the end of the best epoch: 53.
# Best validation model: epoch 53  - val_accuracy 0.5941333174705505

# %%
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(16, 5))

    # Gráfica de Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training acc')
    plt.plot(epochs, val_acc, 'ro-', label='Validation acc')
    plt.title('Accuracy: Train vs Validation')
    plt.legend()
    plt.grid(True)

    # Gráfica de Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
    plt.title('Loss: Train vs Validation')
    plt.legend()
    plt.grid(True)

    plt.show()

# USARLO:
plot_history(h)

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
# 1. Usamos los datos que YA cargamos en RAM (Velocidad: 100x más rápido)
# model.predict procesa todo el bloque de golpe (Batch processing)
print("Prediciendo todo el validación de golpe...")
predictions = model.predict(X_valid_ram.astype('float32') / 255.0, batch_size=32, verbose=1)

# 2. Sacamos la clase ganadora de cada foto
y_pred_indices = np.argmax(predictions, axis=1) # [0, 5, 2...]

# 3. Convertimos números a nombres (si lo necesitas en texto)
class_names = list(categories.values())
y_pred = [class_names[i] for i in y_pred_indices]

# 4. Sacamos el y_true (La realidad)
# Si y_valid_ram era texto:
y_true = y_valid_ram
# Si y_valid_ram era One-Hot o índices, adáptalo.
# Asumiendo que es la lista de textos que devolvía load_dataset_to_ram:
# (Si usaste mi última función, y_valid_ram es una lista de strings ['Helipad', 'Car'...])
# Out:
# Prediciendo todo el validación de golpe...
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 58.773%
# Mean Recall: 60.208%
# Mean Precision: 58.614%
# > Cargo plane: Recall: 84.746% Precision: 94.340% Specificity: 99.835% Dice: 89.286%
# > Small car: Recall: 77.508% Precision: 72.238% Specificity: 93.661% Dice: 74.780%
# > Bus: Recall: 50.575% Precision: 54.321% Specificity: 95.650% Dice: 52.381%
# > Truck: Recall: 19.917% Precision: 45.283% Specificity: 96.450% Dice: 27.666%
# > Motorboat: Recall: 55.963% Precision: 46.212% Specificity: 95.980% Dice: 50.622%
# > Fishing vessel: Recall: 67.123% Precision: 36.567% Specificity: 95.283% Dice: 47.343%
# > Dump truck: Recall: 50.847% Precision: 55.556% Specificity: 97.268% Dice: 53.097%
# > Excavator: Recall: 70.370% Precision: 52.778% Specificity: 97.157% Dice: 60.317%
# > Building: Recall: 72.176% Precision: 63.592% Specificity: 90.079% Dice: 67.613%
# > Helipad: Recall: 55.556% Precision: 71.429% Specificity: 99.893% Dice: 62.500%
# > Storage tank: Recall: 42.763% Precision: 79.268% Specificity: 99.013% Dice: 55.556%
# > Shipping container: Recall: 57.037% Precision: 48.734% Specificity: 95.345% Dice: 52.560%
# > Pylon: Recall: 78.125% Precision: 41.667% Specificity: 98.101% Dice: 54.348%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('../content/dataset/xview_recognition/xview_test'):
    for filename in filenames:
        image = GenericImage(dirpath[29:] + '/' + filename)
        image.tile = np.array([0, 0, 64, 64])
        obj = GenericObject()
        obj.bb = (0, 0, 64, 64)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    # Fix: Remove 'gnition/' from the filename path which was incorrectly added in the previous cell
    image = load_geoimage(ann.filename[8:]) / 255.0
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)
